# %%
import re

import numpy as np
import pandas as pd
import scipy.stats as stats
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import GridSearchCV, cross_val_score
from xgboost import XGBRegressor

# %%
df = pd.read_csv('data/data.csv')
df = df.set_index('AppID')

df
# Out:
#          Score                                           name  recent_percent  \
# AppID
# 335300     6.0       DARK SOULS™ II: Scholar of the First Sin            83.0
# 374320     6.0                                DARK SOULS™ III            94.0
# 570940     6.0                        DARK SOULS™: REMASTERED            92.0
# 435150     6.0  Divinity: Original Sin 2 - Definitive Edition            93.0
# 427520     6.0                                       Factorio            98.0
# ...        ...                                            ...             ...
# 1283410    NaN                                  Tails of Iron            89.0
# 367500     NaN                    Dragon's Dogma: Dark Arisen            92.0
# 1481400    NaN                      Dagon: by H. P. Lovecraft            97.0
# 1210320    NaN              Potion Craft: Alchemist Simulator            92.0
# 757310     NaN                                          Sable            81.0
#
#          recent_count  all_percent  all_count  \
# AppID
# 335300          735.0         86.0    46611.0
# 374320         2741.0         94.0   187094.0
# 570940          742.0         86.0    30940.0
# 435150         2560.0         95.0   113478.0
# 427520         1816.0         98.0   100653.0
# ...               ...          ...        ...
# 1283410        1548.0         89.0     1548.0
# 367500          179.0         89.0    18804.0
# 1481400        2509.0         97.0     2509.0
# 1210320        2749.0         92.0     2749.0
# 757310          411.0         81.0      411.0
#
#                                                 short_desc  \
# AppID
# 335300   DARK SOULS™ II: Scholar of the First Sin bring...
# 374320   Dark Souls continues to push the boundaries wi...
# 570940   Then, there was fire. Re-experience the critic...
# 435150   The critically acclaimed RPG that raised the b...
# 427520   Factorio is a game about building and creating...
# ...                                                    ...
# 1283410  Tails of Iron is an epic RPG Adventure with pu...
# 367500   Set in a huge open world, Dragon’s Dogma: Dark...
# 1481400  Face unspeakable horrors. Succumb to madness. ...
# 1210320  Potion Craft is an alchemist simulator where y...
# 757310   Embark on a unique and unforgettable journey a...
#
#                                                  long_desc  \
# AppID
# 335300   Gamers are in for a big surprise in DARK SOULS...
# 374320   Get the DARK SOULS™ III Season Pass now and ch...
# 570940   Then, there was fire. Re-experience the critic...
# 435150   The Divine is dead. The Void approaches. And t...
# 427520   is a game in which you build and maintain fact...
# ...                                                    ...
# 1283410  Set in a grim land plagued by war, Tails of Ir...
# 367500   Set in a huge open world, presents a rewarding...
# 1481400  ----------------------------------------------...
# 1210320  Leaves, flowers, berries, roots, fruits, miner...
# 757310   Embark on a unique and unforgettable journey a...
#
#                                                       tags
# AppID
# 335300   ['Souls-like', 'Dark Fantasy', 'RPG', 'Difficu...
# 374320   ['Souls-like', 'Dark Fantasy', 'Difficult', 'R...
# 570940   ['Souls-like', 'Education', 'Dark Fantasy', 'A...
# 435150   ['Tactical RPG', 'Exploration', 'Story Rich', ...
# 427520   ['Automation', 'Base Building', 'Resource Mana...
# ...                                                    ...
# 1283410  ['Action RPG', 'Adventure', 'Souls-like', 'Act...
# 367500   ['RPG', 'Open World', 'Character Customization...
# 1481400  ['Horror', 'Lovecraftian', 'Atmospheric', 'Vis...
# 1210320  ['Early Access', 'Singleplayer', 'Crafting', '...
# 757310   ['Exploration', 'Story Rich', 'Open World', 'I...
#
# [864 rows x 9 columns]

# %%
df = df[df['name'].notnull()]

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

missing_value_df
# Out:
#                    column_name  percent_missing
# Score                    Score        90.341578
# name                      name         0.000000
# recent_percent  recent_percent         0.000000
# recent_count      recent_count         0.000000
# all_percent        all_percent         0.000000
# all_count            all_count         0.000000
# short_desc          short_desc         9.658422
# long_desc            long_desc         1.531213
# tags                      tags         0.000000

# %%
### Data Pre-process

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
model.max_seq_length = 30

# Remove appids that were unable to pull information and fill null
df = df[df['name'].notnull()]

# Fill Null
df['short_desc'] = df['short_desc'].fillna('')
df['long_desc'] = df['short_desc'].fillna('')
df['tags'] = df['tags'].fillna('')

# Normalize ratings cols
df['recent_percent']=(df['recent_percent']-df['recent_percent'].mean())/df['recent_percent'].std()
df['recent_count']=(df['recent_count']-df['recent_count'].mean())/df['recent_count'].std()
df['all_percent']=(df['all_percent']-df['all_percent'].mean())/df['all_percent'].std()
df['all_count']=(df['all_count']-df['all_count'].mean())/df['all_count'].std()

# Process name
# Get name embeddings
df['name_emb'] = None
for idx, sentence in zip(df.index, df['name'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'name_emb'] = sentence_emb

# Explode name_emb to multiple cols
emb_len = df['name_emb'].values[0].shape[0]
emb_cols = [f'name_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['name_emb'].tolist(), index=df.index)
df = df.drop(['name_emb'], axis=1)

# Process short_desc
# Get short_desc embeddings
df['short_desc_emb'] = None
for idx, sentence in zip(df.index, df['short_desc'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'short_desc_emb'] = sentence_emb

# Explode short_desc_emb to multiple cols
emb_len = df['short_desc_emb'].values[0].shape[0]
emb_cols = [f'short_desc_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['short_desc_emb'].tolist(), index=df.index)
df = df.drop(['short_desc_emb'], axis=1)

# Process long_desc
# Get long_desc embeddings
df['long_desc_emb'] = None
for idx, sentence in zip(df.index, df['long_desc'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'long_desc_emb'] = sentence_emb

# Explode short_desc_emb to multiple cols
emb_len = df['long_desc_emb'].values[0].shape[0]
emb_cols = [f'long_desc_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['long_desc_emb'].tolist(), index=df.index)
df = df.drop(['long_desc_emb'], axis=1)

# Process tags
# Get tags embeddings
df['tags_emb'] = None
for idx, sentence in zip(df.index, df['tags'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'tags_emb'] = sentence_emb

# Explode tags to multiple cols
emb_len = df['tags_emb'].values[0].shape[0]
emb_cols = [f'tags_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['tags_emb'].tolist(), index=df.index)
df = df.drop(['tags_emb'], axis=1)

# Drop unneeded cols
df_proc = df.drop(['name', 'short_desc', 'long_desc', 'tags'], axis=1)

df_proc
# Out:
# /home/mcminnra/miniconda3/envs/sgr/lib/python3.9/site-packages/pandas/core/frame.py:3636: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[k1] = value[k2]
#          Score  recent_percent  recent_count  all_percent  all_count  \
# AppID
# 335300     6.0        0.039777     -0.060399     0.184392   0.046743
# 374320     6.0        0.630355      0.424180     0.634407   0.678312
# 570940     6.0        0.522977     -0.058709     0.184392  -0.023709
# 435150     6.0        0.576666      0.380456     0.690659   0.347357
# 427520     6.0        0.845110      0.200732     0.859414   0.289700
# ...        ...             ...           ...          ...        ...
# 1283410    NaN        0.361910      0.135993     0.353148  -0.155847
# 367500     NaN        0.522977     -0.194710     0.353148  -0.078269
# 1481400    NaN        0.791422      0.368137     0.803162  -0.151526
# 1210320    NaN        0.522977      0.426112     0.521903  -0.150447
# 757310     NaN       -0.067601     -0.138666    -0.096867  -0.160958
#
#          name_emb_0  name_emb_1  name_emb_2  name_emb_3  name_emb_4  ...  \
# AppID                                                                ...
# 335300    -0.205885    0.530513    0.019095    0.098417   -0.168850  ...
# 374320    -0.425299    0.070268    0.467150   -0.283747   -0.155813  ...
# 570940    -0.411845    0.084661    0.643239   -0.140084    0.178791  ...
# 435150    -0.083358    0.879001    0.190073   -0.143532   -0.288290  ...
# 427520    -0.203325   -0.352310    0.348856    0.072503    0.431592  ...
# ...             ...         ...         ...         ...         ...  ...
# 1283410   -0.872054    0.652232    0.284597    0.426859   -0.615087  ...
# 367500    -0.070725   -0.392730    0.143116    0.816427   -0.205678  ...
# 1481400   -0.445134    0.463027    0.055783   -0.008295    0.002106  ...
# 1210320   -0.145114    0.433815   -0.178932    0.141523   -0.502249  ...
# 757310    -0.345823    0.659737    0.050544   -0.198247   -0.192339  ...
#
#          tags_emb_374  tags_emb_375  tags_emb_376  tags_emb_377  tags_emb_378  \
# AppID
# 335300       0.367525      0.402845      0.248234      0.347452     -0.244038
# 374320      -0.007539      0.256561      0.118918      0.446231     -0.118015
# 570940       0.318000      0.147942      0.137227      0.104347     -0.584267
# 435150       0.749291      0.440631     -0.025958      0.194535     -0.064091
# 427520       0.598158      0.255851     -0.037133     -0.383200      0.143489
# ...               ...           ...           ...           ...           ...
# 1283410      0.357731      0.420448      0.082633      0.339275      0.304262
# 367500       0.335243      0.437943     -0.019936      0.203400      0.053612
# 1481400      0.460440      0.226008      0.429912      0.420732     -0.389293
# 1210320      0.639029      0.421100      0.033655      0.116816     -0.047695
# 757310       0.639164      0.244734     -0.154842      0.343756     -0.176689
#
#          tags_emb_379  tags_emb_380  tags_emb_381  tags_emb_382  tags_emb_383
# AppID
# 335300       0.217287      0.596662     -0.185484      0.025290      0.248362
# 374320      -0.008100      0.701982     -0.163791     -0.200916      0.074816
# 570940       0.060784      0.632545     -0.213510      0.025605      0.109319
# 435150       0.150000     -0.038542      0.379924     -0.027450      0.074269
# 427520       0.491210     -0.059223     -0.007958      0.271041      0.497386
# ...               ...           ...           ...           ...           ...
# 1283410      0.160785      0.563766     -0.053411     -0.139348      0.180551
# 367500       0.318893      0.228779     -0.026610     -0.135828      0.252787
# 1481400      0.259608      0.723123     -0.323522     -0.453848     -0.061351
# 1210320      0.274811      0.128277      0.361566     -0.034780      0.601590
# 757310       0.310162      0.259190      0.033615     -0.109860      0.258490
#
# [849 rows x 1541 columns]

# %%
### ML Model

# data split
df_model = df_proc[df_proc['Score'].notnull()]
X = df_model.drop(['Score'], axis=1)
y = df_model['Score']

df_pred = df_proc[df_proc['Score'].isnull()]
X_pred = df_pred.drop(['Score'], axis=1)

# Fit Model
model = XGBRegressor(
    max_depth=4,  # 32
    n_estimators=354,  # 250
    objective='reg:squarederror',
    random_state=42,
    verbosity=0,
    n_jobs=-1)
model.fit(X, y)

# Get Cross Val Score
scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
print(f' Avg. MSE: {scores.mean():0.4f} (+/- {scores.std():0.4f})')

# pred
y_pred = model.predict(X_pred)

df_pred = pd.DataFrame({
    'AppID': X_pred.index.values,
    'Pred Score': y_pred
}).sort_values('Pred Score', ascending=False).set_index('AppID')
df_pred = df_pred.join(df[['name']], how='left')
df_pred = df_pred[['name', 'Pred Score']]
# Out:
#  Avg. MSE: -2.2944 (+/- 1.6671)

# %%
"""
504230	Celeste	5.581610
236430	DARK SOULS™ II	5.548808
22380	Fallout: New Vegas	5.480839
256290	Child of Light	5.277474
1030300	Hollow Knight: Silksong	5.207141
594650	Hunt: Showdown	5.200999
489520	Minion Masters	5.153164
704450	Neverwinter Nights: Enhanced Edition	5.141562
954740	Terminator: Resistance	5.114006
632470	Disco Elysium - The Final Cut	5.104737
288470	Fable Anniversary	5.088338
230230	Divinity: Original Sin (Classic)	5.075427
207170	Legend of Grimrock	5.075035
1086940	Baldur's Gate 3	5.059088
307690	Sleeping Dogs: Definitive Edition	5.048236
610180	The Jackbox Party Pack 4	5.042070
1160220	Paradise Killer	5.023338
1218500	Galactic Mining Corp	5.018690
1281930	tModLoader	5.016625
1369630	ENDER LILIES: Quietus of the Knights	5.014005
234390	Teleglitch: Die More Edition	4.997182
383870	Firewatch	4.959198
377840	FINAL FANTASY IX	4.955317
774461	The Jackbox Party Pack 5	4.934936
1284410	GWENT: The Witcher Card Game	4.933845
"""

df_pred.head(25)
# Out:
#                                           name  Pred Score
# AppID
# 377160                               Fallout 4    5.414262
# 221380                Age of Empires II (2013)    5.362202
# 720620                               TaleSpire    5.261229
# 253230                           A Hat in Time    5.117088
# 1517290                      Battlefield™ 2042    5.046405
# 1281930                             tModLoader    5.041458
# 34330                      Total War: SHOGUN 2    5.038711
# 257350      Baldur's Gate II: Enhanced Edition    5.025123
# 552500                 Warhammer: Vermintide 2    5.021749
# 204360                        Castle Crashers®    5.020782
# 22380                       Fallout: New Vegas    5.016130
# 997070                       Marvel's Avengers    5.010089
# 1124300                             HUMANKIND™    5.009285
# 1030300                Hollow Knight: Silksong    4.992552
# 1328670         Mass Effect™ Legendary Edition    4.981723
# 1184820                            Poker Quest    4.974876
# 234390            Teleglitch: Die More Edition    4.969124
# 546560                         Half-Life: Alyx    4.961234
# 813780   Age of Empires II: Definitive Edition    4.942304
# 1106750                                  Fault    4.935163
# 952060                         Resident Evil 3    4.913588
# 718850              Age of Wonders: Planetfall    4.912602
# 254700                         Resident Evil 4    4.903717
# 228280         Baldur's Gate: Enhanced Edition    4.899707
# 976730       Halo: The Master Chief Collection    4.897814

# %%
df_pred[df_pred['name'].str.contains('Celeste')]  # Picked - Pred: 5.6, Steam Rank 11
# Out:
#            name  Pred Score
# AppID
# 504230  Celeste    4.435533

# %%
for i , (col, imp) in enumerate(sorted(zip(X_pred.columns, model.feature_importances_), key=lambda x: x[1], reverse=True)[:50]):
    print(f'{i+1}:\t {col} - {imp}')
# Out:
# 1:	 short_desc_emb_281 - 0.18665967881679535
# 2:	 short_desc_emb_327 - 0.11323479562997818
# 3:	 name_emb_286 - 0.11280108988285065
# 4:	 name_emb_36 - 0.08334245532751083
# 5:	 name_emb_185 - 0.07473339140415192
# 6:	 name_emb_206 - 0.03661862760782242
# 7:	 short_desc_emb_300 - 0.036281660199165344
# 8:	 all_count - 0.02914009802043438
# 9:	 name_emb_45 - 0.02824324555695057
# 10:	 short_desc_emb_191 - 0.027385303750634193
# 11:	 short_desc_emb_331 - 0.02246381714940071
# 12:	 short_desc_emb_202 - 0.021862972527742386
# 13:	 name_emb_229 - 0.01981320232152939
# 14:	 short_desc_emb_274 - 0.019718211144208908
# 15:	 name_emb_208 - 0.015994984656572342
# 16:	 tags_emb_76 - 0.015754524618387222
# 17:	 tags_emb_295 - 0.012575052678585052
# 18:	 name_emb_218 - 0.012003966607153416
# 19:	 name_emb_189 - 0.008926288224756718
# 20:	 name_emb_231 - 0.008072699420154095
# 21:	 tags_emb_352 - 0.0073201823979616165
# 22:	 short_desc_emb_72 - 0.007291710935533047
# 23:	 name_emb_311 - 0.007240083534270525
# 24:	 name_emb_21 - 0.006994700990617275
# 25:	 name_emb_125 - 0.006476060952991247
# 26:	 name_emb_101 - 0.006094809155911207
# 27:	 name_emb_302 - 0.005842482205480337
# 28:	 tags_emb_225 - 0.0057010045275092125
# 29:	 tags_emb_362 - 0.005692285485565662
# 30:	 short_desc_emb_120 - 0.004594189580529928
# 31:	 short_desc_emb_131 - 0.004554795101284981
# 32:	 tags_emb_33 - 0.004253904335200787
# 33:	 short_desc_emb_54 - 0.004223063122481108
# 34:	 name_emb_122 - 0.002952003385871649
# 35:	 tags_emb_174 - 0.0027110252995043993
# 36:	 name_emb_375 - 0.0023679824080318213
# 37:	 short_desc_emb_47 - 0.002127044601365924
# 38:	 short_desc_emb_328 - 0.0020303295459598303
# 39:	 name_emb_138 - 0.001913223066367209
# 40:	 tags_emb_45 - 0.001800623838789761
# 41:	 short_desc_emb_61 - 0.0015957787400111556
# 42:	 tags_emb_79 - 0.0013032591668888927
# 43:	 tags_emb_312 - 0.001302211545407772
# 44:	 name_emb_4 - 0.001173940021544695
# 45:	 name_emb_201 - 0.0011187070049345493
# 46:	 short_desc_emb_23 - 0.001024909084662795
# 47:	 name_emb_354 - 0.0009995688451454043
# 48:	 name_emb_14 - 0.0008776753675192595
# 49:	 short_desc_emb_171 - 0.0008467059233225882
# 50:	 short_desc_emb_383 - 0.0008175519178621471

# %%
## Analysis

# %%
df = pd.read_excel('/mnt/c/Users/mcmin/gdrive/video_games/reviews/reviews_and_wishlist.xlsx', skiprows=2)

df
# Out:
#     Rank                                     Game     AppID Platform  \
# 0      1  Dark Souls II: Scholar of the First Sin  335300.0       PC
# 1      2                           Dark Souls III  374320.0       PC
# 2      3                    Dark Souls Remastered  570940.0       PC
# 3      4                 Divinity: Original Sin 2  435150.0       PC
# 4      5                                 Factorio  427520.0       PC
# ..   ...                                      ...       ...      ...
# 78    79                                  Outward  794260.0       PC
# 79    80                             Phasmophobia  739630.0       PC
# 80    81       Superbrothers: Sword & Sworcery EP  204060.0       PC
# 81    82                              War Thunder  236390.0       PC
# 82    83             Warhammer 40,000: Mechanicus  673880.0       PC
#
#     Year(s) Played  Score  GoG Rating  Unnamed: 7 0.2722682126  Unnamed: 9  \
# 0           2020.0    6.0         5.0         NaN          NaN          83
# 1           2020.0    6.0         5.0         NaN         Year  # of Games
# 2           2020.0    6.0         5.0         NaN       2020.0          58
# 3           2020.0    6.0         5.0         NaN       2021.0          25
# 4           2020.0    6.0         5.0         NaN       2022.0           0
# ..             ...    ...         ...         ...          ...         ...
# 78          2021.0    2.0         2.0         NaN          NaN         NaN
# 79          2021.0    2.0         2.0         NaN          NaN         NaN
# 80          2020.0    2.0         2.0         NaN          NaN         NaN
# 81          2020.0    2.0         2.0         NaN          NaN         NaN
# 82          2020.0    1.0         1.0         NaN          NaN         NaN
#
#    Unnamed: 10 0.7277317874  Unnamed: 12  Unnamed: 13
# 0        4.175        1.205          NaN          NaN
# 1   Avg Rating    SD Rating          NaN          NaN
# 2         4.31          1.2          NaN          NaN
# 3         4.04         1.21          NaN          NaN
# 4          NaN          NaN          NaN          NaN
# ..         ...          ...          ...          ...
# 78         NaN          NaN          NaN          NaN
# 79         NaN          NaN          NaN          NaN
# 80         NaN          NaN          NaN          NaN
# 81         NaN          NaN          NaN          NaN
# 82         NaN          NaN          NaN          NaN
#
# [83 rows x 14 columns]

# %%
## Hyper Opt Testing

from hyperopt import tpe, hp, fmin

def objective(params):
    MAX_SEQ_LENGTH = params['max_seq_length']
    MAX_DEPTH = params['max_depth']
    N_ESTIMATORS = params['n_estimators']
    
    df = pd.read_csv('data/data.csv')
    df = df.set_index('AppID')
    
    model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
    model.max_seq_length = MAX_SEQ_LENGTH

    # Remove appids that were unable to pull information and fill null
    df = df[df['name'].notnull()]

    # Fill Null
    df['short_desc'] = df['short_desc'].fillna('')
    df['long_desc'] = df['short_desc'].fillna('')
    df['tags'] = df['tags'].fillna('')

    # Normalize ratings cols
    df['recent_percent']=(df['recent_percent']-df['recent_percent'].mean())/df['recent_percent'].std()
    df['recent_count']=(df['recent_count']-df['recent_count'].mean())/df['recent_count'].std()
    df['all_percent']=(df['all_percent']-df['all_percent'].mean())/df['all_percent'].std()
    df['all_count']=(df['all_count']-df['all_count'].mean())/df['all_count'].std()

    # Process name
    # Get name embeddings
    df['name_emb'] = None
    for idx, sentence in zip(df.index, df['name'].values):
        sentence_emb = model.encode(sentence)
        df.at[idx, 'name_emb'] = sentence_emb

    # Explode name_emb to multiple cols
    emb_len = df['name_emb'].values[0].shape[0]
    emb_cols = [f'name_emb_{i}' for i in range(0, emb_len)]
    df[emb_cols] = pd.DataFrame(df['name_emb'].tolist(), index=df.index)
    df = df.drop(['name_emb'], axis=1)

    # Process short_desc
    # Get short_desc embeddings
    df['short_desc_emb'] = None
    for idx, sentence in zip(df.index, df['short_desc'].values):
        sentence_emb = model.encode(sentence)
        df.at[idx, 'short_desc_emb'] = sentence_emb

    # Explode short_desc_emb to multiple cols
    emb_len = df['short_desc_emb'].values[0].shape[0]
    emb_cols = [f'short_desc_emb_{i}' for i in range(0, emb_len)]
    df[emb_cols] = pd.DataFrame(df['short_desc_emb'].tolist(), index=df.index)
    df = df.drop(['short_desc_emb'], axis=1)

    # Process long_desc
    # Get long_desc embeddings
    df['long_desc_emb'] = None
    for idx, sentence in zip(df.index, df['long_desc'].values):
        sentence_emb = model.encode(sentence)
        df.at[idx, 'long_desc_emb'] = sentence_emb

    # Explode short_desc_emb to multiple cols
    emb_len = df['long_desc_emb'].values[0].shape[0]
    emb_cols = [f'long_desc_emb_{i}' for i in range(0, emb_len)]
    df[emb_cols] = pd.DataFrame(df['long_desc_emb'].tolist(), index=df.index)
    df = df.drop(['long_desc_emb'], axis=1)

    # Process tags
    # Get tags embeddings
    df['tags_emb'] = None
    for idx, sentence in zip(df.index, df['tags'].values):
        sentence_emb = model.encode(sentence)
        df.at[idx, 'tags_emb'] = sentence_emb

    # Explode tags to multiple cols
    emb_len = df['tags_emb'].values[0].shape[0]
    emb_cols = [f'tags_emb_{i}' for i in range(0, emb_len)]
    df[emb_cols] = pd.DataFrame(df['tags_emb'].tolist(), index=df.index)
    df = df.drop(['tags_emb'], axis=1)

    # Drop unneeded cols
    df_proc = df.drop(['name', 'short_desc', 'long_desc', 'tags'], axis=1).copy()
    
    # data split
    df_model = df_proc[df_proc['Score'].notnull()].copy()
    X = df_model.drop(['Score'], axis=1).copy()
    y = df_model['Score'].copy()

    df_pred = df_proc[df_proc['Score'].isnull()].copy()
    X_pred = df_pred.drop(['Score'], axis=1).copy()

    # Fit Model
    model = XGBRegressor(
        max_depth=MAX_DEPTH,
        n_estimators=N_ESTIMATORS,
        objective='reg:squarederror',
        random_state=42,
        verbosity=0,
        n_jobs=-1)
    model.fit(X, y)

    # Get Cross Val Score
    scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    
    return scores.mean()*-1


space = {
    'max_seq_length': hp.randint('max_seq_length', 20, 40),
    'max_depth': hp.randint('max_depth', 1, 8),
    'n_estimators': hp.randint('n_estimators', 200, 500)
}


best = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=60
)

print(best)
