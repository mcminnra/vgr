# %%
import re

import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import GridSearchCV, cross_val_score
from xgboost import XGBRegressor

# %%
df = pd.read_csv('data/data.csv')
df = df.set_index('AppID')

df
# Out:
#          Score                                           name  recent_percent  \
# AppID
# 335300     6.0       DARK SOULS™ II: Scholar of the First Sin            83.0
# 374320     6.0                                DARK SOULS™ III            94.0
# 570940     6.0                        DARK SOULS™: REMASTERED            93.0
# 435150     6.0  Divinity: Original Sin 2 - Definitive Edition            95.0
# 427520     6.0                                       Factorio            98.0
# ...        ...                                            ...             ...
# 1569090    NaN                                   Vivid Knight            90.0
# 1582510    NaN                              Mercenaries Blaze            71.0
# 1599340    NaN                                       Lost Ark            97.0
# 1656220    NaN               Lost Ark Platinum Founder's Pack             0.0
# 1277400    NaN        Monster Hunter Stories 2: Wings of Ruin            76.0
#
#          recent_count  all_percent  all_count  \
# AppID
# 335300         1979.0         86.0    44834.0
# 374320         7512.0         94.0   180498.0
# 570940          788.0         85.0    29344.0
# 435150         2304.0         95.0   109262.0
# 427520         2185.0         98.0    97200.0
# ...               ...          ...        ...
# 1569090         114.0         92.0      884.0
# 1582510          32.0         75.0      166.0
# 1599340        1083.0         97.0     1083.0
# 1656220           0.0          0.0        0.0
# 1277400        5886.0         76.0     5886.0
#
#                                                 short_desc  \
# AppID
# 335300   DARK SOULS™ II: Scholar of the First Sin bring...
# 374320   Dark Souls continues to push the boundaries wi...
# 570940   Then, there was fire. Re-experience the critic...
# 435150   The critically acclaimed RPG that raised the b...
# 427520   Factorio is a game about building and creating...
# ...                                                    ...
# 1569090  Vivid Knight is a roguelike adventure game in ...
# 1582510  “Mercenaries Blaze”is the 5th fantasy tactical...
# 1599340  Embark on an odyssey for the Lost Ark in a vas...
# 1656220                                                NaN
# 1277400  A new adventure awaits you in this second inst...
#
#                                                  long_desc  \
# AppID
# 335300   Gamers are in for a big surprise in DARK SOULS...
# 374320   Get the DARK SOULS™ III Season Pass now and ch...
# 570940   Then, there was fire. Re-experience the critic...
# 435150   The Divine is dead. The Void approaches. And t...
# 427520   is a game in which you build and maintain fact...
# ...                                                    ...
# 1569090  Explore a dungeon that changes with every play...
# 1582510  A story about a corrupt kingdom and a fight fo...
# 1599340  Embark on an odyssey for the Lost Ark in a vas...
# 1656220  Enjoy Lost Ark's launch in luxurious comfort w...
# 1277400  A new adventure awaits you in this second inst...
#
#                                                       tags
# AppID
# 335300   ['Souls-like', 'Dark Fantasy', 'RPG', 'Difficu...
# 374320   ['Souls-like', 'Dark Fantasy', 'Difficult', 'R...
# 570940   ['Souls-like', 'Education', 'Dark Fantasy', 'A...
# 435150   ['Tactical RPG', 'Exploration', 'Story Rich', ...
# 427520   ['Automation', 'Base Building', 'Resource Mana...
# ...                                                    ...
# 1569090  ['Roguelike Deckbuilder', 'Difficult', 'Choice...
# 1582510  ['RPG', 'Strategy', 'Turn-Based Tactics', 'Str...
# 1599340  ['Action', 'RPG', 'MMORPG', 'Action RPG', 'Adv...
# 1656220  ['Action', 'Adventure', 'Free to Play', 'Massi...
# 1277400  ['RPG', 'Adventure', 'JRPG', 'Exploration', '3...
#
# [788 rows x 9 columns]

# %%
df = df[df['name'].notnull()]

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

missing_value_df
# Out:
#                    column_name  percent_missing
# Score                    Score        90.944373
# name                      name         0.000000
# recent_percent  recent_percent         0.000000
# recent_count      recent_count         0.000000
# all_percent        all_percent         0.000000
# all_count            all_count         0.000000
# short_desc          short_desc        10.478655
# long_desc            long_desc         1.811125
# tags                      tags         0.000000

# %%
### Data Pre-process

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
model.max_seq_length = 10000

# Remove appids that were unable to pull information and fill null
df = df[df['name'].notnull()]

# Fill Null
df['short_desc'] = df['short_desc'].fillna('')
df['long_desc'] = df['short_desc'].fillna('')
df['tags'] = df['tags'].fillna('')

# Normalize ratings cols
df['recent_percent']=(df['recent_percent']-df['recent_percent'].mean())/df['recent_percent'].std()
df['recent_count']=(df['recent_count']-df['recent_count'].mean())/df['recent_count'].std()
df['all_percent']=(df['all_percent']-df['all_percent'].mean())/df['all_percent'].std()
df['all_count']=(df['all_count']-df['all_count'].mean())/df['all_count'].std()

# Process name
# Get name embeddings
df['name_emb'] = None
for idx, sentence in zip(df.index, df['name'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'name_emb'] = sentence_emb

# Explode name_emb to multiple cols
emb_len = df['name_emb'].values[0].shape[0]
emb_cols = [f'name_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['name_emb'].tolist(), index=df.index)
df = df.drop(['name_emb'], axis=1)

# Process short_desc
# Get short_desc embeddings
df['short_desc_emb'] = None
for idx, sentence in zip(df.index, df['short_desc'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'short_desc_emb'] = sentence_emb

# Explode short_desc_emb to multiple cols
emb_len = df['short_desc_emb'].values[0].shape[0]
emb_cols = [f'short_desc_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['short_desc_emb'].tolist(), index=df.index)
df = df.drop(['short_desc_emb'], axis=1)

# Process long_desc
# Get long_desc embeddings
df['long_desc_emb'] = None
for idx, sentence in zip(df.index, df['long_desc'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'long_desc_emb'] = sentence_emb

# Explode short_desc_emb to multiple cols
emb_len = df['long_desc_emb'].values[0].shape[0]
emb_cols = [f'long_desc_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['long_desc_emb'].tolist(), index=df.index)
df = df.drop(['long_desc_emb'], axis=1)

# Process tags
# Get tags embeddings
df['tags_emb'] = None
for idx, sentence in zip(df.index, df['tags'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'tags_emb'] = sentence_emb

# Explode tags to multiple cols
emb_len = df['tags_emb'].values[0].shape[0]
emb_cols = [f'tags_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['tags_emb'].tolist(), index=df.index)
df = df.drop(['tags_emb'], axis=1)

# Drop unneeded cols
df_proc = df.drop(['name', 'short_desc', 'long_desc', 'tags'], axis=1)

df_proc
# Out:
# /home/mcminnra/miniconda3/envs/sgr/lib/python3.9/site-packages/pandas/core/frame.py:3636: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[k1] = value[k2]
#          Score  recent_percent  recent_count  all_percent  all_count  \
# AppID
# 335300     6.0        0.110442      0.208409     0.220522   0.033741
# 374320     6.0        0.641903      1.538811     0.617411   0.633974
# 570940     6.0        0.593589     -0.077965     0.170911  -0.034793
# 435150     6.0        0.690218      0.286555     0.667022   0.318797
# 427520     6.0        0.835162      0.257941     0.815855   0.265430
# ...        ...             ...           ...          ...        ...
# 1569090    NaN        0.448645     -0.240028     0.518188  -0.160711
# 1582510    NaN       -0.469333     -0.259745    -0.325199  -0.163888
# 1599340    NaN        0.786847     -0.007033     0.766244  -0.159831
# 1656220    NaN       -3.899671     -0.267439    -4.046028  -0.164622
# 1277400    NaN       -0.227760      1.147842    -0.275588  -0.138580
#
#          name_emb_0  name_emb_1  name_emb_2  name_emb_3  name_emb_4  ...  \
# AppID                                                                ...
# 335300    -0.205885    0.530513    0.019095    0.098417   -0.168850  ...
# 374320    -0.425299    0.070268    0.467150   -0.283747   -0.155813  ...
# 570940    -0.411845    0.084661    0.643239   -0.140084    0.178791  ...
# 435150    -0.083358    0.879001    0.190073   -0.143532   -0.288290  ...
# 427520    -0.203325   -0.352310    0.348856    0.072503    0.431592  ...
# ...             ...         ...         ...         ...         ...  ...
# 1569090    0.290014    0.133307    0.122345    0.043768    0.076412  ...
# 1582510   -0.098120    0.447348    0.058343   -0.344018    0.370707  ...
# 1599340    0.179558    0.133478    0.584903    0.291661    0.171639  ...
# 1656220   -0.504908    0.580813    0.138196    0.232518    0.339013  ...
# 1277400   -0.014609    0.455735    0.329910    0.062382   -0.240313  ...
#
#          tags_emb_374  tags_emb_375  tags_emb_376  tags_emb_377  tags_emb_378  \
# AppID
# 335300       0.115262      0.345862      0.314601      0.397895      0.191249
# 374320       0.126674      0.339611      0.323297      0.429290      0.262892
# 570940       0.235841      0.311501      0.388661      0.383162      0.072721
# 435150       0.370163      0.379355      0.195057      0.410373      0.220993
# 427520       0.362606      0.404979      0.033295     -0.065764      0.200150
# ...               ...           ...           ...           ...           ...
# 1569090      0.056362      0.609228      0.119564      0.231422      0.050099
# 1582510      0.328313      0.634138      0.151306      0.273260     -0.119691
# 1599340      0.247450      0.369483      0.189386      0.351842      0.107656
# 1656220      0.267895      0.377920      0.187860      0.376677      0.092930
# 1277400      0.355932      0.381685      0.134755      0.323149      0.177697
#
#          tags_emb_379  tags_emb_380  tags_emb_381  tags_emb_382  tags_emb_383
# AppID
# 335300       0.155089      0.538477     -0.224875     -0.174770      0.102378
# 374320       0.199058      0.464258     -0.147462     -0.180969      0.051385
# 570940       0.044173      0.577991     -0.172254     -0.140407      0.039733
# 435150       0.058797      0.099029      0.168630      0.011805      0.039026
# 427520       0.384024     -0.044277     -0.100570      0.045499      0.350224
# ...               ...           ...           ...           ...           ...
# 1569090      0.187765      0.506191     -0.376130      0.170645      0.256374
# 1582510      0.218492     -0.013120     -0.126462      0.119150      0.207751
# 1599340      0.282955      0.151401     -0.236875      0.094177      0.057548
# 1656220      0.217142      0.113441     -0.224005      0.028210      0.128886
# 1277400      0.171907      0.277507     -0.081820     -0.013140      0.053564
#
# [773 rows x 1541 columns]

# %%
### ML Model

# data split
df_model = df_proc[df_proc['Score'].notnull()]
X = df_model.drop(['Score'], axis=1)
y = df_model['Score']

df_pred = df_proc[df_proc['Score'].isnull()]
X_pred = df_pred.drop(['Score'], axis=1)

# Fit Model
model = XGBRegressor(
    max_depth=32,
    n_estimators=250,
    objective='reg:squarederror',
    random_state=42,
    verbosity=0,
    n_jobs=-1)
model.fit(X, y)

# Get Cross Val Score
scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
print(f' Avg. MSE: {scores.mean():0.4f} (+/- {scores.std():0.4f})')

# pred
y_pred = model.predict(X_pred)

df_pred = pd.DataFrame({
    'AppID': X_pred.index.values,
    'Pred Score': y_pred
}).sort_values('Pred Score', ascending=False).set_index('AppID')
df_pred = df_pred.join(df[['name']], how='left')
df_pred = df_pred[['name', 'Pred Score']]
# Out:
#  Avg. MSE: -2.2045 (+/- 1.3941)

# %%
df_pred.head(25)
# Out:
#                                               name  Pred Score
# AppID
# 373420   Divinity: Original Sin - Enhanced Edition    5.889911
# 230230            Divinity: Original Sin (Classic)    5.594720
# 258970                    Gauntlet™ Slayer Edition    5.530334
# 727850                                   ELDERBORN    5.454527
# 236430                              DARK SOULS™ II    5.429187
# 610180                    The Jackbox Party Pack 4    5.410854
# 1086940                            Baldur's Gate 3    5.398372
# 1090202       Destiny 2: Shadowkeep Digital Deluxe    5.387590
# 57300                    Amnesia: The Dark Descent    5.353191
# 812140                   Assassin's Creed® Odyssey    5.337534
# 288470                           Fable Anniversary    5.336144
# 972660                                Spiritfarer®    5.321304
# 466300       Planescape: Torment: Enhanced Edition    5.316258
# 434170                    The Jackbox Party Pack 3    5.305679
# 973760            Thronebreaker: The Witcher Tales    5.304965
# 366090                             Colony Survival    5.298052
# 995980                                 Fae Tactics    5.249742
# 1090200                      Destiny 2: Shadowkeep    5.246860
# 55230                        Saints Row: The Third    5.240653
# 320                        Half-Life 2: Deathmatch    5.222818
# 471810                               Death Squared    5.222415
# 374040                              Portal Knights    5.198342
# 740130                              Tales of Arise    5.192035
# 247240                          Volgarr the Viking    5.189807
# 792710                                   Levelhead    5.186869

# %%
for i , (col, imp) in enumerate(sorted(zip(X_pred.columns, model.feature_importances_), key=lambda x: x[1], reverse=True)):
    print(f'{i+1}:\t {col} - {imp}')
# Out:
# 1:	 tags_emb_45 - 0.15889500081539154
# 2:	 short_desc_emb_77 - 0.12083449959754944
# 3:	 name_emb_320 - 0.08438920229673386
# 4:	 tags_emb_369 - 0.08187878131866455
# 5:	 tags_emb_140 - 0.06282053887844086
# 6:	 tags_emb_2 - 0.04937141016125679
# 7:	 tags_emb_183 - 0.040391936898231506
# 8:	 short_desc_emb_72 - 0.0393349714577198
# 9:	 name_emb_291 - 0.03929606080055237
# 10:	 name_emb_270 - 0.028644585981965065
# 11:	 name_emb_44 - 0.027433916926383972
# 12:	 tags_emb_331 - 0.02735893987119198
# 13:	 short_desc_emb_273 - 0.02616981230676174
# 14:	 tags_emb_164 - 0.02198970317840576
# 15:	 name_emb_236 - 0.019435252994298935
# 16:	 tags_emb_354 - 0.013787875883281231
# 17:	 name_emb_308 - 0.013079879805445671
# 18:	 short_desc_emb_270 - 0.012608706951141357
# 19:	 tags_emb_146 - 0.011722777038812637
# 20:	 name_emb_120 - 0.011319129727780819
# 21:	 name_emb_22 - 0.01026031281799078
# 22:	 name_emb_13 - 0.008552712388336658
# 23:	 short_desc_emb_114 - 0.008478990755975246
# 24:	 short_desc_emb_361 - 0.00742401834577322
# 25:	 name_emb_98 - 0.006275235675275326
# 26:	 name_emb_169 - 0.0054762219078838825
# 27:	 name_emb_232 - 0.005414815619587898
# 28:	 name_emb_82 - 0.005132375750690699
# 29:	 name_emb_298 - 0.004887017887085676
# 30:	 name_emb_1 - 0.004024010617285967
# 31:	 name_emb_301 - 0.0032737429719418287
# 32:	 name_emb_141 - 0.0028450831305235624
# 33:	 name_emb_358 - 0.0028015333227813244
# 34:	 name_emb_325 - 0.002729312749579549
# 35:	 name_emb_52 - 0.002626598346978426
# 36:	 short_desc_emb_328 - 0.002254925202578306
# 37:	 short_desc_emb_196 - 0.002017541788518429
# 38:	 tags_emb_83 - 0.0020088315941393375
# 39:	 tags_emb_6 - 0.001703202840872109
# 40:	 name_emb_58 - 0.0016614380292594433
# 41:	 name_emb_297 - 0.0016401545144617558
# 42:	 short_desc_emb_56 - 0.0013605966232717037
# 43:	 name_emb_87 - 0.001296622445806861
# 44:	 name_emb_311 - 0.0012792774941772223
# 45:	 tags_emb_229 - 0.000993013964034617
# 46:	 name_emb_32 - 0.0009244640241377056
# 47:	 name_emb_67 - 0.0009161009802483022
# 48:	 name_emb_3 - 0.0008689126116223633
# 49:	 tags_emb_267 - 0.0008161014411598444
# 50:	 name_emb_155 - 0.0007987113203853369
# 51:	 name_emb_283 - 0.0006216811016201973
# 52:	 short_desc_emb_333 - 0.0005821310915052891
# 53:	 name_emb_53 - 0.0005739713087677956
# 54:	 tags_emb_52 - 0.0005012510227970779
# 55:	 tags_emb_199 - 0.0004572706820908934
# 56:	 name_emb_115 - 0.00043379669659771025
# 57:	 short_desc_emb_381 - 0.0003411485522519797
# 58:	 name_emb_57 - 0.0003232975723221898
# 59:	 name_emb_25 - 0.00030639610486105084
# 60:	 name_emb_65 - 0.00028196658240631223
# 61:	 tags_emb_206 - 0.00026577836251817644
# 62:	 name_emb_108 - 0.0002557819534558803
# 63:	 name_emb_107 - 0.0002302850189153105
# 64:	 recent_percent - 0.00021922258019912988
# 65:	 tags_emb_252 - 0.00018572519184090197
# 66:	 short_desc_emb_190 - 0.00018381468544248492
# 67:	 short_desc_emb_66 - 0.00018074881518259645
# 68:	 short_desc_emb_336 - 0.00017415816546417773
# 69:	 name_emb_260 - 0.0001672594662522897
# 70:	 short_desc_emb_211 - 0.00016588139988016337
# 71:	 name_emb_353 - 0.00015771144535392523
# 72:	 tags_emb_79 - 0.00014625715266447514
# 73:	 name_emb_15 - 0.00014607436605729163
# 74:	 short_desc_emb_182 - 0.00013907828542869538
# 75:	 name_emb_16 - 0.00012817179958801717
# 76:	 name_emb_17 - 0.0001244595187017694
# 77:	 short_desc_emb_281 - 0.00010714102245401591
# 78:	 tags_emb_204 - 9.621197386877611e-05
# 79:	 name_emb_12 - 8.999672718346119e-05
# 80:	 name_emb_60 - 8.468085434287786e-05
# 81:	 name_emb_273 - 7.791061943862587e-05
# 82:	 tags_emb_186 - 6.995377771090716e-05
# 83:	 name_emb_96 - 6.874968676129356e-05
# 84:	 name_emb_264 - 5.5008786148391664e-05
# 85:	 name_emb_40 - 5.333159788278863e-05
# 86:	 short_desc_emb_309 - 5.030536340200342e-05
# 87:	 tags_emb_197 - 4.122575046494603e-05
# 88:	 tags_emb_189 - 3.262235622969456e-05
# 89:	 recent_count - 3.1646282877773046e-05
# 90:	 name_emb_303 - 2.7374402634450234e-05
# 91:	 name_emb_76 - 2.7323872927809134e-05
# 92:	 name_emb_322 - 2.6203773813904263e-05
# 93:	 name_emb_174 - 2.516323365853168e-05
# 94:	 tags_emb_162 - 1.9973356756963767e-05
# 95:	 tags_emb_196 - 1.837991840147879e-05
# 96:	 tags_emb_266 - 1.7809947166824713e-05
# 97:	 short_desc_emb_210 - 1.762124702509027e-05
# 98:	 short_desc_emb_186 - 1.5281215382856317e-05
# 99:	 name_emb_136 - 1.2073867765138857e-05
# 100:	 name_emb_68 - 1.0286668839398772e-05
# 101:	 name_emb_336 - 8.524963050149381e-06
# 102:	 short_desc_emb_153 - 8.069835530477576e-06
# 103:	 name_emb_284 - 6.9378220359794796e-06
# 104:	 name_emb_341 - 6.929043138370616e-06
# 105:	 short_desc_emb_16 - 6.3963511820475105e-06
# 106:	 short_desc_emb_45 - 6.245814802241512e-06
# 107:	 tags_emb_30 - 5.884184247406665e-06
# 108:	 tags_emb_200 - 4.660789727495285e-06
# 109:	 short_desc_emb_382 - 4.1014882299350575e-06
# 110:	 tags_emb_348 - 4.037302460346837e-06
# 111:	 short_desc_emb_29 - 3.854986971418839e-06
# 112:	 name_emb_242 - 3.830285550066037e-06
# 113:	 name_emb_80 - 3.767718226299621e-06
# 114:	 tags_emb_276 - 3.666017846626346e-06
# 115:	 name_emb_51 - 3.5241414479969535e-06
# 116:	 tags_emb_53 - 3.52174151885265e-06
# 117:	 name_emb_10 - 3.374536845512921e-06
# 118:	 short_desc_emb_306 - 3.142605237371754e-06
# 119:	 name_emb_8 - 2.837736701621907e-06
# 120:	 tags_emb_80 - 2.3742238681734307e-06
# 121:	 tags_emb_312 - 2.3145564682636177e-06
# 122:	 all_percent - 2.249892759209615e-06
# 123:	 short_desc_emb_175 - 1.925632659549592e-06
# 124:	 name_emb_27 - 1.90075161299319e-06
# 125:	 tags_emb_151 - 1.648744387239276e-06
# 126:	 name_emb_2 - 1.5924432545944e-06
# 127:	 name_emb_337 - 1.5408888884849148e-06
# 128:	 tags_emb_215 - 1.2094424164388329e-06
# 129:	 name_emb_287 - 1.1760395182136563e-06
# 130:	 name_emb_148 - 1.1491124496387783e-06
# 131:	 name_emb_37 - 9.045749607139442e-07
# 132:	 short_desc_emb_326 - 8.747640549700009e-07
# 133:	 name_emb_74 - 8.114309366646921e-07
# 134:	 name_emb_7 - 7.805101063240727e-07
# 135:	 name_emb_0 - 7.043857408461918e-07
# 136:	 name_emb_29 - 6.914980303918128e-07
# 137:	 short_desc_emb_137 - 6.615994720959861e-07
# 138:	 short_desc_emb_22 - 6.383513095897797e-07
# 139:	 short_desc_emb_9 - 6.336629212455591e-07
# 140:	 short_desc_emb_27 - 6.085513177822577e-07
# 141:	 name_emb_6 - 5.575711270466854e-07
# 142:	 name_emb_176 - 4.903855597149231e-07
# 143:	 name_emb_45 - 4.547276262201194e-07
# 144:	 name_emb_160 - 3.8068333196861204e-07
# 145:	 name_emb_246 - 3.385457318927365e-07
# 146:	 name_emb_376 - 3.374071297912451e-07
# 147:	 name_emb_21 - 3.2464078003613395e-07
# 148:	 name_emb_92 - 1.9201509360300406e-07
# 149:	 name_emb_162 - 1.85695114396367e-07
# 150:	 name_emb_302 - 1.8036635651696997e-07
# 151:	 short_desc_emb_94 - 1.651707179917139e-07
# 152:	 short_desc_emb_274 - 1.4608689014039555e-07
# 153:	 short_desc_emb_292 - 1.4438451501064264e-07
# 154:	 name_emb_113 - 1.3992259084716352e-07
# 155:	 short_desc_emb_84 - 1.2963869266968686e-07
# 156:	 name_emb_4 - 1.2251798864326702e-07
# 157:	 name_emb_14 - 1.221629304382077e-07
# 158:	 tags_emb_84 - 1.160766345265074e-07
# 159:	 name_emb_81 - 1.071170316890857e-07
# 160:	 short_desc_emb_239 - 1.0486011348120883e-07
# 161:	 tags_emb_74 - 8.995240818876482e-08
# 162:	 name_emb_48 - 7.969725146494966e-08
# 163:	 name_emb_281 - 7.630553255921768e-08
# 164:	 name_emb_199 - 6.944240737993823e-08
# 165:	 name_emb_154 - 6.360192372767415e-08
# 166:	 short_desc_emb_340 - 5.963909899264763e-08
# 167:	 name_emb_130 - 5.211566644902632e-08
# 168:	 short_desc_emb_113 - 5.204293529459392e-08
# 169:	 name_emb_335 - 5.082804577227762e-08
# 170:	 short_desc_emb_4 - 4.2512599662813955e-08
# 171:	 name_emb_23 - 4.114210838679355e-08
# 172:	 short_desc_emb_329 - 3.9507863647259e-08
# 173:	 short_desc_emb_17 - 3.665414283204882e-08
# 174:	 tags_emb_237 - 3.4122056291607805e-08
# 175:	 short_desc_emb_375 - 3.3235576069046147e-08
# 176:	 name_emb_363 - 3.010528715208238e-08
# 177:	 short_desc_emb_299 - 2.8508502225577104e-08
# 178:	 name_emb_138 - 2.823175471178274e-08
# 179:	 name_emb_201 - 2.6623505178235973e-08
# 180:	 name_emb_324 - 2.606449989173143e-08
# 181:	 short_desc_emb_213 - 2.5965736227817615e-08
# 182:	 short_desc_emb_337 - 2.549479027891266e-08
# 183:	 tags_emb_5 - 2.421622546933122e-08
# 184:	 name_emb_39 - 2.192136783207843e-08
# 185:	 name_emb_355 - 2.033788426558658e-08
# 186:	 name_emb_222 - 1.919103453928983e-08
# 187:	 short_desc_emb_31 - 1.5411787401831134e-08
# 188:	 short_desc_emb_235 - 1.505454072514567e-08
# 189:	 tags_emb_68 - 1.4980033213873867e-08
# 190:	 short_desc_emb_157 - 1.4175006946004487e-08
# 191:	 name_emb_349 - 1.3579161795007622e-08
# 192:	 name_emb_127 - 1.3429577450096986e-08
# 193:	 all_count - 0.0
# 194:	 name_emb_5 - 0.0
# 195:	 name_emb_9 - 0.0
# 196:	 name_emb_11 - 0.0
# 197:	 name_emb_18 - 0.0
# 198:	 name_emb_19 - 0.0
# 199:	 name_emb_20 - 0.0
# 200:	 name_emb_24 - 0.0
# 201:	 name_emb_26 - 0.0
# 202:	 name_emb_28 - 0.0
# 203:	 name_emb_30 - 0.0
# 204:	 name_emb_31 - 0.0
# 205:	 name_emb_33 - 0.0
# 206:	 name_emb_34 - 0.0
# 207:	 name_emb_35 - 0.0
# 208:	 name_emb_36 - 0.0
# 209:	 name_emb_38 - 0.0
# 210:	 name_emb_41 - 0.0
# 211:	 name_emb_42 - 0.0
# 212:	 name_emb_43 - 0.0
# 213:	 name_emb_46 - 0.0
# 214:	 name_emb_47 - 0.0
# 215:	 name_emb_49 - 0.0
# 216:	 name_emb_50 - 0.0
# 217:	 name_emb_54 - 0.0
# 218:	 name_emb_55 - 0.0
# 219:	 name_emb_56 - 0.0
# 220:	 name_emb_59 - 0.0
# 221:	 name_emb_61 - 0.0
# 222:	 name_emb_62 - 0.0
# 223:	 name_emb_63 - 0.0
# 224:	 name_emb_64 - 0.0
# 225:	 name_emb_66 - 0.0
# 226:	 name_emb_69 - 0.0
# 227:	 name_emb_70 - 0.0
# 228:	 name_emb_71 - 0.0
# 229:	 name_emb_72 - 0.0
# 230:	 name_emb_73 - 0.0
# 231:	 name_emb_75 - 0.0
# 232:	 name_emb_77 - 0.0
# 233:	 name_emb_78 - 0.0
# 234:	 name_emb_79 - 0.0
# 235:	 name_emb_83 - 0.0
# 236:	 name_emb_84 - 0.0
# 237:	 name_emb_85 - 0.0
# 238:	 name_emb_86 - 0.0
# 239:	 name_emb_88 - 0.0
# 240:	 name_emb_89 - 0.0
# 241:	 name_emb_90 - 0.0
# 242:	 name_emb_91 - 0.0
# 243:	 name_emb_93 - 0.0
# 244:	 name_emb_94 - 0.0
# 245:	 name_emb_95 - 0.0
# 246:	 name_emb_97 - 0.0
# 247:	 name_emb_99 - 0.0
# 248:	 name_emb_100 - 0.0
# 249:	 name_emb_101 - 0.0
# 250:	 name_emb_102 - 0.0
# 251:	 name_emb_103 - 0.0
# 252:	 name_emb_104 - 0.0
# 253:	 name_emb_105 - 0.0
# 254:	 name_emb_106 - 0.0
# 255:	 name_emb_109 - 0.0
# 256:	 name_emb_110 - 0.0
# 257:	 name_emb_111 - 0.0
# 258:	 name_emb_112 - 0.0
# 259:	 name_emb_114 - 0.0
# 260:	 name_emb_116 - 0.0
# 261:	 name_emb_117 - 0.0
# 262:	 name_emb_118 - 0.0
# 263:	 name_emb_119 - 0.0
# 264:	 name_emb_121 - 0.0
# 265:	 name_emb_122 - 0.0
# 266:	 name_emb_123 - 0.0
# 267:	 name_emb_124 - 0.0
# 268:	 name_emb_125 - 0.0
# 269:	 name_emb_126 - 0.0
# 270:	 name_emb_128 - 0.0
# 271:	 name_emb_129 - 0.0
# 272:	 name_emb_131 - 0.0
# 273:	 name_emb_132 - 0.0
# 274:	 name_emb_133 - 0.0
# 275:	 name_emb_134 - 0.0
# 276:	 name_emb_135 - 0.0
# 277:	 name_emb_137 - 0.0
# 278:	 name_emb_139 - 0.0
# 279:	 name_emb_140 - 0.0
# 280:	 name_emb_142 - 0.0
# 281:	 name_emb_143 - 0.0
# 282:	 name_emb_144 - 0.0
# 283:	 name_emb_145 - 0.0
# 284:	 name_emb_146 - 0.0
# 285:	 name_emb_147 - 0.0
# 286:	 name_emb_149 - 0.0
# 287:	 name_emb_150 - 0.0
# 288:	 name_emb_151 - 0.0
# 289:	 name_emb_152 - 0.0
# 290:	 name_emb_153 - 0.0
# 291:	 name_emb_156 - 0.0
# 292:	 name_emb_157 - 0.0
# 293:	 name_emb_158 - 0.0
# 294:	 name_emb_159 - 0.0
# 295:	 name_emb_161 - 0.0
# 296:	 name_emb_163 - 0.0
# 297:	 name_emb_164 - 0.0
# 298:	 name_emb_165 - 0.0
# 299:	 name_emb_166 - 0.0
# 300:	 name_emb_167 - 0.0
# 301:	 name_emb_168 - 0.0
# 302:	 name_emb_170 - 0.0
# 303:	 name_emb_171 - 0.0
# 304:	 name_emb_172 - 0.0
# 305:	 name_emb_173 - 0.0
# 306:	 name_emb_175 - 0.0
# 307:	 name_emb_177 - 0.0
# 308:	 name_emb_178 - 0.0
# 309:	 name_emb_179 - 0.0
# 310:	 name_emb_180 - 0.0
# 311:	 name_emb_181 - 0.0
# 312:	 name_emb_182 - 0.0
# 313:	 name_emb_183 - 0.0
# 314:	 name_emb_184 - 0.0
# 315:	 name_emb_185 - 0.0
# 316:	 name_emb_186 - 0.0
# 317:	 name_emb_187 - 0.0
# 318:	 name_emb_188 - 0.0
# 319:	 name_emb_189 - 0.0
# 320:	 name_emb_190 - 0.0
# 321:	 name_emb_191 - 0.0
# 322:	 name_emb_192 - 0.0
# 323:	 name_emb_193 - 0.0
# 324:	 name_emb_194 - 0.0
# 325:	 name_emb_195 - 0.0
# 326:	 name_emb_196 - 0.0
# 327:	 name_emb_197 - 0.0
# 328:	 name_emb_198 - 0.0
# 329:	 name_emb_200 - 0.0
# 330:	 name_emb_202 - 0.0
# 331:	 name_emb_203 - 0.0
# 332:	 name_emb_204 - 0.0
# 333:	 name_emb_205 - 0.0
# 334:	 name_emb_206 - 0.0
# 335:	 name_emb_207 - 0.0
# 336:	 name_emb_208 - 0.0
# 337:	 name_emb_209 - 0.0
# 338:	 name_emb_210 - 0.0
# 339:	 name_emb_211 - 0.0
# 340:	 name_emb_212 - 0.0
# 341:	 name_emb_213 - 0.0
# 342:	 name_emb_214 - 0.0
# 343:	 name_emb_215 - 0.0
# 344:	 name_emb_216 - 0.0
# 345:	 name_emb_217 - 0.0
# 346:	 name_emb_218 - 0.0
# 347:	 name_emb_219 - 0.0
# 348:	 name_emb_220 - 0.0
# 349:	 name_emb_221 - 0.0
# 350:	 name_emb_223 - 0.0
# 351:	 name_emb_224 - 0.0
# 352:	 name_emb_225 - 0.0
# 353:	 name_emb_226 - 0.0
# 354:	 name_emb_227 - 0.0
# 355:	 name_emb_228 - 0.0
# 356:	 name_emb_229 - 0.0
# 357:	 name_emb_230 - 0.0
# 358:	 name_emb_231 - 0.0
# 359:	 name_emb_233 - 0.0
# 360:	 name_emb_234 - 0.0
# 361:	 name_emb_235 - 0.0
# 362:	 name_emb_237 - 0.0
# 363:	 name_emb_238 - 0.0
# 364:	 name_emb_239 - 0.0
# 365:	 name_emb_240 - 0.0
# 366:	 name_emb_241 - 0.0
# 367:	 name_emb_243 - 0.0
# 368:	 name_emb_244 - 0.0
# 369:	 name_emb_245 - 0.0
# 370:	 name_emb_247 - 0.0
# 371:	 name_emb_248 - 0.0
# 372:	 name_emb_249 - 0.0
# 373:	 name_emb_250 - 0.0
# 374:	 name_emb_251 - 0.0
# 375:	 name_emb_252 - 0.0
# 376:	 name_emb_253 - 0.0
# 377:	 name_emb_254 - 0.0
# 378:	 name_emb_255 - 0.0
# 379:	 name_emb_256 - 0.0
# 380:	 name_emb_257 - 0.0
# 381:	 name_emb_258 - 0.0
# 382:	 name_emb_259 - 0.0
# 383:	 name_emb_261 - 0.0
# 384:	 name_emb_262 - 0.0
# 385:	 name_emb_263 - 0.0
# 386:	 name_emb_265 - 0.0
# 387:	 name_emb_266 - 0.0
# 388:	 name_emb_267 - 0.0
# 389:	 name_emb_268 - 0.0
# 390:	 name_emb_269 - 0.0
# 391:	 name_emb_271 - 0.0
# 392:	 name_emb_272 - 0.0
# 393:	 name_emb_274 - 0.0
# 394:	 name_emb_275 - 0.0
# 395:	 name_emb_276 - 0.0
# 396:	 name_emb_277 - 0.0
# 397:	 name_emb_278 - 0.0
# 398:	 name_emb_279 - 0.0
# 399:	 name_emb_280 - 0.0
# 400:	 name_emb_282 - 0.0
# 401:	 name_emb_285 - 0.0
# 402:	 name_emb_286 - 0.0
# 403:	 name_emb_288 - 0.0
# 404:	 name_emb_289 - 0.0
# 405:	 name_emb_290 - 0.0
# 406:	 name_emb_292 - 0.0
# 407:	 name_emb_293 - 0.0
# 408:	 name_emb_294 - 0.0
# 409:	 name_emb_295 - 0.0
# 410:	 name_emb_296 - 0.0
# 411:	 name_emb_299 - 0.0
# 412:	 name_emb_300 - 0.0
# 413:	 name_emb_304 - 0.0
# 414:	 name_emb_305 - 0.0
# 415:	 name_emb_306 - 0.0
# 416:	 name_emb_307 - 0.0
# 417:	 name_emb_309 - 0.0
# 418:	 name_emb_310 - 0.0
# 419:	 name_emb_312 - 0.0
# 420:	 name_emb_313 - 0.0
# 421:	 name_emb_314 - 0.0
# 422:	 name_emb_315 - 0.0
# 423:	 name_emb_316 - 0.0
# 424:	 name_emb_317 - 0.0
# 425:	 name_emb_318 - 0.0
# 426:	 name_emb_319 - 0.0
# 427:	 name_emb_321 - 0.0
# 428:	 name_emb_323 - 0.0
# 429:	 name_emb_326 - 0.0
# 430:	 name_emb_327 - 0.0
# 431:	 name_emb_328 - 0.0
# 432:	 name_emb_329 - 0.0
# 433:	 name_emb_330 - 0.0
# 434:	 name_emb_331 - 0.0
# 435:	 name_emb_332 - 0.0
# 436:	 name_emb_333 - 0.0
# 437:	 name_emb_334 - 0.0
# 438:	 name_emb_338 - 0.0
# 439:	 name_emb_339 - 0.0
# 440:	 name_emb_340 - 0.0
# 441:	 name_emb_342 - 0.0
# 442:	 name_emb_343 - 0.0
# 443:	 name_emb_344 - 0.0
# 444:	 name_emb_345 - 0.0
# 445:	 name_emb_346 - 0.0
# 446:	 name_emb_347 - 0.0
# 447:	 name_emb_348 - 0.0
# 448:	 name_emb_350 - 0.0
# 449:	 name_emb_351 - 0.0
# 450:	 name_emb_352 - 0.0
# 451:	 name_emb_354 - 0.0
# 452:	 name_emb_356 - 0.0
# 453:	 name_emb_357 - 0.0
# 454:	 name_emb_359 - 0.0
# 455:	 name_emb_360 - 0.0
# 456:	 name_emb_361 - 0.0
# 457:	 name_emb_362 - 0.0
# 458:	 name_emb_364 - 0.0
# 459:	 name_emb_365 - 0.0
# 460:	 name_emb_366 - 0.0
# 461:	 name_emb_367 - 0.0
# 462:	 name_emb_368 - 0.0
# 463:	 name_emb_369 - 0.0
# 464:	 name_emb_370 - 0.0
# 465:	 name_emb_371 - 0.0
# 466:	 name_emb_372 - 0.0
# 467:	 name_emb_373 - 0.0
# 468:	 name_emb_374 - 0.0
# 469:	 name_emb_375 - 0.0
# 470:	 name_emb_377 - 0.0
# 471:	 name_emb_378 - 0.0
# 472:	 name_emb_379 - 0.0
# 473:	 name_emb_380 - 0.0
# 474:	 name_emb_381 - 0.0
# 475:	 name_emb_382 - 0.0
# 476:	 name_emb_383 - 0.0
# 477:	 short_desc_emb_0 - 0.0
# 478:	 short_desc_emb_1 - 0.0
# 479:	 short_desc_emb_2 - 0.0
# 480:	 short_desc_emb_3 - 0.0
# 481:	 short_desc_emb_5 - 0.0
# 482:	 short_desc_emb_6 - 0.0
# 483:	 short_desc_emb_7 - 0.0
# 484:	 short_desc_emb_8 - 0.0
# 485:	 short_desc_emb_10 - 0.0
# 486:	 short_desc_emb_11 - 0.0
# 487:	 short_desc_emb_12 - 0.0
# 488:	 short_desc_emb_13 - 0.0
# 489:	 short_desc_emb_14 - 0.0
# 490:	 short_desc_emb_15 - 0.0
# 491:	 short_desc_emb_18 - 0.0
# 492:	 short_desc_emb_19 - 0.0
# 493:	 short_desc_emb_20 - 0.0
# 494:	 short_desc_emb_21 - 0.0
# 495:	 short_desc_emb_23 - 0.0
# 496:	 short_desc_emb_24 - 0.0
# 497:	 short_desc_emb_25 - 0.0
# 498:	 short_desc_emb_26 - 0.0
# 499:	 short_desc_emb_28 - 0.0
# 500:	 short_desc_emb_30 - 0.0
# 501:	 short_desc_emb_32 - 0.0
# 502:	 short_desc_emb_33 - 0.0
# 503:	 short_desc_emb_34 - 0.0
# 504:	 short_desc_emb_35 - 0.0
# 505:	 short_desc_emb_36 - 0.0
# 506:	 short_desc_emb_37 - 0.0
# 507:	 short_desc_emb_38 - 0.0
# 508:	 short_desc_emb_39 - 0.0
# 509:	 short_desc_emb_40 - 0.0
# 510:	 short_desc_emb_41 - 0.0
# 511:	 short_desc_emb_42 - 0.0
# 512:	 short_desc_emb_43 - 0.0
# 513:	 short_desc_emb_44 - 0.0
# 514:	 short_desc_emb_46 - 0.0
# 515:	 short_desc_emb_47 - 0.0
# 516:	 short_desc_emb_48 - 0.0
# 517:	 short_desc_emb_49 - 0.0
# 518:	 short_desc_emb_50 - 0.0
# 519:	 short_desc_emb_51 - 0.0
# 520:	 short_desc_emb_52 - 0.0
# 521:	 short_desc_emb_53 - 0.0
# 522:	 short_desc_emb_54 - 0.0
# 523:	 short_desc_emb_55 - 0.0
# 524:	 short_desc_emb_57 - 0.0
# 525:	 short_desc_emb_58 - 0.0
# 526:	 short_desc_emb_59 - 0.0
# 527:	 short_desc_emb_60 - 0.0
# 528:	 short_desc_emb_61 - 0.0
# 529:	 short_desc_emb_62 - 0.0
# 530:	 short_desc_emb_63 - 0.0
# 531:	 short_desc_emb_64 - 0.0
# 532:	 short_desc_emb_65 - 0.0
# 533:	 short_desc_emb_67 - 0.0
# 534:	 short_desc_emb_68 - 0.0
# 535:	 short_desc_emb_69 - 0.0
# 536:	 short_desc_emb_70 - 0.0
# 537:	 short_desc_emb_71 - 0.0
# 538:	 short_desc_emb_73 - 0.0
# 539:	 short_desc_emb_74 - 0.0
# 540:	 short_desc_emb_75 - 0.0
# 541:	 short_desc_emb_76 - 0.0
# 542:	 short_desc_emb_78 - 0.0
# 543:	 short_desc_emb_79 - 0.0
# 544:	 short_desc_emb_80 - 0.0
# 545:	 short_desc_emb_81 - 0.0
# 546:	 short_desc_emb_82 - 0.0
# 547:	 short_desc_emb_83 - 0.0
# 548:	 short_desc_emb_85 - 0.0
# 549:	 short_desc_emb_86 - 0.0
# 550:	 short_desc_emb_87 - 0.0
# 551:	 short_desc_emb_88 - 0.0
# 552:	 short_desc_emb_89 - 0.0
# 553:	 short_desc_emb_90 - 0.0
# 554:	 short_desc_emb_91 - 0.0
# 555:	 short_desc_emb_92 - 0.0
# 556:	 short_desc_emb_93 - 0.0
# 557:	 short_desc_emb_95 - 0.0
# 558:	 short_desc_emb_96 - 0.0
# 559:	 short_desc_emb_97 - 0.0
# 560:	 short_desc_emb_98 - 0.0
# 561:	 short_desc_emb_99 - 0.0
# 562:	 short_desc_emb_100 - 0.0
# 563:	 short_desc_emb_101 - 0.0
# 564:	 short_desc_emb_102 - 0.0
# 565:	 short_desc_emb_103 - 0.0
# 566:	 short_desc_emb_104 - 0.0
# 567:	 short_desc_emb_105 - 0.0
# 568:	 short_desc_emb_106 - 0.0
# 569:	 short_desc_emb_107 - 0.0
# 570:	 short_desc_emb_108 - 0.0
# 571:	 short_desc_emb_109 - 0.0
# 572:	 short_desc_emb_110 - 0.0
# 573:	 short_desc_emb_111 - 0.0
# 574:	 short_desc_emb_112 - 0.0
# 575:	 short_desc_emb_115 - 0.0
# 576:	 short_desc_emb_116 - 0.0
# 577:	 short_desc_emb_117 - 0.0
# 578:	 short_desc_emb_118 - 0.0
# 579:	 short_desc_emb_119 - 0.0
# 580:	 short_desc_emb_120 - 0.0
# 581:	 short_desc_emb_121 - 0.0
# 582:	 short_desc_emb_122 - 0.0
# 583:	 short_desc_emb_123 - 0.0
# 584:	 short_desc_emb_124 - 0.0
# 585:	 short_desc_emb_125 - 0.0
# 586:	 short_desc_emb_126 - 0.0
# 587:	 short_desc_emb_127 - 0.0
# 588:	 short_desc_emb_128 - 0.0
# 589:	 short_desc_emb_129 - 0.0
# 590:	 short_desc_emb_130 - 0.0
# 591:	 short_desc_emb_131 - 0.0
# 592:	 short_desc_emb_132 - 0.0
# 593:	 short_desc_emb_133 - 0.0
# 594:	 short_desc_emb_134 - 0.0
# 595:	 short_desc_emb_135 - 0.0
# 596:	 short_desc_emb_136 - 0.0
# 597:	 short_desc_emb_138 - 0.0
# 598:	 short_desc_emb_139 - 0.0
# 599:	 short_desc_emb_140 - 0.0
# 600:	 short_desc_emb_141 - 0.0
# 601:	 short_desc_emb_142 - 0.0
# 602:	 short_desc_emb_143 - 0.0
# 603:	 short_desc_emb_144 - 0.0
# 604:	 short_desc_emb_145 - 0.0
# 605:	 short_desc_emb_146 - 0.0
# 606:	 short_desc_emb_147 - 0.0
# 607:	 short_desc_emb_148 - 0.0
# 608:	 short_desc_emb_149 - 0.0
# 609:	 short_desc_emb_150 - 0.0
# 610:	 short_desc_emb_151 - 0.0
# 611:	 short_desc_emb_152 - 0.0
# 612:	 short_desc_emb_154 - 0.0
# 613:	 short_desc_emb_155 - 0.0
# 614:	 short_desc_emb_156 - 0.0
# 615:	 short_desc_emb_158 - 0.0
# 616:	 short_desc_emb_159 - 0.0
# 617:	 short_desc_emb_160 - 0.0
# 618:	 short_desc_emb_161 - 0.0
# 619:	 short_desc_emb_162 - 0.0
# 620:	 short_desc_emb_163 - 0.0
# 621:	 short_desc_emb_164 - 0.0
# 622:	 short_desc_emb_165 - 0.0
# 623:	 short_desc_emb_166 - 0.0
# 624:	 short_desc_emb_167 - 0.0
# 625:	 short_desc_emb_168 - 0.0
# 626:	 short_desc_emb_169 - 0.0
# 627:	 short_desc_emb_170 - 0.0
# 628:	 short_desc_emb_171 - 0.0
# 629:	 short_desc_emb_172 - 0.0
# 630:	 short_desc_emb_173 - 0.0
# 631:	 short_desc_emb_174 - 0.0
# 632:	 short_desc_emb_176 - 0.0
# 633:	 short_desc_emb_177 - 0.0
# 634:	 short_desc_emb_178 - 0.0
# 635:	 short_desc_emb_179 - 0.0
# 636:	 short_desc_emb_180 - 0.0
# 637:	 short_desc_emb_181 - 0.0
# 638:	 short_desc_emb_183 - 0.0
# 639:	 short_desc_emb_184 - 0.0
# 640:	 short_desc_emb_185 - 0.0
# 641:	 short_desc_emb_187 - 0.0
# 642:	 short_desc_emb_188 - 0.0
# 643:	 short_desc_emb_189 - 0.0
# 644:	 short_desc_emb_191 - 0.0
# 645:	 short_desc_emb_192 - 0.0
# 646:	 short_desc_emb_193 - 0.0
# 647:	 short_desc_emb_194 - 0.0
# 648:	 short_desc_emb_195 - 0.0
# 649:	 short_desc_emb_197 - 0.0
# 650:	 short_desc_emb_198 - 0.0
# 651:	 short_desc_emb_199 - 0.0
# 652:	 short_desc_emb_200 - 0.0
# 653:	 short_desc_emb_201 - 0.0
# 654:	 short_desc_emb_202 - 0.0
# 655:	 short_desc_emb_203 - 0.0
# 656:	 short_desc_emb_204 - 0.0
# 657:	 short_desc_emb_205 - 0.0
# 658:	 short_desc_emb_206 - 0.0
# 659:	 short_desc_emb_207 - 0.0
# 660:	 short_desc_emb_208 - 0.0
# 661:	 short_desc_emb_209 - 0.0
# 662:	 short_desc_emb_212 - 0.0
# 663:	 short_desc_emb_214 - 0.0
# 664:	 short_desc_emb_215 - 0.0
# 665:	 short_desc_emb_216 - 0.0
# 666:	 short_desc_emb_217 - 0.0
# 667:	 short_desc_emb_218 - 0.0
# 668:	 short_desc_emb_219 - 0.0
# 669:	 short_desc_emb_220 - 0.0
# 670:	 short_desc_emb_221 - 0.0
# 671:	 short_desc_emb_222 - 0.0
# 672:	 short_desc_emb_223 - 0.0
# 673:	 short_desc_emb_224 - 0.0
# 674:	 short_desc_emb_225 - 0.0
# 675:	 short_desc_emb_226 - 0.0
# 676:	 short_desc_emb_227 - 0.0
# 677:	 short_desc_emb_228 - 0.0
# 678:	 short_desc_emb_229 - 0.0
# 679:	 short_desc_emb_230 - 0.0
# 680:	 short_desc_emb_231 - 0.0
# 681:	 short_desc_emb_232 - 0.0
# 682:	 short_desc_emb_233 - 0.0
# 683:	 short_desc_emb_234 - 0.0
# 684:	 short_desc_emb_236 - 0.0
# 685:	 short_desc_emb_237 - 0.0
# 686:	 short_desc_emb_238 - 0.0
# 687:	 short_desc_emb_240 - 0.0
# 688:	 short_desc_emb_241 - 0.0
# 689:	 short_desc_emb_242 - 0.0
# 690:	 short_desc_emb_243 - 0.0
# 691:	 short_desc_emb_244 - 0.0
# 692:	 short_desc_emb_245 - 0.0
# 693:	 short_desc_emb_246 - 0.0
# 694:	 short_desc_emb_247 - 0.0
# 695:	 short_desc_emb_248 - 0.0
# 696:	 short_desc_emb_249 - 0.0
# 697:	 short_desc_emb_250 - 0.0
# 698:	 short_desc_emb_251 - 0.0
# 699:	 short_desc_emb_252 - 0.0
# 700:	 short_desc_emb_253 - 0.0
# 701:	 short_desc_emb_254 - 0.0
# 702:	 short_desc_emb_255 - 0.0
# 703:	 short_desc_emb_256 - 0.0
# 704:	 short_desc_emb_257 - 0.0
# 705:	 short_desc_emb_258 - 0.0
# 706:	 short_desc_emb_259 - 0.0
# 707:	 short_desc_emb_260 - 0.0
# 708:	 short_desc_emb_261 - 0.0
# 709:	 short_desc_emb_262 - 0.0
# 710:	 short_desc_emb_263 - 0.0
# 711:	 short_desc_emb_264 - 0.0
# 712:	 short_desc_emb_265 - 0.0
# 713:	 short_desc_emb_266 - 0.0
# 714:	 short_desc_emb_267 - 0.0
# 715:	 short_desc_emb_268 - 0.0
# 716:	 short_desc_emb_269 - 0.0
# 717:	 short_desc_emb_271 - 0.0
# 718:	 short_desc_emb_272 - 0.0
# 719:	 short_desc_emb_275 - 0.0
# 720:	 short_desc_emb_276 - 0.0
# 721:	 short_desc_emb_277 - 0.0
# 722:	 short_desc_emb_278 - 0.0
# 723:	 short_desc_emb_279 - 0.0
# 724:	 short_desc_emb_280 - 0.0
# 725:	 short_desc_emb_282 - 0.0
# 726:	 short_desc_emb_283 - 0.0
# 727:	 short_desc_emb_284 - 0.0
# 728:	 short_desc_emb_285 - 0.0
# 729:	 short_desc_emb_286 - 0.0
# 730:	 short_desc_emb_287 - 0.0
# 731:	 short_desc_emb_288 - 0.0
# 732:	 short_desc_emb_289 - 0.0
# 733:	 short_desc_emb_290 - 0.0
# 734:	 short_desc_emb_291 - 0.0
# 735:	 short_desc_emb_293 - 0.0
# 736:	 short_desc_emb_294 - 0.0
# 737:	 short_desc_emb_295 - 0.0
# 738:	 short_desc_emb_296 - 0.0
# 739:	 short_desc_emb_297 - 0.0
# 740:	 short_desc_emb_298 - 0.0
# 741:	 short_desc_emb_300 - 0.0
# 742:	 short_desc_emb_301 - 0.0
# 743:	 short_desc_emb_302 - 0.0
# 744:	 short_desc_emb_303 - 0.0
# 745:	 short_desc_emb_304 - 0.0
# 746:	 short_desc_emb_305 - 0.0
# 747:	 short_desc_emb_307 - 0.0
# 748:	 short_desc_emb_308 - 0.0
# 749:	 short_desc_emb_310 - 0.0
# 750:	 short_desc_emb_311 - 0.0
# 751:	 short_desc_emb_312 - 0.0
# 752:	 short_desc_emb_313 - 0.0
# 753:	 short_desc_emb_314 - 0.0
# 754:	 short_desc_emb_315 - 0.0
# 755:	 short_desc_emb_316 - 0.0
# 756:	 short_desc_emb_317 - 0.0
# 757:	 short_desc_emb_318 - 0.0
# 758:	 short_desc_emb_319 - 0.0
# 759:	 short_desc_emb_320 - 0.0
# 760:	 short_desc_emb_321 - 0.0
# 761:	 short_desc_emb_322 - 0.0
# 762:	 short_desc_emb_323 - 0.0
# 763:	 short_desc_emb_324 - 0.0
# 764:	 short_desc_emb_325 - 0.0
# 765:	 short_desc_emb_327 - 0.0
# 766:	 short_desc_emb_330 - 0.0
# 767:	 short_desc_emb_331 - 0.0
# 768:	 short_desc_emb_332 - 0.0
# 769:	 short_desc_emb_334 - 0.0
# 770:	 short_desc_emb_335 - 0.0
# 771:	 short_desc_emb_338 - 0.0
# 772:	 short_desc_emb_339 - 0.0
# 773:	 short_desc_emb_341 - 0.0
# 774:	 short_desc_emb_342 - 0.0
# 775:	 short_desc_emb_343 - 0.0
# 776:	 short_desc_emb_344 - 0.0
# 777:	 short_desc_emb_345 - 0.0
# 778:	 short_desc_emb_346 - 0.0
# 779:	 short_desc_emb_347 - 0.0
# 780:	 short_desc_emb_348 - 0.0
# 781:	 short_desc_emb_349 - 0.0
# 782:	 short_desc_emb_350 - 0.0
# 783:	 short_desc_emb_351 - 0.0
# 784:	 short_desc_emb_352 - 0.0
# 785:	 short_desc_emb_353 - 0.0
# 786:	 short_desc_emb_354 - 0.0
# 787:	 short_desc_emb_355 - 0.0
# 788:	 short_desc_emb_356 - 0.0
# 789:	 short_desc_emb_357 - 0.0
# 790:	 short_desc_emb_358 - 0.0
# 791:	 short_desc_emb_359 - 0.0
# 792:	 short_desc_emb_360 - 0.0
# 793:	 short_desc_emb_362 - 0.0
# 794:	 short_desc_emb_363 - 0.0
# 795:	 short_desc_emb_364 - 0.0
# 796:	 short_desc_emb_365 - 0.0
# 797:	 short_desc_emb_366 - 0.0
# 798:	 short_desc_emb_367 - 0.0
# 799:	 short_desc_emb_368 - 0.0
# 800:	 short_desc_emb_369 - 0.0
# 801:	 short_desc_emb_370 - 0.0
# 802:	 short_desc_emb_371 - 0.0
# 803:	 short_desc_emb_372 - 0.0
# 804:	 short_desc_emb_373 - 0.0
# 805:	 short_desc_emb_374 - 0.0
# 806:	 short_desc_emb_376 - 0.0
# 807:	 short_desc_emb_377 - 0.0
# 808:	 short_desc_emb_378 - 0.0
# 809:	 short_desc_emb_379 - 0.0
# 810:	 short_desc_emb_380 - 0.0
# 811:	 short_desc_emb_383 - 0.0
# 812:	 long_desc_emb_0 - 0.0
# 813:	 long_desc_emb_1 - 0.0
# 814:	 long_desc_emb_2 - 0.0
# 815:	 long_desc_emb_3 - 0.0
# 816:	 long_desc_emb_4 - 0.0
# 817:	 long_desc_emb_5 - 0.0
# 818:	 long_desc_emb_6 - 0.0
# 819:	 long_desc_emb_7 - 0.0
# 820:	 long_desc_emb_8 - 0.0
# 821:	 long_desc_emb_9 - 0.0
# 822:	 long_desc_emb_10 - 0.0
# 823:	 long_desc_emb_11 - 0.0
# 824:	 long_desc_emb_12 - 0.0
# 825:	 long_desc_emb_13 - 0.0
# 826:	 long_desc_emb_14 - 0.0
# 827:	 long_desc_emb_15 - 0.0
# 828:	 long_desc_emb_16 - 0.0
# 829:	 long_desc_emb_17 - 0.0
# 830:	 long_desc_emb_18 - 0.0
# 831:	 long_desc_emb_19 - 0.0
# 832:	 long_desc_emb_20 - 0.0
# 833:	 long_desc_emb_21 - 0.0
# 834:	 long_desc_emb_22 - 0.0
# 835:	 long_desc_emb_23 - 0.0
# 836:	 long_desc_emb_24 - 0.0
# 837:	 long_desc_emb_25 - 0.0
# 838:	 long_desc_emb_26 - 0.0
# 839:	 long_desc_emb_27 - 0.0
# 840:	 long_desc_emb_28 - 0.0
# 841:	 long_desc_emb_29 - 0.0
# 842:	 long_desc_emb_30 - 0.0
# 843:	 long_desc_emb_31 - 0.0
# 844:	 long_desc_emb_32 - 0.0
# 845:	 long_desc_emb_33 - 0.0
# 846:	 long_desc_emb_34 - 0.0
# 847:	 long_desc_emb_35 - 0.0
# 848:	 long_desc_emb_36 - 0.0
# 849:	 long_desc_emb_37 - 0.0
# 850:	 long_desc_emb_38 - 0.0
# 851:	 long_desc_emb_39 - 0.0
# 852:	 long_desc_emb_40 - 0.0
# 853:	 long_desc_emb_41 - 0.0
# 854:	 long_desc_emb_42 - 0.0
# 855:	 long_desc_emb_43 - 0.0
# 856:	 long_desc_emb_44 - 0.0
# 857:	 long_desc_emb_45 - 0.0
# 858:	 long_desc_emb_46 - 0.0
# 859:	 long_desc_emb_47 - 0.0
# 860:	 long_desc_emb_48 - 0.0
# 861:	 long_desc_emb_49 - 0.0
# 862:	 long_desc_emb_50 - 0.0
# 863:	 long_desc_emb_51 - 0.0
# 864:	 long_desc_emb_52 - 0.0
# 865:	 long_desc_emb_53 - 0.0
# 866:	 long_desc_emb_54 - 0.0
# 867:	 long_desc_emb_55 - 0.0
# 868:	 long_desc_emb_56 - 0.0
# 869:	 long_desc_emb_57 - 0.0
# 870:	 long_desc_emb_58 - 0.0
# 871:	 long_desc_emb_59 - 0.0
# 872:	 long_desc_emb_60 - 0.0
# 873:	 long_desc_emb_61 - 0.0
# 874:	 long_desc_emb_62 - 0.0
# 875:	 long_desc_emb_63 - 0.0
# 876:	 long_desc_emb_64 - 0.0
# 877:	 long_desc_emb_65 - 0.0
# 878:	 long_desc_emb_66 - 0.0
# 879:	 long_desc_emb_67 - 0.0
# 880:	 long_desc_emb_68 - 0.0
# 881:	 long_desc_emb_69 - 0.0
# 882:	 long_desc_emb_70 - 0.0
# 883:	 long_desc_emb_71 - 0.0
# 884:	 long_desc_emb_72 - 0.0
# 885:	 long_desc_emb_73 - 0.0
# 886:	 long_desc_emb_74 - 0.0
# 887:	 long_desc_emb_75 - 0.0
# 888:	 long_desc_emb_76 - 0.0
# 889:	 long_desc_emb_77 - 0.0
# 890:	 long_desc_emb_78 - 0.0
# 891:	 long_desc_emb_79 - 0.0
# 892:	 long_desc_emb_80 - 0.0
# 893:	 long_desc_emb_81 - 0.0
# 894:	 long_desc_emb_82 - 0.0
# 895:	 long_desc_emb_83 - 0.0
# 896:	 long_desc_emb_84 - 0.0
# 897:	 long_desc_emb_85 - 0.0
# 898:	 long_desc_emb_86 - 0.0
# 899:	 long_desc_emb_87 - 0.0
# 900:	 long_desc_emb_88 - 0.0
# 901:	 long_desc_emb_89 - 0.0
# 902:	 long_desc_emb_90 - 0.0
# 903:	 long_desc_emb_91 - 0.0
# 904:	 long_desc_emb_92 - 0.0
# 905:	 long_desc_emb_93 - 0.0
# 906:	 long_desc_emb_94 - 0.0
# 907:	 long_desc_emb_95 - 0.0
# 908:	 long_desc_emb_96 - 0.0
# 909:	 long_desc_emb_97 - 0.0
# 910:	 long_desc_emb_98 - 0.0
# 911:	 long_desc_emb_99 - 0.0
# 912:	 long_desc_emb_100 - 0.0
# 913:	 long_desc_emb_101 - 0.0
# 914:	 long_desc_emb_102 - 0.0
# 915:	 long_desc_emb_103 - 0.0
# 916:	 long_desc_emb_104 - 0.0
# 917:	 long_desc_emb_105 - 0.0
# 918:	 long_desc_emb_106 - 0.0
# 919:	 long_desc_emb_107 - 0.0
# 920:	 long_desc_emb_108 - 0.0
# 921:	 long_desc_emb_109 - 0.0
# 922:	 long_desc_emb_110 - 0.0
# 923:	 long_desc_emb_111 - 0.0
# 924:	 long_desc_emb_112 - 0.0
# 925:	 long_desc_emb_113 - 0.0
# 926:	 long_desc_emb_114 - 0.0
# 927:	 long_desc_emb_115 - 0.0
# 928:	 long_desc_emb_116 - 0.0
# 929:	 long_desc_emb_117 - 0.0
# 930:	 long_desc_emb_118 - 0.0
# 931:	 long_desc_emb_119 - 0.0
# 932:	 long_desc_emb_120 - 0.0
# 933:	 long_desc_emb_121 - 0.0
# 934:	 long_desc_emb_122 - 0.0
# 935:	 long_desc_emb_123 - 0.0
# 936:	 long_desc_emb_124 - 0.0
# 937:	 long_desc_emb_125 - 0.0
# 938:	 long_desc_emb_126 - 0.0
# 939:	 long_desc_emb_127 - 0.0
# 940:	 long_desc_emb_128 - 0.0
# 941:	 long_desc_emb_129 - 0.0
# 942:	 long_desc_emb_130 - 0.0
# 943:	 long_desc_emb_131 - 0.0
# 944:	 long_desc_emb_132 - 0.0
# 945:	 long_desc_emb_133 - 0.0
# 946:	 long_desc_emb_134 - 0.0
# 947:	 long_desc_emb_135 - 0.0
# 948:	 long_desc_emb_136 - 0.0
# 949:	 long_desc_emb_137 - 0.0
# 950:	 long_desc_emb_138 - 0.0
# 951:	 long_desc_emb_139 - 0.0
# 952:	 long_desc_emb_140 - 0.0
# 953:	 long_desc_emb_141 - 0.0
# 954:	 long_desc_emb_142 - 0.0
# 955:	 long_desc_emb_143 - 0.0
# 956:	 long_desc_emb_144 - 0.0
# 957:	 long_desc_emb_145 - 0.0
# 958:	 long_desc_emb_146 - 0.0
# 959:	 long_desc_emb_147 - 0.0
# 960:	 long_desc_emb_148 - 0.0
# 961:	 long_desc_emb_149 - 0.0
# 962:	 long_desc_emb_150 - 0.0
# 963:	 long_desc_emb_151 - 0.0
# 964:	 long_desc_emb_152 - 0.0
# 965:	 long_desc_emb_153 - 0.0
# 966:	 long_desc_emb_154 - 0.0
# 967:	 long_desc_emb_155 - 0.0
# 968:	 long_desc_emb_156 - 0.0
# 969:	 long_desc_emb_157 - 0.0
# 970:	 long_desc_emb_158 - 0.0
# 971:	 long_desc_emb_159 - 0.0
# 972:	 long_desc_emb_160 - 0.0
# 973:	 long_desc_emb_161 - 0.0
# 974:	 long_desc_emb_162 - 0.0
# 975:	 long_desc_emb_163 - 0.0
# 976:	 long_desc_emb_164 - 0.0
# 977:	 long_desc_emb_165 - 0.0
# 978:	 long_desc_emb_166 - 0.0
# 979:	 long_desc_emb_167 - 0.0
# 980:	 long_desc_emb_168 - 0.0
# 981:	 long_desc_emb_169 - 0.0
# 982:	 long_desc_emb_170 - 0.0
# 983:	 long_desc_emb_171 - 0.0
# 984:	 long_desc_emb_172 - 0.0
# 985:	 long_desc_emb_173 - 0.0
# 986:	 long_desc_emb_174 - 0.0
# 987:	 long_desc_emb_175 - 0.0
# 988:	 long_desc_emb_176 - 0.0
# 989:	 long_desc_emb_177 - 0.0
# 990:	 long_desc_emb_178 - 0.0
# 991:	 long_desc_emb_179 - 0.0
# 992:	 long_desc_emb_180 - 0.0
# 993:	 long_desc_emb_181 - 0.0
# 994:	 long_desc_emb_182 - 0.0
# 995:	 long_desc_emb_183 - 0.0
# 996:	 long_desc_emb_184 - 0.0
# 997:	 long_desc_emb_185 - 0.0
# 998:	 long_desc_emb_186 - 0.0
# 999:	 long_desc_emb_187 - 0.0
# 1000:	 long_desc_emb_188 - 0.0
# 1001:	 long_desc_emb_189 - 0.0
# 1002:	 long_desc_emb_190 - 0.0
# 1003:	 long_desc_emb_191 - 0.0
# 1004:	 long_desc_emb_192 - 0.0
# 1005:	 long_desc_emb_193 - 0.0
# 1006:	 long_desc_emb_194 - 0.0
# 1007:	 long_desc_emb_195 - 0.0
# 1008:	 long_desc_emb_196 - 0.0
# 1009:	 long_desc_emb_197 - 0.0
# 1010:	 long_desc_emb_198 - 0.0
# 1011:	 long_desc_emb_199 - 0.0
# 1012:	 long_desc_emb_200 - 0.0
# 1013:	 long_desc_emb_201 - 0.0
# 1014:	 long_desc_emb_202 - 0.0
# 1015:	 long_desc_emb_203 - 0.0
# 1016:	 long_desc_emb_204 - 0.0
# 1017:	 long_desc_emb_205 - 0.0
# 1018:	 long_desc_emb_206 - 0.0
# 1019:	 long_desc_emb_207 - 0.0
# 1020:	 long_desc_emb_208 - 0.0
# 1021:	 long_desc_emb_209 - 0.0
# 1022:	 long_desc_emb_210 - 0.0
# 1023:	 long_desc_emb_211 - 0.0
# 1024:	 long_desc_emb_212 - 0.0
# 1025:	 long_desc_emb_213 - 0.0
# 1026:	 long_desc_emb_214 - 0.0
# 1027:	 long_desc_emb_215 - 0.0
# 1028:	 long_desc_emb_216 - 0.0
# 1029:	 long_desc_emb_217 - 0.0
# 1030:	 long_desc_emb_218 - 0.0
# 1031:	 long_desc_emb_219 - 0.0
# 1032:	 long_desc_emb_220 - 0.0
# 1033:	 long_desc_emb_221 - 0.0
# 1034:	 long_desc_emb_222 - 0.0
# 1035:	 long_desc_emb_223 - 0.0
# 1036:	 long_desc_emb_224 - 0.0
# 1037:	 long_desc_emb_225 - 0.0
# 1038:	 long_desc_emb_226 - 0.0
# 1039:	 long_desc_emb_227 - 0.0
# 1040:	 long_desc_emb_228 - 0.0
# 1041:	 long_desc_emb_229 - 0.0
# 1042:	 long_desc_emb_230 - 0.0
# 1043:	 long_desc_emb_231 - 0.0
# 1044:	 long_desc_emb_232 - 0.0
# 1045:	 long_desc_emb_233 - 0.0
# 1046:	 long_desc_emb_234 - 0.0
# 1047:	 long_desc_emb_235 - 0.0
# 1048:	 long_desc_emb_236 - 0.0
# 1049:	 long_desc_emb_237 - 0.0
# 1050:	 long_desc_emb_238 - 0.0
# 1051:	 long_desc_emb_239 - 0.0
# 1052:	 long_desc_emb_240 - 0.0
# 1053:	 long_desc_emb_241 - 0.0
# 1054:	 long_desc_emb_242 - 0.0
# 1055:	 long_desc_emb_243 - 0.0
# 1056:	 long_desc_emb_244 - 0.0
# 1057:	 long_desc_emb_245 - 0.0
# 1058:	 long_desc_emb_246 - 0.0
# 1059:	 long_desc_emb_247 - 0.0
# 1060:	 long_desc_emb_248 - 0.0
# 1061:	 long_desc_emb_249 - 0.0
# 1062:	 long_desc_emb_250 - 0.0
# 1063:	 long_desc_emb_251 - 0.0
# 1064:	 long_desc_emb_252 - 0.0
# 1065:	 long_desc_emb_253 - 0.0
# 1066:	 long_desc_emb_254 - 0.0
# 1067:	 long_desc_emb_255 - 0.0
# 1068:	 long_desc_emb_256 - 0.0
# 1069:	 long_desc_emb_257 - 0.0
# 1070:	 long_desc_emb_258 - 0.0
# 1071:	 long_desc_emb_259 - 0.0
# 1072:	 long_desc_emb_260 - 0.0
# 1073:	 long_desc_emb_261 - 0.0
# 1074:	 long_desc_emb_262 - 0.0
# 1075:	 long_desc_emb_263 - 0.0
# 1076:	 long_desc_emb_264 - 0.0
# 1077:	 long_desc_emb_265 - 0.0
# 1078:	 long_desc_emb_266 - 0.0
# 1079:	 long_desc_emb_267 - 0.0
# 1080:	 long_desc_emb_268 - 0.0
# 1081:	 long_desc_emb_269 - 0.0
# 1082:	 long_desc_emb_270 - 0.0
# 1083:	 long_desc_emb_271 - 0.0
# 1084:	 long_desc_emb_272 - 0.0
# 1085:	 long_desc_emb_273 - 0.0
# 1086:	 long_desc_emb_274 - 0.0
# 1087:	 long_desc_emb_275 - 0.0
# 1088:	 long_desc_emb_276 - 0.0
# 1089:	 long_desc_emb_277 - 0.0
# 1090:	 long_desc_emb_278 - 0.0
# 1091:	 long_desc_emb_279 - 0.0
# 1092:	 long_desc_emb_280 - 0.0
# 1093:	 long_desc_emb_281 - 0.0
# 1094:	 long_desc_emb_282 - 0.0
# 1095:	 long_desc_emb_283 - 0.0
# 1096:	 long_desc_emb_284 - 0.0
# 1097:	 long_desc_emb_285 - 0.0
# 1098:	 long_desc_emb_286 - 0.0
# 1099:	 long_desc_emb_287 - 0.0
# 1100:	 long_desc_emb_288 - 0.0
# 1101:	 long_desc_emb_289 - 0.0
# 1102:	 long_desc_emb_290 - 0.0
# 1103:	 long_desc_emb_291 - 0.0
# 1104:	 long_desc_emb_292 - 0.0
# 1105:	 long_desc_emb_293 - 0.0
# 1106:	 long_desc_emb_294 - 0.0
# 1107:	 long_desc_emb_295 - 0.0
# 1108:	 long_desc_emb_296 - 0.0
# 1109:	 long_desc_emb_297 - 0.0
# 1110:	 long_desc_emb_298 - 0.0
# 1111:	 long_desc_emb_299 - 0.0
# 1112:	 long_desc_emb_300 - 0.0
# 1113:	 long_desc_emb_301 - 0.0
# 1114:	 long_desc_emb_302 - 0.0
# 1115:	 long_desc_emb_303 - 0.0
# 1116:	 long_desc_emb_304 - 0.0
# 1117:	 long_desc_emb_305 - 0.0
# 1118:	 long_desc_emb_306 - 0.0
# 1119:	 long_desc_emb_307 - 0.0
# 1120:	 long_desc_emb_308 - 0.0
# 1121:	 long_desc_emb_309 - 0.0
# 1122:	 long_desc_emb_310 - 0.0
# 1123:	 long_desc_emb_311 - 0.0
# 1124:	 long_desc_emb_312 - 0.0
# 1125:	 long_desc_emb_313 - 0.0
# 1126:	 long_desc_emb_314 - 0.0
# 1127:	 long_desc_emb_315 - 0.0
# 1128:	 long_desc_emb_316 - 0.0
# 1129:	 long_desc_emb_317 - 0.0
# 1130:	 long_desc_emb_318 - 0.0
# 1131:	 long_desc_emb_319 - 0.0
# 1132:	 long_desc_emb_320 - 0.0
# 1133:	 long_desc_emb_321 - 0.0
# 1134:	 long_desc_emb_322 - 0.0
# 1135:	 long_desc_emb_323 - 0.0
# 1136:	 long_desc_emb_324 - 0.0
# 1137:	 long_desc_emb_325 - 0.0
# 1138:	 long_desc_emb_326 - 0.0
# 1139:	 long_desc_emb_327 - 0.0
# 1140:	 long_desc_emb_328 - 0.0
# 1141:	 long_desc_emb_329 - 0.0
# 1142:	 long_desc_emb_330 - 0.0
# 1143:	 long_desc_emb_331 - 0.0
# 1144:	 long_desc_emb_332 - 0.0
# 1145:	 long_desc_emb_333 - 0.0
# 1146:	 long_desc_emb_334 - 0.0
# 1147:	 long_desc_emb_335 - 0.0
# 1148:	 long_desc_emb_336 - 0.0
# 1149:	 long_desc_emb_337 - 0.0
# 1150:	 long_desc_emb_338 - 0.0
# 1151:	 long_desc_emb_339 - 0.0
# 1152:	 long_desc_emb_340 - 0.0
# 1153:	 long_desc_emb_341 - 0.0
# 1154:	 long_desc_emb_342 - 0.0
# 1155:	 long_desc_emb_343 - 0.0
# 1156:	 long_desc_emb_344 - 0.0
# 1157:	 long_desc_emb_345 - 0.0
# 1158:	 long_desc_emb_346 - 0.0
# 1159:	 long_desc_emb_347 - 0.0
# 1160:	 long_desc_emb_348 - 0.0
# 1161:	 long_desc_emb_349 - 0.0
# 1162:	 long_desc_emb_350 - 0.0
# 1163:	 long_desc_emb_351 - 0.0
# 1164:	 long_desc_emb_352 - 0.0
# 1165:	 long_desc_emb_353 - 0.0
# 1166:	 long_desc_emb_354 - 0.0
# 1167:	 long_desc_emb_355 - 0.0
# 1168:	 long_desc_emb_356 - 0.0
# 1169:	 long_desc_emb_357 - 0.0
# 1170:	 long_desc_emb_358 - 0.0
# 1171:	 long_desc_emb_359 - 0.0
# 1172:	 long_desc_emb_360 - 0.0
# 1173:	 long_desc_emb_361 - 0.0
# 1174:	 long_desc_emb_362 - 0.0
# 1175:	 long_desc_emb_363 - 0.0
# 1176:	 long_desc_emb_364 - 0.0
# 1177:	 long_desc_emb_365 - 0.0
# 1178:	 long_desc_emb_366 - 0.0
# 1179:	 long_desc_emb_367 - 0.0
# 1180:	 long_desc_emb_368 - 0.0
# 1181:	 long_desc_emb_369 - 0.0
# 1182:	 long_desc_emb_370 - 0.0
# 1183:	 long_desc_emb_371 - 0.0
# 1184:	 long_desc_emb_372 - 0.0
# 1185:	 long_desc_emb_373 - 0.0
# 1186:	 long_desc_emb_374 - 0.0
# 1187:	 long_desc_emb_375 - 0.0
# 1188:	 long_desc_emb_376 - 0.0
# 1189:	 long_desc_emb_377 - 0.0
# 1190:	 long_desc_emb_378 - 0.0
# 1191:	 long_desc_emb_379 - 0.0
# 1192:	 long_desc_emb_380 - 0.0
# 1193:	 long_desc_emb_381 - 0.0
# 1194:	 long_desc_emb_382 - 0.0
# 1195:	 long_desc_emb_383 - 0.0
# 1196:	 tags_emb_0 - 0.0
# 1197:	 tags_emb_1 - 0.0
# 1198:	 tags_emb_3 - 0.0
# 1199:	 tags_emb_4 - 0.0
# 1200:	 tags_emb_7 - 0.0
# 1201:	 tags_emb_8 - 0.0
# 1202:	 tags_emb_9 - 0.0
# 1203:	 tags_emb_10 - 0.0
# 1204:	 tags_emb_11 - 0.0
# 1205:	 tags_emb_12 - 0.0
# 1206:	 tags_emb_13 - 0.0
# 1207:	 tags_emb_14 - 0.0
# 1208:	 tags_emb_15 - 0.0
# 1209:	 tags_emb_16 - 0.0
# 1210:	 tags_emb_17 - 0.0
# 1211:	 tags_emb_18 - 0.0
# 1212:	 tags_emb_19 - 0.0
# 1213:	 tags_emb_20 - 0.0
# 1214:	 tags_emb_21 - 0.0
# 1215:	 tags_emb_22 - 0.0
# 1216:	 tags_emb_23 - 0.0
# 1217:	 tags_emb_24 - 0.0
# 1218:	 tags_emb_25 - 0.0
# 1219:	 tags_emb_26 - 0.0
# 1220:	 tags_emb_27 - 0.0
# 1221:	 tags_emb_28 - 0.0
# 1222:	 tags_emb_29 - 0.0
# 1223:	 tags_emb_31 - 0.0
# 1224:	 tags_emb_32 - 0.0
# 1225:	 tags_emb_33 - 0.0
# 1226:	 tags_emb_34 - 0.0
# 1227:	 tags_emb_35 - 0.0
# 1228:	 tags_emb_36 - 0.0
# 1229:	 tags_emb_37 - 0.0
# 1230:	 tags_emb_38 - 0.0
# 1231:	 tags_emb_39 - 0.0
# 1232:	 tags_emb_40 - 0.0
# 1233:	 tags_emb_41 - 0.0
# 1234:	 tags_emb_42 - 0.0
# 1235:	 tags_emb_43 - 0.0
# 1236:	 tags_emb_44 - 0.0
# 1237:	 tags_emb_46 - 0.0
# 1238:	 tags_emb_47 - 0.0
# 1239:	 tags_emb_48 - 0.0
# 1240:	 tags_emb_49 - 0.0
# 1241:	 tags_emb_50 - 0.0
# 1242:	 tags_emb_51 - 0.0
# 1243:	 tags_emb_54 - 0.0
# 1244:	 tags_emb_55 - 0.0
# 1245:	 tags_emb_56 - 0.0
# 1246:	 tags_emb_57 - 0.0
# 1247:	 tags_emb_58 - 0.0
# 1248:	 tags_emb_59 - 0.0
# 1249:	 tags_emb_60 - 0.0
# 1250:	 tags_emb_61 - 0.0
# 1251:	 tags_emb_62 - 0.0
# 1252:	 tags_emb_63 - 0.0
# 1253:	 tags_emb_64 - 0.0
# 1254:	 tags_emb_65 - 0.0
# 1255:	 tags_emb_66 - 0.0
# 1256:	 tags_emb_67 - 0.0
# 1257:	 tags_emb_69 - 0.0
# 1258:	 tags_emb_70 - 0.0
# 1259:	 tags_emb_71 - 0.0
# 1260:	 tags_emb_72 - 0.0
# 1261:	 tags_emb_73 - 0.0
# 1262:	 tags_emb_75 - 0.0
# 1263:	 tags_emb_76 - 0.0
# 1264:	 tags_emb_77 - 0.0
# 1265:	 tags_emb_78 - 0.0
# 1266:	 tags_emb_81 - 0.0
# 1267:	 tags_emb_82 - 0.0
# 1268:	 tags_emb_85 - 0.0
# 1269:	 tags_emb_86 - 0.0
# 1270:	 tags_emb_87 - 0.0
# 1271:	 tags_emb_88 - 0.0
# 1272:	 tags_emb_89 - 0.0
# 1273:	 tags_emb_90 - 0.0
# 1274:	 tags_emb_91 - 0.0
# 1275:	 tags_emb_92 - 0.0
# 1276:	 tags_emb_93 - 0.0
# 1277:	 tags_emb_94 - 0.0
# 1278:	 tags_emb_95 - 0.0
# 1279:	 tags_emb_96 - 0.0
# 1280:	 tags_emb_97 - 0.0
# 1281:	 tags_emb_98 - 0.0
# 1282:	 tags_emb_99 - 0.0
# 1283:	 tags_emb_100 - 0.0
# 1284:	 tags_emb_101 - 0.0
# 1285:	 tags_emb_102 - 0.0
# 1286:	 tags_emb_103 - 0.0
# 1287:	 tags_emb_104 - 0.0
# 1288:	 tags_emb_105 - 0.0
# 1289:	 tags_emb_106 - 0.0
# 1290:	 tags_emb_107 - 0.0
# 1291:	 tags_emb_108 - 0.0
# 1292:	 tags_emb_109 - 0.0
# 1293:	 tags_emb_110 - 0.0
# 1294:	 tags_emb_111 - 0.0
# 1295:	 tags_emb_112 - 0.0
# 1296:	 tags_emb_113 - 0.0
# 1297:	 tags_emb_114 - 0.0
# 1298:	 tags_emb_115 - 0.0
# 1299:	 tags_emb_116 - 0.0
# 1300:	 tags_emb_117 - 0.0
# 1301:	 tags_emb_118 - 0.0
# 1302:	 tags_emb_119 - 0.0
# 1303:	 tags_emb_120 - 0.0
# 1304:	 tags_emb_121 - 0.0
# 1305:	 tags_emb_122 - 0.0
# 1306:	 tags_emb_123 - 0.0
# 1307:	 tags_emb_124 - 0.0
# 1308:	 tags_emb_125 - 0.0
# 1309:	 tags_emb_126 - 0.0
# 1310:	 tags_emb_127 - 0.0
# 1311:	 tags_emb_128 - 0.0
# 1312:	 tags_emb_129 - 0.0
# 1313:	 tags_emb_130 - 0.0
# 1314:	 tags_emb_131 - 0.0
# 1315:	 tags_emb_132 - 0.0
# 1316:	 tags_emb_133 - 0.0
# 1317:	 tags_emb_134 - 0.0
# 1318:	 tags_emb_135 - 0.0
# 1319:	 tags_emb_136 - 0.0
# 1320:	 tags_emb_137 - 0.0
# 1321:	 tags_emb_138 - 0.0
# 1322:	 tags_emb_139 - 0.0
# 1323:	 tags_emb_141 - 0.0
# 1324:	 tags_emb_142 - 0.0
# 1325:	 tags_emb_143 - 0.0
# 1326:	 tags_emb_144 - 0.0
# 1327:	 tags_emb_145 - 0.0
# 1328:	 tags_emb_147 - 0.0
# 1329:	 tags_emb_148 - 0.0
# 1330:	 tags_emb_149 - 0.0
# 1331:	 tags_emb_150 - 0.0
# 1332:	 tags_emb_152 - 0.0
# 1333:	 tags_emb_153 - 0.0
# 1334:	 tags_emb_154 - 0.0
# 1335:	 tags_emb_155 - 0.0
# 1336:	 tags_emb_156 - 0.0
# 1337:	 tags_emb_157 - 0.0
# 1338:	 tags_emb_158 - 0.0
# 1339:	 tags_emb_159 - 0.0
# 1340:	 tags_emb_160 - 0.0
# 1341:	 tags_emb_161 - 0.0
# 1342:	 tags_emb_163 - 0.0
# 1343:	 tags_emb_165 - 0.0
# 1344:	 tags_emb_166 - 0.0
# 1345:	 tags_emb_167 - 0.0
# 1346:	 tags_emb_168 - 0.0
# 1347:	 tags_emb_169 - 0.0
# 1348:	 tags_emb_170 - 0.0
# 1349:	 tags_emb_171 - 0.0
# 1350:	 tags_emb_172 - 0.0
# 1351:	 tags_emb_173 - 0.0
# 1352:	 tags_emb_174 - 0.0
# 1353:	 tags_emb_175 - 0.0
# 1354:	 tags_emb_176 - 0.0
# 1355:	 tags_emb_177 - 0.0
# 1356:	 tags_emb_178 - 0.0
# 1357:	 tags_emb_179 - 0.0
# 1358:	 tags_emb_180 - 0.0
# 1359:	 tags_emb_181 - 0.0
# 1360:	 tags_emb_182 - 0.0
# 1361:	 tags_emb_184 - 0.0
# 1362:	 tags_emb_185 - 0.0
# 1363:	 tags_emb_187 - 0.0
# 1364:	 tags_emb_188 - 0.0
# 1365:	 tags_emb_190 - 0.0
# 1366:	 tags_emb_191 - 0.0
# 1367:	 tags_emb_192 - 0.0
# 1368:	 tags_emb_193 - 0.0
# 1369:	 tags_emb_194 - 0.0
# 1370:	 tags_emb_195 - 0.0
# 1371:	 tags_emb_198 - 0.0
# 1372:	 tags_emb_201 - 0.0
# 1373:	 tags_emb_202 - 0.0
# 1374:	 tags_emb_203 - 0.0
# 1375:	 tags_emb_205 - 0.0
# 1376:	 tags_emb_207 - 0.0
# 1377:	 tags_emb_208 - 0.0
# 1378:	 tags_emb_209 - 0.0
# 1379:	 tags_emb_210 - 0.0
# 1380:	 tags_emb_211 - 0.0
# 1381:	 tags_emb_212 - 0.0
# 1382:	 tags_emb_213 - 0.0
# 1383:	 tags_emb_214 - 0.0
# 1384:	 tags_emb_216 - 0.0
# 1385:	 tags_emb_217 - 0.0
# 1386:	 tags_emb_218 - 0.0
# 1387:	 tags_emb_219 - 0.0
# 1388:	 tags_emb_220 - 0.0
# 1389:	 tags_emb_221 - 0.0
# 1390:	 tags_emb_222 - 0.0
# 1391:	 tags_emb_223 - 0.0
# 1392:	 tags_emb_224 - 0.0
# 1393:	 tags_emb_225 - 0.0
# 1394:	 tags_emb_226 - 0.0
# 1395:	 tags_emb_227 - 0.0
# 1396:	 tags_emb_228 - 0.0
# 1397:	 tags_emb_230 - 0.0
# 1398:	 tags_emb_231 - 0.0
# 1399:	 tags_emb_232 - 0.0
# 1400:	 tags_emb_233 - 0.0
# 1401:	 tags_emb_234 - 0.0
# 1402:	 tags_emb_235 - 0.0
# 1403:	 tags_emb_236 - 0.0
# 1404:	 tags_emb_238 - 0.0
# 1405:	 tags_emb_239 - 0.0
# 1406:	 tags_emb_240 - 0.0
# 1407:	 tags_emb_241 - 0.0
# 1408:	 tags_emb_242 - 0.0
# 1409:	 tags_emb_243 - 0.0
# 1410:	 tags_emb_244 - 0.0
# 1411:	 tags_emb_245 - 0.0
# 1412:	 tags_emb_246 - 0.0
# 1413:	 tags_emb_247 - 0.0
# 1414:	 tags_emb_248 - 0.0
# 1415:	 tags_emb_249 - 0.0
# 1416:	 tags_emb_250 - 0.0
# 1417:	 tags_emb_251 - 0.0
# 1418:	 tags_emb_253 - 0.0
# 1419:	 tags_emb_254 - 0.0
# 1420:	 tags_emb_255 - 0.0
# 1421:	 tags_emb_256 - 0.0
# 1422:	 tags_emb_257 - 0.0
# 1423:	 tags_emb_258 - 0.0
# 1424:	 tags_emb_259 - 0.0
# 1425:	 tags_emb_260 - 0.0
# 1426:	 tags_emb_261 - 0.0
# 1427:	 tags_emb_262 - 0.0
# 1428:	 tags_emb_263 - 0.0
# 1429:	 tags_emb_264 - 0.0
# 1430:	 tags_emb_265 - 0.0
# 1431:	 tags_emb_268 - 0.0
# 1432:	 tags_emb_269 - 0.0
# 1433:	 tags_emb_270 - 0.0
# 1434:	 tags_emb_271 - 0.0
# 1435:	 tags_emb_272 - 0.0
# 1436:	 tags_emb_273 - 0.0
# 1437:	 tags_emb_274 - 0.0
# 1438:	 tags_emb_275 - 0.0
# 1439:	 tags_emb_277 - 0.0
# 1440:	 tags_emb_278 - 0.0
# 1441:	 tags_emb_279 - 0.0
# 1442:	 tags_emb_280 - 0.0
# 1443:	 tags_emb_281 - 0.0
# 1444:	 tags_emb_282 - 0.0
# 1445:	 tags_emb_283 - 0.0
# 1446:	 tags_emb_284 - 0.0
# 1447:	 tags_emb_285 - 0.0
# 1448:	 tags_emb_286 - 0.0
# 1449:	 tags_emb_287 - 0.0
# 1450:	 tags_emb_288 - 0.0
# 1451:	 tags_emb_289 - 0.0
# 1452:	 tags_emb_290 - 0.0
# 1453:	 tags_emb_291 - 0.0
# 1454:	 tags_emb_292 - 0.0
# 1455:	 tags_emb_293 - 0.0
# 1456:	 tags_emb_294 - 0.0
# 1457:	 tags_emb_295 - 0.0
# 1458:	 tags_emb_296 - 0.0
# 1459:	 tags_emb_297 - 0.0
# 1460:	 tags_emb_298 - 0.0
# 1461:	 tags_emb_299 - 0.0
# 1462:	 tags_emb_300 - 0.0
# 1463:	 tags_emb_301 - 0.0
# 1464:	 tags_emb_302 - 0.0
# 1465:	 tags_emb_303 - 0.0
# 1466:	 tags_emb_304 - 0.0
# 1467:	 tags_emb_305 - 0.0
# 1468:	 tags_emb_306 - 0.0
# 1469:	 tags_emb_307 - 0.0
# 1470:	 tags_emb_308 - 0.0
# 1471:	 tags_emb_309 - 0.0
# 1472:	 tags_emb_310 - 0.0
# 1473:	 tags_emb_311 - 0.0
# 1474:	 tags_emb_313 - 0.0
# 1475:	 tags_emb_314 - 0.0
# 1476:	 tags_emb_315 - 0.0
# 1477:	 tags_emb_316 - 0.0
# 1478:	 tags_emb_317 - 0.0
# 1479:	 tags_emb_318 - 0.0
# 1480:	 tags_emb_319 - 0.0
# 1481:	 tags_emb_320 - 0.0
# 1482:	 tags_emb_321 - 0.0
# 1483:	 tags_emb_322 - 0.0
# 1484:	 tags_emb_323 - 0.0
# 1485:	 tags_emb_324 - 0.0
# 1486:	 tags_emb_325 - 0.0
# 1487:	 tags_emb_326 - 0.0
# 1488:	 tags_emb_327 - 0.0
# 1489:	 tags_emb_328 - 0.0
# 1490:	 tags_emb_329 - 0.0
# 1491:	 tags_emb_330 - 0.0
# 1492:	 tags_emb_332 - 0.0
# 1493:	 tags_emb_333 - 0.0
# 1494:	 tags_emb_334 - 0.0
# 1495:	 tags_emb_335 - 0.0
# 1496:	 tags_emb_336 - 0.0
# 1497:	 tags_emb_337 - 0.0
# 1498:	 tags_emb_338 - 0.0
# 1499:	 tags_emb_339 - 0.0
# 1500:	 tags_emb_340 - 0.0
# 1501:	 tags_emb_341 - 0.0
# 1502:	 tags_emb_342 - 0.0
# 1503:	 tags_emb_343 - 0.0
# 1504:	 tags_emb_344 - 0.0
# 1505:	 tags_emb_345 - 0.0
# 1506:	 tags_emb_346 - 0.0
# 1507:	 tags_emb_347 - 0.0
# 1508:	 tags_emb_349 - 0.0
# 1509:	 tags_emb_350 - 0.0
# 1510:	 tags_emb_351 - 0.0
# 1511:	 tags_emb_352 - 0.0
# 1512:	 tags_emb_353 - 0.0
# 1513:	 tags_emb_355 - 0.0
# 1514:	 tags_emb_356 - 0.0
# 1515:	 tags_emb_357 - 0.0
# 1516:	 tags_emb_358 - 0.0
# 1517:	 tags_emb_359 - 0.0
# 1518:	 tags_emb_360 - 0.0
# 1519:	 tags_emb_361 - 0.0
# 1520:	 tags_emb_362 - 0.0
# 1521:	 tags_emb_363 - 0.0
# 1522:	 tags_emb_364 - 0.0
# 1523:	 tags_emb_365 - 0.0
# 1524:	 tags_emb_366 - 0.0
# 1525:	 tags_emb_367 - 0.0
# 1526:	 tags_emb_368 - 0.0
# 1527:	 tags_emb_370 - 0.0
# 1528:	 tags_emb_371 - 0.0
# 1529:	 tags_emb_372 - 0.0
# 1530:	 tags_emb_373 - 0.0
# 1531:	 tags_emb_374 - 0.0
# 1532:	 tags_emb_375 - 0.0
# 1533:	 tags_emb_376 - 0.0
# 1534:	 tags_emb_377 - 0.0
# 1535:	 tags_emb_378 - 0.0
# 1536:	 tags_emb_379 - 0.0
# 1537:	 tags_emb_380 - 0.0
# 1538:	 tags_emb_381 - 0.0
# 1539:	 tags_emb_382 - 0.0
# 1540:	 tags_emb_383 - 0.0
