# %%
import re

import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import GridSearchCV, cross_val_score
from xgboost import XGBRegressor

# %%
df = pd.read_csv('data/data.csv')
df = df.set_index('AppID')

df
# Out:
#          Score                                           name  recent_percent  \
# AppID
# 335300     6.0       DARK SOULS™ II: Scholar of the First Sin            84.0
# 374320     6.0                                DARK SOULS™ III            93.0
# 570940     6.0                        DARK SOULS™: REMASTERED            92.0
# 435150     6.0  Divinity: Original Sin 2 - Definitive Edition            95.0
# 427520     6.0                                       Factorio            98.0
# ...        ...                                            ...             ...
# 300550     NaN         Shadowrun: Dragonfall - Director's Cut            89.0
# 1123770    NaN                         Curse of the Dead Gods            82.0
# 1656220    NaN               Lost Ark Platinum Founder's Pack             0.0
# 1599340    NaN                                       Lost Ark            95.0
# 1124300    NaN                                     HUMANKIND™             0.0
#
#          recent_count  all_percent  all_count  \
# AppID
# 335300          704.0         86.0    42211.0
# 374320         2870.0         93.0   170504.0
# 570940          720.0         85.0    28282.0
# 435150         1780.0         95.0   106442.0
# 427520         1305.0         98.0    93926.0
# ...               ...          ...        ...
# 300550           28.0         89.0     4273.0
# 1123770          85.0         87.0     3653.0
# 1656220           0.0          0.0        0.0
# 1599340         420.0         95.0      420.0
# 1124300           0.0          0.0        0.0
#
#                                                 short_desc  \
# AppID
# 335300   DARK SOULS™ II: Scholar of the First Sin bring...
# 374320   Dark Souls continues to push the boundaries wi...
# 570940   Then, there was fire. Re-experience the critic...
# 435150   The critically acclaimed RPG that raised the b...
# 427520   Factorio is a game about building and creating...
# ...                                                    ...
# 300550   Harebrained Schemes' biggest Shadowrun game to...
# 1123770  You seek untold riches, eternal life, divine p...
# 1656220                                                NaN
# 1599340  Embark on an odyssey for the Lost Ark in a vas...
# 1124300  HUMANKIND™ is Amplitude Studios' magnum opus, ...
#
#                                                  long_desc  \
# AppID
# 335300   Gamers are in for a big surprise in DARK SOULS...
# 374320   Get the DARK SOULS™ III Season Pass now and ch...
# 570940   Then, there was fire. Re-experience the critic...
# 435150   The Divine is dead. The Void approaches. And t...
# 427520   is a game in which you build and maintain fact...
# ...                                                    ...
# 300550   is a standalone release of Harebrained Schemes...
# 1123770  You seek untold riches, eternal life, divine p...
# 1656220  Enjoy Lost Ark's launch in luxurious comfort w...
# 1599340  Embark on an odyssey for the Lost Ark in a vas...
# 1124300  HUMANKIND™ is , where you’ll be  and combining...
#
#                                                       tags
# AppID
# 335300   ['Souls-like', 'Dark Fantasy', 'RPG', 'Difficu...
# 374320   ['Souls-like', 'Dark Fantasy', 'Difficult', 'R...
# 570940   ['Souls-like', 'Education', 'Dark Fantasy', 'A...
# 435150   ['Exploration', 'Tactical RPG', 'Story Rich', ...
# 427520   ['Automation', 'Base Building', 'Resource Mana...
# ...                                                    ...
# 300550   ['RPG', 'Cyberpunk', 'Turn-Based', 'Story Rich...
# 1123770  ['Action Roguelike', 'Dark Fantasy', 'Isometri...
# 1656220  ['Action', 'Adventure', 'Free to Play', 'Massi...
# 1599340  ['Action', 'RPG', 'MMORPG', 'Adventure', 'Acti...
# 1124300  ['Strategy', 'Turn-Based Strategy', '4X', 'His...
#
# [761 rows x 9 columns]

# %%
df = df[df['name'].notnull()]

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

missing_value_df
# Out:
#                    column_name  percent_missing
# Score                    Score        91.286863
# name                      name         0.000000
# recent_percent  recent_percent         0.000000
# recent_count      recent_count         0.000000
# all_percent        all_percent         0.000000
# all_count            all_count         0.000000
# short_desc          short_desc        10.723861
# long_desc            long_desc         1.608579
# tags                      tags         0.000000

# %%
### Data Pre-process

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
model.max_seq_length = 10000

# Remove appids that were unable to pull information and fill null
df = df[df['name'].notnull()]

# Fill Null
df['short_desc'] = df['short_desc'].fillna('')
df['long_desc'] = df['short_desc'].fillna('')
df['tags'] = df['tags'].fillna('')

# Normalize ratings cols
df['recent_percent']=(df['recent_percent']-df['recent_percent'].mean())/df['recent_percent'].std()
df['recent_count']=(df['recent_count']-df['recent_count'].mean())/df['recent_count'].std()
df['all_percent']=(df['all_percent']-df['all_percent'].mean())/df['all_percent'].std()
df['all_count']=(df['all_count']-df['all_count'].mean())/df['all_count'].std()

# Process name
# Get name embeddings
df['name_emb'] = None
for idx, sentence in zip(df.index, df['name'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'name_emb'] = sentence_emb

# Explode name_emb to multiple cols
emb_len = df['name_emb'].values[0].shape[0]
emb_cols = [f'name_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['name_emb'].tolist(), index=df.index)
df = df.drop(['name_emb'], axis=1)

# Process short_desc
# Get short_desc embeddings
df['short_desc_emb'] = None
for idx, sentence in zip(df.index, df['short_desc'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'short_desc_emb'] = sentence_emb

# Explode short_desc_emb to multiple cols
emb_len = df['short_desc_emb'].values[0].shape[0]
emb_cols = [f'short_desc_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['short_desc_emb'].tolist(), index=df.index)
df = df.drop(['short_desc_emb'], axis=1)

# Process long_desc
# Get long_desc embeddings
df['long_desc_emb'] = None
for idx, sentence in zip(df.index, df['long_desc'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'long_desc_emb'] = sentence_emb

# Explode short_desc_emb to multiple cols
emb_len = df['long_desc_emb'].values[0].shape[0]
emb_cols = [f'long_desc_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['long_desc_emb'].tolist(), index=df.index)
df = df.drop(['long_desc_emb'], axis=1)

# Process tags
# Get tags embeddings
df['tags_emb'] = None
for idx, sentence in zip(df.index, df['tags'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'tags_emb'] = sentence_emb

# Explode tags to multiple cols
emb_len = df['tags_emb'].values[0].shape[0]
emb_cols = [f'tags_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['tags_emb'].tolist(), index=df.index)
df = df.drop(['tags_emb'], axis=1)

# Drop unneeded cols
df_proc = df.drop(['name', 'short_desc', 'long_desc', 'tags'], axis=1)

df_proc
# Out:
#          Score  recent_percent  recent_count  all_percent  all_count  \
# AppID
# 335300     6.0        0.135476     -0.067126     0.192202   0.021239
# 374320     6.0        0.594169      0.467825     0.563386   0.590301
# 570940     6.0        0.543203     -0.063174     0.139176  -0.040546
# 435150     6.0        0.696101      0.198621     0.669438   0.306145
# 427520     6.0        0.848999      0.081307     0.828517   0.250628
# ...        ...             ...           ...          ...        ...
# 300550     NaN        0.390306     -0.234082     0.351281  -0.147041
# 1123770    NaN        0.033545     -0.220004     0.245228  -0.149791
# 1656220    NaN       -4.145658     -0.240997    -4.368051  -0.165995
# 1599340    NaN        0.696101     -0.137267     0.669438  -0.164132
# 1124300    NaN       -4.145658     -0.240997    -4.368051  -0.165995
#
#          name_emb_0  name_emb_1  name_emb_2  name_emb_3  name_emb_4  ...  \
# AppID                                                                ...
# 335300    -0.205885    0.530514    0.019095    0.098417   -0.168850  ...
# 374320    -0.425300    0.070268    0.467150   -0.283747   -0.155813  ...
# 570940    -0.411845    0.084661    0.643239   -0.140084    0.178792  ...
# 435150    -0.083358    0.879001    0.190073   -0.143532   -0.288290  ...
# 427520    -0.203325   -0.352310    0.348856    0.072503    0.431592  ...
# ...             ...         ...         ...         ...         ...  ...
# 300550    -0.056121   -0.387639    0.244720   -0.006604    0.354779  ...
# 1123770   -0.134340    0.665992    0.176863   -0.211233   -0.215129  ...
# 1656220   -0.504908    0.580813    0.138195    0.232517    0.339013  ...
# 1599340    0.179558    0.133478    0.584903    0.291661    0.171639  ...
# 1124300   -0.193845    0.160164    0.051958   -0.628105   -0.027723  ...
#
#          tags_emb_374  tags_emb_375  tags_emb_376  tags_emb_377  tags_emb_378  \
# AppID
# 335300       0.115262      0.345862      0.314601      0.397895      0.191249
# 374320       0.116821      0.334152      0.317752      0.427623      0.259606
# 570940       0.225787      0.307348      0.386953      0.379711      0.068206
# 435150       0.347019      0.380082      0.186806      0.406189      0.202399
# 427520       0.356976      0.407364      0.030227     -0.060064      0.199887
# ...               ...           ...           ...           ...           ...
# 300550       0.284871      0.598091      0.153172      0.397115     -0.090651
# 1123770      0.247612      0.505186      0.259316      0.296274     -0.013975
# 1656220      0.267895      0.377920      0.187860      0.376677      0.092930
# 1599340      0.259837      0.393009      0.190811      0.325813      0.104222
# 1124300      0.315847      0.649741      0.175472      0.248827     -0.153346
#
#          tags_emb_379  tags_emb_380  tags_emb_381  tags_emb_382  tags_emb_383
# AppID
# 335300       0.155089      0.538477     -0.224874     -0.174770      0.102378
# 374320       0.187720      0.463271     -0.159190     -0.183715      0.048535
# 570940       0.046789      0.564373     -0.161320     -0.144110      0.041049
# 435150       0.070317      0.111917      0.159146      0.006333      0.042420
# 427520       0.386202     -0.035973     -0.105921      0.050927      0.349570
# ...               ...           ...           ...           ...           ...
# 300550       0.215774      0.145057     -0.100049      0.025129      0.260629
# 1123770      0.291900      0.476312     -0.227017      0.209345      0.065049
# 1656220      0.217142      0.113441     -0.224005      0.028210      0.128886
# 1599340      0.272540      0.120247     -0.210933      0.116108      0.048274
# 1124300      0.166174      0.137226      0.002403     -0.043646      0.179358
#
# [746 rows x 2309 columns]

# %%
### ML Model

# data split
df_model = df_proc[df_proc['Score'].notnull()]
X = df_model.drop(['Score'], axis=1)
y = df_model['Score']

df_pred = df_proc[df_proc['Score'].isnull()]
X_pred = df_pred.drop(['Score'], axis=1)

# model
objective = ['reg:squarederror']
max_depth = [int(x) for x in np.linspace(25, 50, num=5) if x != 0]
n_estimators = [int(x) for x in np.linspace(50, 250, num=10) if x != 0]
random_grid = {
    'objective': objective,
    'max_depth': max_depth,
    'n_estimators': n_estimators,
}
model = XGBRegressor(random_state=42, verbosity=0, n_jobs=-1)
search = GridSearchCV(estimator=model, param_grid=random_grid, scoring='neg_mean_squared_error', cv=3, verbose=1, n_jobs=-1)
search.fit(X, y)
print(search.best_params_)

# Fit Model
model = XGBRegressor(**search.best_params_, random_state=42, verbosity=0, n_jobs=-1)
model.fit(X, y)

# Get Cross Val Score
scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
print(f' Avg. MSE: {scores.mean():0.4f} (+/- {scores.std():0.4f})')

# pred
y_pred = model.predict(X_pred)

df_pred = pd.DataFrame({
    'AppID': X_pred.index.values,
    'Pred Score': y_pred
}).sort_values('Pred Score', ascending=False).set_index('AppID')
df_pred = df_pred.join(df[['name']], how='left')
df_pred = df_pred[['name', 'Pred Score']]

df_pred
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# {'max_depth': 25, 'n_estimators': 72, 'objective': 'reg:squarederror'}
#  Avg. MSE: -2.3128 (+/- 1.4824)
#                                                       name  Pred Score
# AppID
# 640820       Pathfinder: Kingmaker - Enhanced Plus Edition    5.656024
# 632470                       Disco Elysium - The Final Cut    5.580381
# 1139900                                        Ghostrunner    5.534202
# 373420           Divinity: Original Sin - Enhanced Edition    5.524318
# 22330    The Elder Scrolls IV: Oblivion® Game of the Ye...    5.486963
# ...                                                    ...         ...
# 1418630                                       Dread Hunger    2.844273
# 601840                                          Griftlands    2.745710
# 848450                              Subnautica: Below Zero    2.740181
# 433080                          XCOM 2: Anarchy's Children    2.716713
# 420290                                           Blackwake    2.709818
#
# [681 rows x 2 columns]

# %%
"""
No Name
78	588650	5.660944 - Dead Cells
411	288470	5.444581 - Fable Anniversy
642	1174180	5.382903 - RDR2
185	550	5.309083     - L4D2
376	17460	5.304587 - Mass Effect

Name
576	976730	5.124917 - Halo: MCC
627	1174180	4.943077 - RDR2
626	1172620	4.901459 - Sea of Thieves
334	391540	4.901459 - Undertale
535	812140	4.883088 - AC: Odyssey
Avg. MSE: -1.9802 (+/- 1.4576)
"""
# Out:
# '\nNo Name\n78\t588650\t5.660944 - Dead Cells\n411\t288470\t5.444581 - Fable Anniversy\n642\t1174180\t5.382903 - RDR2\n185\t550\t5.309083     - L4D2\n376\t17460\t5.304587 - Mass Effect\n\nName\n576\t976730\t5.124917 - Halo: MCC\n627\t1174180\t4.943077 - RDR2\n626\t1172620\t4.901459 - Sea of Thieves\n334\t391540\t4.901459 - Undertale\n535\t812140\t4.883088 - AC: Odyssey\nAvg. MSE: -1.9802 (+/- 1.4576)\n'

# %%
for i , (col, imp) in enumerate(sorted(zip(X_pred.columns, model.feature_importances_), key=lambda x: x[1], reverse=True)):
    print(f'{i+1}:\t {col} - {imp}')
# Out:
# 1:	 short_desc_emb_291 - 0.21761205792427063
# 2:	 name_emb_583 - 0.12712204456329346
# 3:	 short_desc_emb_281 - 0.11921712011098862
# 4:	 name_emb_343 - 0.0727023109793663
# 5:	 name_emb_45 - 0.05890677124261856
# 6:	 name_emb_289 - 0.052350860089063644
# 7:	 name_emb_732 - 0.04873856157064438
# 8:	 name_emb_658 - 0.037858348339796066
# 9:	 name_emb_281 - 0.026585353538393974
# 10:	 name_emb_120 - 0.024303916841745377
# 11:	 short_desc_emb_571 - 0.020129768177866936
# 12:	 tags_emb_286 - 0.016809502616524696
# 13:	 name_emb_744 - 0.01641199178993702
# 14:	 tags_emb_25 - 0.013854063116014004
# 15:	 tags_emb_211 - 0.01361350528895855
# 16:	 short_desc_emb_643 - 0.011295730248093605
# 17:	 name_emb_717 - 0.010061802342534065
# 18:	 name_emb_229 - 0.00984121672809124
# 19:	 short_desc_emb_530 - 0.008785940706729889
# 20:	 name_emb_12 - 0.00877720769494772
# 21:	 short_desc_emb_182 - 0.0076879700645804405
# 22:	 short_desc_emb_412 - 0.007244313135743141
# 23:	 short_desc_emb_114 - 0.007057476323097944
# 24:	 name_emb_142 - 0.006797822192311287
# 25:	 short_desc_emb_606 - 0.006701019126921892
# 26:	 tags_emb_333 - 0.004807095974683762
# 27:	 short_desc_emb_375 - 0.004386330489069223
# 28:	 name_emb_273 - 0.0036686889361590147
# 29:	 name_emb_51 - 0.003347348654642701
# 30:	 short_desc_emb_213 - 0.0028853341937065125
# 31:	 short_desc_emb_418 - 0.002797389402985573
# 32:	 short_desc_emb_603 - 0.0023190376814454794
# 33:	 name_emb_58 - 0.002130439504981041
# 34:	 name_emb_22 - 0.002072653966024518
# 35:	 short_desc_emb_224 - 0.0018682937370613217
# 36:	 name_emb_63 - 0.0017145141027867794
# 37:	 name_emb_4 - 0.0017007187707349658
# 38:	 name_emb_551 - 0.0016048674006015062
# 39:	 name_emb_358 - 0.0015935278497636318
# 40:	 short_desc_emb_334 - 0.0011695042485371232
# 41:	 short_desc_emb_559 - 0.0011453770566731691
# 42:	 tags_emb_327 - 0.0011265097418799996
# 43:	 short_desc_emb_194 - 0.0010179533855989575
# 44:	 name_emb_300 - 0.0008153263479471207
# 45:	 tags_emb_162 - 0.0006541332113556564
# 46:	 short_desc_emb_22 - 0.0006272316677495837
# 47:	 name_emb_67 - 0.0005996716790832579
# 48:	 name_emb_1 - 0.0005608216742984951
# 49:	 name_emb_43 - 0.0005318445037119091
# 50:	 name_emb_159 - 0.0004919306375086308
# 51:	 short_desc_emb_750 - 0.00043384419404901564
# 52:	 name_emb_579 - 0.00039046636084094644
# 53:	 short_desc_emb_131 - 0.0003062338219024241
# 54:	 name_emb_9 - 0.00025713047944009304
# 55:	 name_emb_53 - 0.00023047238937579095
# 56:	 name_emb_3 - 0.00021725817350670695
# 57:	 tags_emb_188 - 0.00017091735207941383
# 58:	 short_desc_emb_104 - 0.00016332909581251442
# 59:	 name_emb_7 - 0.00015252585581038147
# 60:	 recent_count - 0.00013072097499389201
# 61:	 name_emb_536 - 0.00012021591101074591
# 62:	 name_emb_690 - 0.00011668029765132815
# 63:	 short_desc_emb_487 - 0.00011222186731174588
# 64:	 short_desc_emb_94 - 9.885327017400414e-05
# 65:	 short_desc_emb_399 - 9.716943168314174e-05
# 66:	 recent_percent - 9.487221541348845e-05
# 67:	 short_desc_emb_452 - 8.228827937273309e-05
# 68:	 name_emb_276 - 8.130035712383687e-05
# 69:	 short_desc_emb_295 - 6.987636152189225e-05
# 70:	 name_emb_703 - 5.810426955576986e-05
# 71:	 name_emb_82 - 4.413742499309592e-05
# 72:	 name_emb_260 - 3.864401878672652e-05
# 73:	 tags_emb_281 - 3.5548371670302004e-05
# 74:	 tags_emb_242 - 3.373073923285119e-05
# 75:	 tags_emb_221 - 3.0124510885798372e-05
# 76:	 name_emb_736 - 2.5143441234831698e-05
# 77:	 name_emb_544 - 2.2648846424999647e-05
# 78:	 short_desc_emb_748 - 2.2144758986542e-05
# 79:	 name_emb_0 - 2.144421341654379e-05
# 80:	 name_emb_35 - 2.0900379240629263e-05
# 81:	 name_emb_10 - 1.9935736418119632e-05
# 82:	 name_emb_164 - 1.9039853214053437e-05
# 83:	 name_emb_204 - 1.7455164197599515e-05
# 84:	 name_emb_6 - 1.6257907191175036e-05
# 85:	 short_desc_emb_85 - 1.6242916899500415e-05
# 86:	 name_emb_199 - 1.4915920473868027e-05
# 87:	 name_emb_133 - 1.3983925782667939e-05
# 88:	 short_desc_emb_274 - 1.2210844033688772e-05
# 89:	 short_desc_emb_46 - 8.100613740680274e-06
# 90:	 tags_emb_215 - 7.368982096522814e-06
# 91:	 name_emb_191 - 5.703833721781848e-06
# 92:	 short_desc_emb_254 - 5.474495992530137e-06
# 93:	 short_desc_emb_664 - 4.739206360682147e-06
# 94:	 short_desc_emb_370 - 4.712305326393107e-06
# 95:	 tags_emb_227 - 4.445393642527051e-06
# 96:	 name_emb_299 - 4.1674397834867705e-06
# 97:	 name_emb_172 - 3.7875838643230963e-06
# 98:	 tags_emb_369 - 3.5149178074789234e-06
# 99:	 name_emb_234 - 3.2375251066696364e-06
# 100:	 name_emb_479 - 2.991947212649393e-06
# 101:	 name_emb_29 - 2.855682168956264e-06
# 102:	 name_emb_314 - 2.320944986422546e-06
# 103:	 short_desc_emb_215 - 2.3010204586171312e-06
# 104:	 short_desc_emb_29 - 2.2813665054854937e-06
# 105:	 name_emb_2 - 2.134806436515646e-06
# 106:	 name_emb_31 - 1.8010814528679475e-06
# 107:	 name_emb_157 - 1.5607979548803996e-06
# 108:	 name_emb_530 - 1.375014903715055e-06
# 109:	 name_emb_113 - 1.2742355011141626e-06
# 110:	 name_emb_344 - 1.1924437330890214e-06
# 111:	 name_emb_203 - 1.0536666650295956e-06
# 112:	 short_desc_emb_183 - 8.923101404434419e-07
# 113:	 name_emb_165 - 8.339641794918862e-07
# 114:	 short_desc_emb_72 - 7.599080618092557e-07
# 115:	 name_emb_387 - 5.699586722585082e-07
# 116:	 name_emb_23 - 5.44494525911432e-07
# 117:	 short_desc_emb_567 - 4.3455230525069055e-07
# 118:	 short_desc_emb_562 - 4.147508434471092e-07
# 119:	 all_percent - 4.0925618804976693e-07
# 120:	 name_emb_39 - 4.076206039371755e-07
# 121:	 tags_emb_140 - 3.946951494526729e-07
# 122:	 tags_emb_118 - 3.763958318359073e-07
# 123:	 name_emb_243 - 3.391161556010047e-07
# 124:	 name_emb_593 - 3.260988421516231e-07
# 125:	 tags_emb_234 - 2.8333454338280717e-07
# 126:	 tags_emb_337 - 2.3759767486808414e-07
# 127:	 name_emb_667 - 2.1629789159760549e-07
# 128:	 tags_emb_344 - 1.9717087695880764e-07
# 129:	 name_emb_34 - 1.401615179474902e-07
# 130:	 short_desc_emb_23 - 1.3847520108356548e-07
# 131:	 name_emb_500 - 1.1000086885815108e-07
# 132:	 tags_emb_294 - 1.068676169779792e-07
# 133:	 tags_emb_206 - 1.0298177244294493e-07
# 134:	 short_desc_emb_459 - 1.0132752947811241e-07
# 135:	 tags_emb_295 - 9.957239655022931e-08
# 136:	 short_desc_emb_538 - 9.439843751124499e-08
# 137:	 short_desc_emb_233 - 9.375610687811786e-08
# 138:	 name_emb_689 - 6.963167464846265e-08
# 139:	 name_emb_329 - 6.208332337109823e-08
# 140:	 name_emb_492 - 5.231798638760665e-08
# 141:	 name_emb_153 - 4.5328853559567506e-08
# 142:	 tags_emb_13 - 4.523730012806482e-08
# 143:	 short_desc_emb_416 - 3.917410040799041e-08
# 144:	 short_desc_emb_451 - 3.717388707968894e-08
# 145:	 name_emb_559 - 3.647738466838746e-08
# 146:	 short_desc_emb_458 - 3.316270280606659e-08
# 147:	 name_emb_224 - 2.97403932592033e-08
# 148:	 short_desc_emb_531 - 2.236771834418505e-08
# 149:	 name_emb_548 - 2.0682218604406444e-08
# 150:	 name_emb_462 - 2.0224259600354344e-08
# 151:	 name_emb_376 - 2.003904242542376e-08
# 152:	 name_emb_100 - 1.945772432065951e-08
# 153:	 short_desc_emb_507 - 1.9439422516143168e-08
# 154:	 name_emb_323 - 1.846665753646448e-08
# 155:	 tags_emb_181 - 1.7060360235632288e-08
# 156:	 short_desc_emb_2 - 1.6019944482081883e-08
# 157:	 name_emb_532 - 1.4445942220220331e-08
# 158:	 all_count - 1.3429255041330634e-08
# 159:	 name_emb_622 - 1.326393750389343e-08
# 160:	 tags_emb_331 - 1.3220157413229572e-08
# 161:	 tags_emb_126 - 1.272233873805817e-08
# 162:	 name_emb_330 - 1.2564569829009997e-08
# 163:	 short_desc_emb_273 - 1.2198502652438492e-08
# 164:	 name_emb_187 - 1.157729201395341e-08
# 165:	 name_emb_5 - 0.0
# 166:	 name_emb_8 - 0.0
# 167:	 name_emb_11 - 0.0
# 168:	 name_emb_13 - 0.0
# 169:	 name_emb_14 - 0.0
# 170:	 name_emb_15 - 0.0
# 171:	 name_emb_16 - 0.0
# 172:	 name_emb_17 - 0.0
# 173:	 name_emb_18 - 0.0
# 174:	 name_emb_19 - 0.0
# 175:	 name_emb_20 - 0.0
# 176:	 name_emb_21 - 0.0
# 177:	 name_emb_24 - 0.0
# 178:	 name_emb_25 - 0.0
# 179:	 name_emb_26 - 0.0
# 180:	 name_emb_27 - 0.0
# 181:	 name_emb_28 - 0.0
# 182:	 name_emb_30 - 0.0
# 183:	 name_emb_32 - 0.0
# 184:	 name_emb_33 - 0.0
# 185:	 name_emb_36 - 0.0
# 186:	 name_emb_37 - 0.0
# 187:	 name_emb_38 - 0.0
# 188:	 name_emb_40 - 0.0
# 189:	 name_emb_41 - 0.0
# 190:	 name_emb_42 - 0.0
# 191:	 name_emb_44 - 0.0
# 192:	 name_emb_46 - 0.0
# 193:	 name_emb_47 - 0.0
# 194:	 name_emb_48 - 0.0
# 195:	 name_emb_49 - 0.0
# 196:	 name_emb_50 - 0.0
# 197:	 name_emb_52 - 0.0
# 198:	 name_emb_54 - 0.0
# 199:	 name_emb_55 - 0.0
# 200:	 name_emb_56 - 0.0
# 201:	 name_emb_57 - 0.0
# 202:	 name_emb_59 - 0.0
# 203:	 name_emb_60 - 0.0
# 204:	 name_emb_61 - 0.0
# 205:	 name_emb_62 - 0.0
# 206:	 name_emb_64 - 0.0
# 207:	 name_emb_65 - 0.0
# 208:	 name_emb_66 - 0.0
# 209:	 name_emb_68 - 0.0
# 210:	 name_emb_69 - 0.0
# 211:	 name_emb_70 - 0.0
# 212:	 name_emb_71 - 0.0
# 213:	 name_emb_72 - 0.0
# 214:	 name_emb_73 - 0.0
# 215:	 name_emb_74 - 0.0
# 216:	 name_emb_75 - 0.0
# 217:	 name_emb_76 - 0.0
# 218:	 name_emb_77 - 0.0
# 219:	 name_emb_78 - 0.0
# 220:	 name_emb_79 - 0.0
# 221:	 name_emb_80 - 0.0
# 222:	 name_emb_81 - 0.0
# 223:	 name_emb_83 - 0.0
# 224:	 name_emb_84 - 0.0
# 225:	 name_emb_85 - 0.0
# 226:	 name_emb_86 - 0.0
# 227:	 name_emb_87 - 0.0
# 228:	 name_emb_88 - 0.0
# 229:	 name_emb_89 - 0.0
# 230:	 name_emb_90 - 0.0
# 231:	 name_emb_91 - 0.0
# 232:	 name_emb_92 - 0.0
# 233:	 name_emb_93 - 0.0
# 234:	 name_emb_94 - 0.0
# 235:	 name_emb_95 - 0.0
# 236:	 name_emb_96 - 0.0
# 237:	 name_emb_97 - 0.0
# 238:	 name_emb_98 - 0.0
# 239:	 name_emb_99 - 0.0
# 240:	 name_emb_101 - 0.0
# 241:	 name_emb_102 - 0.0
# 242:	 name_emb_103 - 0.0
# 243:	 name_emb_104 - 0.0
# 244:	 name_emb_105 - 0.0
# 245:	 name_emb_106 - 0.0
# 246:	 name_emb_107 - 0.0
# 247:	 name_emb_108 - 0.0
# 248:	 name_emb_109 - 0.0
# 249:	 name_emb_110 - 0.0
# 250:	 name_emb_111 - 0.0
# 251:	 name_emb_112 - 0.0
# 252:	 name_emb_114 - 0.0
# 253:	 name_emb_115 - 0.0
# 254:	 name_emb_116 - 0.0
# 255:	 name_emb_117 - 0.0
# 256:	 name_emb_118 - 0.0
# 257:	 name_emb_119 - 0.0
# 258:	 name_emb_121 - 0.0
# 259:	 name_emb_122 - 0.0
# 260:	 name_emb_123 - 0.0
# 261:	 name_emb_124 - 0.0
# 262:	 name_emb_125 - 0.0
# 263:	 name_emb_126 - 0.0
# 264:	 name_emb_127 - 0.0
# 265:	 name_emb_128 - 0.0
# 266:	 name_emb_129 - 0.0
# 267:	 name_emb_130 - 0.0
# 268:	 name_emb_131 - 0.0
# 269:	 name_emb_132 - 0.0
# 270:	 name_emb_134 - 0.0
# 271:	 name_emb_135 - 0.0
# 272:	 name_emb_136 - 0.0
# 273:	 name_emb_137 - 0.0
# 274:	 name_emb_138 - 0.0
# 275:	 name_emb_139 - 0.0
# 276:	 name_emb_140 - 0.0
# 277:	 name_emb_141 - 0.0
# 278:	 name_emb_143 - 0.0
# 279:	 name_emb_144 - 0.0
# 280:	 name_emb_145 - 0.0
# 281:	 name_emb_146 - 0.0
# 282:	 name_emb_147 - 0.0
# 283:	 name_emb_148 - 0.0
# 284:	 name_emb_149 - 0.0
# 285:	 name_emb_150 - 0.0
# 286:	 name_emb_151 - 0.0
# 287:	 name_emb_152 - 0.0
# 288:	 name_emb_154 - 0.0
# 289:	 name_emb_155 - 0.0
# 290:	 name_emb_156 - 0.0
# 291:	 name_emb_158 - 0.0
# 292:	 name_emb_160 - 0.0
# 293:	 name_emb_161 - 0.0
# 294:	 name_emb_162 - 0.0
# 295:	 name_emb_163 - 0.0
# 296:	 name_emb_166 - 0.0
# 297:	 name_emb_167 - 0.0
# 298:	 name_emb_168 - 0.0
# 299:	 name_emb_169 - 0.0
# 300:	 name_emb_170 - 0.0
# 301:	 name_emb_171 - 0.0
# 302:	 name_emb_173 - 0.0
# 303:	 name_emb_174 - 0.0
# 304:	 name_emb_175 - 0.0
# 305:	 name_emb_176 - 0.0
# 306:	 name_emb_177 - 0.0
# 307:	 name_emb_178 - 0.0
# 308:	 name_emb_179 - 0.0
# 309:	 name_emb_180 - 0.0
# 310:	 name_emb_181 - 0.0
# 311:	 name_emb_182 - 0.0
# 312:	 name_emb_183 - 0.0
# 313:	 name_emb_184 - 0.0
# 314:	 name_emb_185 - 0.0
# 315:	 name_emb_186 - 0.0
# 316:	 name_emb_188 - 0.0
# 317:	 name_emb_189 - 0.0
# 318:	 name_emb_190 - 0.0
# 319:	 name_emb_192 - 0.0
# 320:	 name_emb_193 - 0.0
# 321:	 name_emb_194 - 0.0
# 322:	 name_emb_195 - 0.0
# 323:	 name_emb_196 - 0.0
# 324:	 name_emb_197 - 0.0
# 325:	 name_emb_198 - 0.0
# 326:	 name_emb_200 - 0.0
# 327:	 name_emb_201 - 0.0
# 328:	 name_emb_202 - 0.0
# 329:	 name_emb_205 - 0.0
# 330:	 name_emb_206 - 0.0
# 331:	 name_emb_207 - 0.0
# 332:	 name_emb_208 - 0.0
# 333:	 name_emb_209 - 0.0
# 334:	 name_emb_210 - 0.0
# 335:	 name_emb_211 - 0.0
# 336:	 name_emb_212 - 0.0
# 337:	 name_emb_213 - 0.0
# 338:	 name_emb_214 - 0.0
# 339:	 name_emb_215 - 0.0
# 340:	 name_emb_216 - 0.0
# 341:	 name_emb_217 - 0.0
# 342:	 name_emb_218 - 0.0
# 343:	 name_emb_219 - 0.0
# 344:	 name_emb_220 - 0.0
# 345:	 name_emb_221 - 0.0
# 346:	 name_emb_222 - 0.0
# 347:	 name_emb_223 - 0.0
# 348:	 name_emb_225 - 0.0
# 349:	 name_emb_226 - 0.0
# 350:	 name_emb_227 - 0.0
# 351:	 name_emb_228 - 0.0
# 352:	 name_emb_230 - 0.0
# 353:	 name_emb_231 - 0.0
# 354:	 name_emb_232 - 0.0
# 355:	 name_emb_233 - 0.0
# 356:	 name_emb_235 - 0.0
# 357:	 name_emb_236 - 0.0
# 358:	 name_emb_237 - 0.0
# 359:	 name_emb_238 - 0.0
# 360:	 name_emb_239 - 0.0
# 361:	 name_emb_240 - 0.0
# 362:	 name_emb_241 - 0.0
# 363:	 name_emb_242 - 0.0
# 364:	 name_emb_244 - 0.0
# 365:	 name_emb_245 - 0.0
# 366:	 name_emb_246 - 0.0
# 367:	 name_emb_247 - 0.0
# 368:	 name_emb_248 - 0.0
# 369:	 name_emb_249 - 0.0
# 370:	 name_emb_250 - 0.0
# 371:	 name_emb_251 - 0.0
# 372:	 name_emb_252 - 0.0
# 373:	 name_emb_253 - 0.0
# 374:	 name_emb_254 - 0.0
# 375:	 name_emb_255 - 0.0
# 376:	 name_emb_256 - 0.0
# 377:	 name_emb_257 - 0.0
# 378:	 name_emb_258 - 0.0
# 379:	 name_emb_259 - 0.0
# 380:	 name_emb_261 - 0.0
# 381:	 name_emb_262 - 0.0
# 382:	 name_emb_263 - 0.0
# 383:	 name_emb_264 - 0.0
# 384:	 name_emb_265 - 0.0
# 385:	 name_emb_266 - 0.0
# 386:	 name_emb_267 - 0.0
# 387:	 name_emb_268 - 0.0
# 388:	 name_emb_269 - 0.0
# 389:	 name_emb_270 - 0.0
# 390:	 name_emb_271 - 0.0
# 391:	 name_emb_272 - 0.0
# 392:	 name_emb_274 - 0.0
# 393:	 name_emb_275 - 0.0
# 394:	 name_emb_277 - 0.0
# 395:	 name_emb_278 - 0.0
# 396:	 name_emb_279 - 0.0
# 397:	 name_emb_280 - 0.0
# 398:	 name_emb_282 - 0.0
# 399:	 name_emb_283 - 0.0
# 400:	 name_emb_284 - 0.0
# 401:	 name_emb_285 - 0.0
# 402:	 name_emb_286 - 0.0
# 403:	 name_emb_287 - 0.0
# 404:	 name_emb_288 - 0.0
# 405:	 name_emb_290 - 0.0
# 406:	 name_emb_291 - 0.0
# 407:	 name_emb_292 - 0.0
# 408:	 name_emb_293 - 0.0
# 409:	 name_emb_294 - 0.0
# 410:	 name_emb_295 - 0.0
# 411:	 name_emb_296 - 0.0
# 412:	 name_emb_297 - 0.0
# 413:	 name_emb_298 - 0.0
# 414:	 name_emb_301 - 0.0
# 415:	 name_emb_302 - 0.0
# 416:	 name_emb_303 - 0.0
# 417:	 name_emb_304 - 0.0
# 418:	 name_emb_305 - 0.0
# 419:	 name_emb_306 - 0.0
# 420:	 name_emb_307 - 0.0
# 421:	 name_emb_308 - 0.0
# 422:	 name_emb_309 - 0.0
# 423:	 name_emb_310 - 0.0
# 424:	 name_emb_311 - 0.0
# 425:	 name_emb_312 - 0.0
# 426:	 name_emb_313 - 0.0
# 427:	 name_emb_315 - 0.0
# 428:	 name_emb_316 - 0.0
# 429:	 name_emb_317 - 0.0
# 430:	 name_emb_318 - 0.0
# 431:	 name_emb_319 - 0.0
# 432:	 name_emb_320 - 0.0
# 433:	 name_emb_321 - 0.0
# 434:	 name_emb_322 - 0.0
# 435:	 name_emb_324 - 0.0
# 436:	 name_emb_325 - 0.0
# 437:	 name_emb_326 - 0.0
# 438:	 name_emb_327 - 0.0
# 439:	 name_emb_328 - 0.0
# 440:	 name_emb_331 - 0.0
# 441:	 name_emb_332 - 0.0
# 442:	 name_emb_333 - 0.0
# 443:	 name_emb_334 - 0.0
# 444:	 name_emb_335 - 0.0
# 445:	 name_emb_336 - 0.0
# 446:	 name_emb_337 - 0.0
# 447:	 name_emb_338 - 0.0
# 448:	 name_emb_339 - 0.0
# 449:	 name_emb_340 - 0.0
# 450:	 name_emb_341 - 0.0
# 451:	 name_emb_342 - 0.0
# 452:	 name_emb_345 - 0.0
# 453:	 name_emb_346 - 0.0
# 454:	 name_emb_347 - 0.0
# 455:	 name_emb_348 - 0.0
# 456:	 name_emb_349 - 0.0
# 457:	 name_emb_350 - 0.0
# 458:	 name_emb_351 - 0.0
# 459:	 name_emb_352 - 0.0
# 460:	 name_emb_353 - 0.0
# 461:	 name_emb_354 - 0.0
# 462:	 name_emb_355 - 0.0
# 463:	 name_emb_356 - 0.0
# 464:	 name_emb_357 - 0.0
# 465:	 name_emb_359 - 0.0
# 466:	 name_emb_360 - 0.0
# 467:	 name_emb_361 - 0.0
# 468:	 name_emb_362 - 0.0
# 469:	 name_emb_363 - 0.0
# 470:	 name_emb_364 - 0.0
# 471:	 name_emb_365 - 0.0
# 472:	 name_emb_366 - 0.0
# 473:	 name_emb_367 - 0.0
# 474:	 name_emb_368 - 0.0
# 475:	 name_emb_369 - 0.0
# 476:	 name_emb_370 - 0.0
# 477:	 name_emb_371 - 0.0
# 478:	 name_emb_372 - 0.0
# 479:	 name_emb_373 - 0.0
# 480:	 name_emb_374 - 0.0
# 481:	 name_emb_375 - 0.0
# 482:	 name_emb_377 - 0.0
# 483:	 name_emb_378 - 0.0
# 484:	 name_emb_379 - 0.0
# 485:	 name_emb_380 - 0.0
# 486:	 name_emb_381 - 0.0
# 487:	 name_emb_382 - 0.0
# 488:	 name_emb_383 - 0.0
# 489:	 name_emb_384 - 0.0
# 490:	 name_emb_385 - 0.0
# 491:	 name_emb_386 - 0.0
# 492:	 name_emb_388 - 0.0
# 493:	 name_emb_389 - 0.0
# 494:	 name_emb_390 - 0.0
# 495:	 name_emb_391 - 0.0
# 496:	 name_emb_392 - 0.0
# 497:	 name_emb_393 - 0.0
# 498:	 name_emb_394 - 0.0
# 499:	 name_emb_395 - 0.0
# 500:	 name_emb_396 - 0.0
# 501:	 name_emb_397 - 0.0
# 502:	 name_emb_398 - 0.0
# 503:	 name_emb_399 - 0.0
# 504:	 name_emb_400 - 0.0
# 505:	 name_emb_401 - 0.0
# 506:	 name_emb_402 - 0.0
# 507:	 name_emb_403 - 0.0
# 508:	 name_emb_404 - 0.0
# 509:	 name_emb_405 - 0.0
# 510:	 name_emb_406 - 0.0
# 511:	 name_emb_407 - 0.0
# 512:	 name_emb_408 - 0.0
# 513:	 name_emb_409 - 0.0
# 514:	 name_emb_410 - 0.0
# 515:	 name_emb_411 - 0.0
# 516:	 name_emb_412 - 0.0
# 517:	 name_emb_413 - 0.0
# 518:	 name_emb_414 - 0.0
# 519:	 name_emb_415 - 0.0
# 520:	 name_emb_416 - 0.0
# 521:	 name_emb_417 - 0.0
# 522:	 name_emb_418 - 0.0
# 523:	 name_emb_419 - 0.0
# 524:	 name_emb_420 - 0.0
# 525:	 name_emb_421 - 0.0
# 526:	 name_emb_422 - 0.0
# 527:	 name_emb_423 - 0.0
# 528:	 name_emb_424 - 0.0
# 529:	 name_emb_425 - 0.0
# 530:	 name_emb_426 - 0.0
# 531:	 name_emb_427 - 0.0
# 532:	 name_emb_428 - 0.0
# 533:	 name_emb_429 - 0.0
# 534:	 name_emb_430 - 0.0
# 535:	 name_emb_431 - 0.0
# 536:	 name_emb_432 - 0.0
# 537:	 name_emb_433 - 0.0
# 538:	 name_emb_434 - 0.0
# 539:	 name_emb_435 - 0.0
# 540:	 name_emb_436 - 0.0
# 541:	 name_emb_437 - 0.0
# 542:	 name_emb_438 - 0.0
# 543:	 name_emb_439 - 0.0
# 544:	 name_emb_440 - 0.0
# 545:	 name_emb_441 - 0.0
# 546:	 name_emb_442 - 0.0
# 547:	 name_emb_443 - 0.0
# 548:	 name_emb_444 - 0.0
# 549:	 name_emb_445 - 0.0
# 550:	 name_emb_446 - 0.0
# 551:	 name_emb_447 - 0.0
# 552:	 name_emb_448 - 0.0
# 553:	 name_emb_449 - 0.0
# 554:	 name_emb_450 - 0.0
# 555:	 name_emb_451 - 0.0
# 556:	 name_emb_452 - 0.0
# 557:	 name_emb_453 - 0.0
# 558:	 name_emb_454 - 0.0
# 559:	 name_emb_455 - 0.0
# 560:	 name_emb_456 - 0.0
# 561:	 name_emb_457 - 0.0
# 562:	 name_emb_458 - 0.0
# 563:	 name_emb_459 - 0.0
# 564:	 name_emb_460 - 0.0
# 565:	 name_emb_461 - 0.0
# 566:	 name_emb_463 - 0.0
# 567:	 name_emb_464 - 0.0
# 568:	 name_emb_465 - 0.0
# 569:	 name_emb_466 - 0.0
# 570:	 name_emb_467 - 0.0
# 571:	 name_emb_468 - 0.0
# 572:	 name_emb_469 - 0.0
# 573:	 name_emb_470 - 0.0
# 574:	 name_emb_471 - 0.0
# 575:	 name_emb_472 - 0.0
# 576:	 name_emb_473 - 0.0
# 577:	 name_emb_474 - 0.0
# 578:	 name_emb_475 - 0.0
# 579:	 name_emb_476 - 0.0
# 580:	 name_emb_477 - 0.0
# 581:	 name_emb_478 - 0.0
# 582:	 name_emb_480 - 0.0
# 583:	 name_emb_481 - 0.0
# 584:	 name_emb_482 - 0.0
# 585:	 name_emb_483 - 0.0
# 586:	 name_emb_484 - 0.0
# 587:	 name_emb_485 - 0.0
# 588:	 name_emb_486 - 0.0
# 589:	 name_emb_487 - 0.0
# 590:	 name_emb_488 - 0.0
# 591:	 name_emb_489 - 0.0
# 592:	 name_emb_490 - 0.0
# 593:	 name_emb_491 - 0.0
# 594:	 name_emb_493 - 0.0
# 595:	 name_emb_494 - 0.0
# 596:	 name_emb_495 - 0.0
# 597:	 name_emb_496 - 0.0
# 598:	 name_emb_497 - 0.0
# 599:	 name_emb_498 - 0.0
# 600:	 name_emb_499 - 0.0
# 601:	 name_emb_501 - 0.0
# 602:	 name_emb_502 - 0.0
# 603:	 name_emb_503 - 0.0
# 604:	 name_emb_504 - 0.0
# 605:	 name_emb_505 - 0.0
# 606:	 name_emb_506 - 0.0
# 607:	 name_emb_507 - 0.0
# 608:	 name_emb_508 - 0.0
# 609:	 name_emb_509 - 0.0
# 610:	 name_emb_510 - 0.0
# 611:	 name_emb_511 - 0.0
# 612:	 name_emb_512 - 0.0
# 613:	 name_emb_513 - 0.0
# 614:	 name_emb_514 - 0.0
# 615:	 name_emb_515 - 0.0
# 616:	 name_emb_516 - 0.0
# 617:	 name_emb_517 - 0.0
# 618:	 name_emb_518 - 0.0
# 619:	 name_emb_519 - 0.0
# 620:	 name_emb_520 - 0.0
# 621:	 name_emb_521 - 0.0
# 622:	 name_emb_522 - 0.0
# 623:	 name_emb_523 - 0.0
# 624:	 name_emb_524 - 0.0
# 625:	 name_emb_525 - 0.0
# 626:	 name_emb_526 - 0.0
# 627:	 name_emb_527 - 0.0
# 628:	 name_emb_528 - 0.0
# 629:	 name_emb_529 - 0.0
# 630:	 name_emb_531 - 0.0
# 631:	 name_emb_533 - 0.0
# 632:	 name_emb_534 - 0.0
# 633:	 name_emb_535 - 0.0
# 634:	 name_emb_537 - 0.0
# 635:	 name_emb_538 - 0.0
# 636:	 name_emb_539 - 0.0
# 637:	 name_emb_540 - 0.0
# 638:	 name_emb_541 - 0.0
# 639:	 name_emb_542 - 0.0
# 640:	 name_emb_543 - 0.0
# 641:	 name_emb_545 - 0.0
# 642:	 name_emb_546 - 0.0
# 643:	 name_emb_547 - 0.0
# 644:	 name_emb_549 - 0.0
# 645:	 name_emb_550 - 0.0
# 646:	 name_emb_552 - 0.0
# 647:	 name_emb_553 - 0.0
# 648:	 name_emb_554 - 0.0
# 649:	 name_emb_555 - 0.0
# 650:	 name_emb_556 - 0.0
# 651:	 name_emb_557 - 0.0
# 652:	 name_emb_558 - 0.0
# 653:	 name_emb_560 - 0.0
# 654:	 name_emb_561 - 0.0
# 655:	 name_emb_562 - 0.0
# 656:	 name_emb_563 - 0.0
# 657:	 name_emb_564 - 0.0
# 658:	 name_emb_565 - 0.0
# 659:	 name_emb_566 - 0.0
# 660:	 name_emb_567 - 0.0
# 661:	 name_emb_568 - 0.0
# 662:	 name_emb_569 - 0.0
# 663:	 name_emb_570 - 0.0
# 664:	 name_emb_571 - 0.0
# 665:	 name_emb_572 - 0.0
# 666:	 name_emb_573 - 0.0
# 667:	 name_emb_574 - 0.0
# 668:	 name_emb_575 - 0.0
# 669:	 name_emb_576 - 0.0
# 670:	 name_emb_577 - 0.0
# 671:	 name_emb_578 - 0.0
# 672:	 name_emb_580 - 0.0
# 673:	 name_emb_581 - 0.0
# 674:	 name_emb_582 - 0.0
# 675:	 name_emb_584 - 0.0
# 676:	 name_emb_585 - 0.0
# 677:	 name_emb_586 - 0.0
# 678:	 name_emb_587 - 0.0
# 679:	 name_emb_588 - 0.0
# 680:	 name_emb_589 - 0.0
# 681:	 name_emb_590 - 0.0
# 682:	 name_emb_591 - 0.0
# 683:	 name_emb_592 - 0.0
# 684:	 name_emb_594 - 0.0
# 685:	 name_emb_595 - 0.0
# 686:	 name_emb_596 - 0.0
# 687:	 name_emb_597 - 0.0
# 688:	 name_emb_598 - 0.0
# 689:	 name_emb_599 - 0.0
# 690:	 name_emb_600 - 0.0
# 691:	 name_emb_601 - 0.0
# 692:	 name_emb_602 - 0.0
# 693:	 name_emb_603 - 0.0
# 694:	 name_emb_604 - 0.0
# 695:	 name_emb_605 - 0.0
# 696:	 name_emb_606 - 0.0
# 697:	 name_emb_607 - 0.0
# 698:	 name_emb_608 - 0.0
# 699:	 name_emb_609 - 0.0
# 700:	 name_emb_610 - 0.0
# 701:	 name_emb_611 - 0.0
# 702:	 name_emb_612 - 0.0
# 703:	 name_emb_613 - 0.0
# 704:	 name_emb_614 - 0.0
# 705:	 name_emb_615 - 0.0
# 706:	 name_emb_616 - 0.0
# 707:	 name_emb_617 - 0.0
# 708:	 name_emb_618 - 0.0
# 709:	 name_emb_619 - 0.0
# 710:	 name_emb_620 - 0.0
# 711:	 name_emb_621 - 0.0
# 712:	 name_emb_623 - 0.0
# 713:	 name_emb_624 - 0.0
# 714:	 name_emb_625 - 0.0
# 715:	 name_emb_626 - 0.0
# 716:	 name_emb_627 - 0.0
# 717:	 name_emb_628 - 0.0
# 718:	 name_emb_629 - 0.0
# 719:	 name_emb_630 - 0.0
# 720:	 name_emb_631 - 0.0
# 721:	 name_emb_632 - 0.0
# 722:	 name_emb_633 - 0.0
# 723:	 name_emb_634 - 0.0
# 724:	 name_emb_635 - 0.0
# 725:	 name_emb_636 - 0.0
# 726:	 name_emb_637 - 0.0
# 727:	 name_emb_638 - 0.0
# 728:	 name_emb_639 - 0.0
# 729:	 name_emb_640 - 0.0
# 730:	 name_emb_641 - 0.0
# 731:	 name_emb_642 - 0.0
# 732:	 name_emb_643 - 0.0
# 733:	 name_emb_644 - 0.0
# 734:	 name_emb_645 - 0.0
# 735:	 name_emb_646 - 0.0
# 736:	 name_emb_647 - 0.0
# 737:	 name_emb_648 - 0.0
# 738:	 name_emb_649 - 0.0
# 739:	 name_emb_650 - 0.0
# 740:	 name_emb_651 - 0.0
# 741:	 name_emb_652 - 0.0
# 742:	 name_emb_653 - 0.0
# 743:	 name_emb_654 - 0.0
# 744:	 name_emb_655 - 0.0
# 745:	 name_emb_656 - 0.0
# 746:	 name_emb_657 - 0.0
# 747:	 name_emb_659 - 0.0
# 748:	 name_emb_660 - 0.0
# 749:	 name_emb_661 - 0.0
# 750:	 name_emb_662 - 0.0
# 751:	 name_emb_663 - 0.0
# 752:	 name_emb_664 - 0.0
# 753:	 name_emb_665 - 0.0
# 754:	 name_emb_666 - 0.0
# 755:	 name_emb_668 - 0.0
# 756:	 name_emb_669 - 0.0
# 757:	 name_emb_670 - 0.0
# 758:	 name_emb_671 - 0.0
# 759:	 name_emb_672 - 0.0
# 760:	 name_emb_673 - 0.0
# 761:	 name_emb_674 - 0.0
# 762:	 name_emb_675 - 0.0
# 763:	 name_emb_676 - 0.0
# 764:	 name_emb_677 - 0.0
# 765:	 name_emb_678 - 0.0
# 766:	 name_emb_679 - 0.0
# 767:	 name_emb_680 - 0.0
# 768:	 name_emb_681 - 0.0
# 769:	 name_emb_682 - 0.0
# 770:	 name_emb_683 - 0.0
# 771:	 name_emb_684 - 0.0
# 772:	 name_emb_685 - 0.0
# 773:	 name_emb_686 - 0.0
# 774:	 name_emb_687 - 0.0
# 775:	 name_emb_688 - 0.0
# 776:	 name_emb_691 - 0.0
# 777:	 name_emb_692 - 0.0
# 778:	 name_emb_693 - 0.0
# 779:	 name_emb_694 - 0.0
# 780:	 name_emb_695 - 0.0
# 781:	 name_emb_696 - 0.0
# 782:	 name_emb_697 - 0.0
# 783:	 name_emb_698 - 0.0
# 784:	 name_emb_699 - 0.0
# 785:	 name_emb_700 - 0.0
# 786:	 name_emb_701 - 0.0
# 787:	 name_emb_702 - 0.0
# 788:	 name_emb_704 - 0.0
# 789:	 name_emb_705 - 0.0
# 790:	 name_emb_706 - 0.0
# 791:	 name_emb_707 - 0.0
# 792:	 name_emb_708 - 0.0
# 793:	 name_emb_709 - 0.0
# 794:	 name_emb_710 - 0.0
# 795:	 name_emb_711 - 0.0
# 796:	 name_emb_712 - 0.0
# 797:	 name_emb_713 - 0.0
# 798:	 name_emb_714 - 0.0
# 799:	 name_emb_715 - 0.0
# 800:	 name_emb_716 - 0.0
# 801:	 name_emb_718 - 0.0
# 802:	 name_emb_719 - 0.0
# 803:	 name_emb_720 - 0.0
# 804:	 name_emb_721 - 0.0
# 805:	 name_emb_722 - 0.0
# 806:	 name_emb_723 - 0.0
# 807:	 name_emb_724 - 0.0
# 808:	 name_emb_725 - 0.0
# 809:	 name_emb_726 - 0.0
# 810:	 name_emb_727 - 0.0
# 811:	 name_emb_728 - 0.0
# 812:	 name_emb_729 - 0.0
# 813:	 name_emb_730 - 0.0
# 814:	 name_emb_731 - 0.0
# 815:	 name_emb_733 - 0.0
# 816:	 name_emb_734 - 0.0
# 817:	 name_emb_735 - 0.0
# 818:	 name_emb_737 - 0.0
# 819:	 name_emb_738 - 0.0
# 820:	 name_emb_739 - 0.0
# 821:	 name_emb_740 - 0.0
# 822:	 name_emb_741 - 0.0
# 823:	 name_emb_742 - 0.0
# 824:	 name_emb_743 - 0.0
# 825:	 name_emb_745 - 0.0
# 826:	 name_emb_746 - 0.0
# 827:	 name_emb_747 - 0.0
# 828:	 name_emb_748 - 0.0
# 829:	 name_emb_749 - 0.0
# 830:	 name_emb_750 - 0.0
# 831:	 name_emb_751 - 0.0
# 832:	 name_emb_752 - 0.0
# 833:	 name_emb_753 - 0.0
# 834:	 name_emb_754 - 0.0
# 835:	 name_emb_755 - 0.0
# 836:	 name_emb_756 - 0.0
# 837:	 name_emb_757 - 0.0
# 838:	 name_emb_758 - 0.0
# 839:	 name_emb_759 - 0.0
# 840:	 name_emb_760 - 0.0
# 841:	 name_emb_761 - 0.0
# 842:	 name_emb_762 - 0.0
# 843:	 name_emb_763 - 0.0
# 844:	 name_emb_764 - 0.0
# 845:	 name_emb_765 - 0.0
# 846:	 name_emb_766 - 0.0
# 847:	 name_emb_767 - 0.0
# 848:	 short_desc_emb_0 - 0.0
# 849:	 short_desc_emb_1 - 0.0
# 850:	 short_desc_emb_3 - 0.0
# 851:	 short_desc_emb_4 - 0.0
# 852:	 short_desc_emb_5 - 0.0
# 853:	 short_desc_emb_6 - 0.0
# 854:	 short_desc_emb_7 - 0.0
# 855:	 short_desc_emb_8 - 0.0
# 856:	 short_desc_emb_9 - 0.0
# 857:	 short_desc_emb_10 - 0.0
# 858:	 short_desc_emb_11 - 0.0
# 859:	 short_desc_emb_12 - 0.0
# 860:	 short_desc_emb_13 - 0.0
# 861:	 short_desc_emb_14 - 0.0
# 862:	 short_desc_emb_15 - 0.0
# 863:	 short_desc_emb_16 - 0.0
# 864:	 short_desc_emb_17 - 0.0
# 865:	 short_desc_emb_18 - 0.0
# 866:	 short_desc_emb_19 - 0.0
# 867:	 short_desc_emb_20 - 0.0
# 868:	 short_desc_emb_21 - 0.0
# 869:	 short_desc_emb_24 - 0.0
# 870:	 short_desc_emb_25 - 0.0
# 871:	 short_desc_emb_26 - 0.0
# 872:	 short_desc_emb_27 - 0.0
# 873:	 short_desc_emb_28 - 0.0
# 874:	 short_desc_emb_30 - 0.0
# 875:	 short_desc_emb_31 - 0.0
# 876:	 short_desc_emb_32 - 0.0
# 877:	 short_desc_emb_33 - 0.0
# 878:	 short_desc_emb_34 - 0.0
# 879:	 short_desc_emb_35 - 0.0
# 880:	 short_desc_emb_36 - 0.0
# 881:	 short_desc_emb_37 - 0.0
# 882:	 short_desc_emb_38 - 0.0
# 883:	 short_desc_emb_39 - 0.0
# 884:	 short_desc_emb_40 - 0.0
# 885:	 short_desc_emb_41 - 0.0
# 886:	 short_desc_emb_42 - 0.0
# 887:	 short_desc_emb_43 - 0.0
# 888:	 short_desc_emb_44 - 0.0
# 889:	 short_desc_emb_45 - 0.0
# 890:	 short_desc_emb_47 - 0.0
# 891:	 short_desc_emb_48 - 0.0
# 892:	 short_desc_emb_49 - 0.0
# 893:	 short_desc_emb_50 - 0.0
# 894:	 short_desc_emb_51 - 0.0
# 895:	 short_desc_emb_52 - 0.0
# 896:	 short_desc_emb_53 - 0.0
# 897:	 short_desc_emb_54 - 0.0
# 898:	 short_desc_emb_55 - 0.0
# 899:	 short_desc_emb_56 - 0.0
# 900:	 short_desc_emb_57 - 0.0
# 901:	 short_desc_emb_58 - 0.0
# 902:	 short_desc_emb_59 - 0.0
# 903:	 short_desc_emb_60 - 0.0
# 904:	 short_desc_emb_61 - 0.0
# 905:	 short_desc_emb_62 - 0.0
# 906:	 short_desc_emb_63 - 0.0
# 907:	 short_desc_emb_64 - 0.0
# 908:	 short_desc_emb_65 - 0.0
# 909:	 short_desc_emb_66 - 0.0
# 910:	 short_desc_emb_67 - 0.0
# 911:	 short_desc_emb_68 - 0.0
# 912:	 short_desc_emb_69 - 0.0
# 913:	 short_desc_emb_70 - 0.0
# 914:	 short_desc_emb_71 - 0.0
# 915:	 short_desc_emb_73 - 0.0
# 916:	 short_desc_emb_74 - 0.0
# 917:	 short_desc_emb_75 - 0.0
# 918:	 short_desc_emb_76 - 0.0
# 919:	 short_desc_emb_77 - 0.0
# 920:	 short_desc_emb_78 - 0.0
# 921:	 short_desc_emb_79 - 0.0
# 922:	 short_desc_emb_80 - 0.0
# 923:	 short_desc_emb_81 - 0.0
# 924:	 short_desc_emb_82 - 0.0
# 925:	 short_desc_emb_83 - 0.0
# 926:	 short_desc_emb_84 - 0.0
# 927:	 short_desc_emb_86 - 0.0
# 928:	 short_desc_emb_87 - 0.0
# 929:	 short_desc_emb_88 - 0.0
# 930:	 short_desc_emb_89 - 0.0
# 931:	 short_desc_emb_90 - 0.0
# 932:	 short_desc_emb_91 - 0.0
# 933:	 short_desc_emb_92 - 0.0
# 934:	 short_desc_emb_93 - 0.0
# 935:	 short_desc_emb_95 - 0.0
# 936:	 short_desc_emb_96 - 0.0
# 937:	 short_desc_emb_97 - 0.0
# 938:	 short_desc_emb_98 - 0.0
# 939:	 short_desc_emb_99 - 0.0
# 940:	 short_desc_emb_100 - 0.0
# 941:	 short_desc_emb_101 - 0.0
# 942:	 short_desc_emb_102 - 0.0
# 943:	 short_desc_emb_103 - 0.0
# 944:	 short_desc_emb_105 - 0.0
# 945:	 short_desc_emb_106 - 0.0
# 946:	 short_desc_emb_107 - 0.0
# 947:	 short_desc_emb_108 - 0.0
# 948:	 short_desc_emb_109 - 0.0
# 949:	 short_desc_emb_110 - 0.0
# 950:	 short_desc_emb_111 - 0.0
# 951:	 short_desc_emb_112 - 0.0
# 952:	 short_desc_emb_113 - 0.0
# 953:	 short_desc_emb_115 - 0.0
# 954:	 short_desc_emb_116 - 0.0
# 955:	 short_desc_emb_117 - 0.0
# 956:	 short_desc_emb_118 - 0.0
# 957:	 short_desc_emb_119 - 0.0
# 958:	 short_desc_emb_120 - 0.0
# 959:	 short_desc_emb_121 - 0.0
# 960:	 short_desc_emb_122 - 0.0
# 961:	 short_desc_emb_123 - 0.0
# 962:	 short_desc_emb_124 - 0.0
# 963:	 short_desc_emb_125 - 0.0
# 964:	 short_desc_emb_126 - 0.0
# 965:	 short_desc_emb_127 - 0.0
# 966:	 short_desc_emb_128 - 0.0
# 967:	 short_desc_emb_129 - 0.0
# 968:	 short_desc_emb_130 - 0.0
# 969:	 short_desc_emb_132 - 0.0
# 970:	 short_desc_emb_133 - 0.0
# 971:	 short_desc_emb_134 - 0.0
# 972:	 short_desc_emb_135 - 0.0
# 973:	 short_desc_emb_136 - 0.0
# 974:	 short_desc_emb_137 - 0.0
# 975:	 short_desc_emb_138 - 0.0
# 976:	 short_desc_emb_139 - 0.0
# 977:	 short_desc_emb_140 - 0.0
# 978:	 short_desc_emb_141 - 0.0
# 979:	 short_desc_emb_142 - 0.0
# 980:	 short_desc_emb_143 - 0.0
# 981:	 short_desc_emb_144 - 0.0
# 982:	 short_desc_emb_145 - 0.0
# 983:	 short_desc_emb_146 - 0.0
# 984:	 short_desc_emb_147 - 0.0
# 985:	 short_desc_emb_148 - 0.0
# 986:	 short_desc_emb_149 - 0.0
# 987:	 short_desc_emb_150 - 0.0
# 988:	 short_desc_emb_151 - 0.0
# 989:	 short_desc_emb_152 - 0.0
# 990:	 short_desc_emb_153 - 0.0
# 991:	 short_desc_emb_154 - 0.0
# 992:	 short_desc_emb_155 - 0.0
# 993:	 short_desc_emb_156 - 0.0
# 994:	 short_desc_emb_157 - 0.0
# 995:	 short_desc_emb_158 - 0.0
# 996:	 short_desc_emb_159 - 0.0
# 997:	 short_desc_emb_160 - 0.0
# 998:	 short_desc_emb_161 - 0.0
# 999:	 short_desc_emb_162 - 0.0
# 1000:	 short_desc_emb_163 - 0.0
# 1001:	 short_desc_emb_164 - 0.0
# 1002:	 short_desc_emb_165 - 0.0
# 1003:	 short_desc_emb_166 - 0.0
# 1004:	 short_desc_emb_167 - 0.0
# 1005:	 short_desc_emb_168 - 0.0
# 1006:	 short_desc_emb_169 - 0.0
# 1007:	 short_desc_emb_170 - 0.0
# 1008:	 short_desc_emb_171 - 0.0
# 1009:	 short_desc_emb_172 - 0.0
# 1010:	 short_desc_emb_173 - 0.0
# 1011:	 short_desc_emb_174 - 0.0
# 1012:	 short_desc_emb_175 - 0.0
# 1013:	 short_desc_emb_176 - 0.0
# 1014:	 short_desc_emb_177 - 0.0
# 1015:	 short_desc_emb_178 - 0.0
# 1016:	 short_desc_emb_179 - 0.0
# 1017:	 short_desc_emb_180 - 0.0
# 1018:	 short_desc_emb_181 - 0.0
# 1019:	 short_desc_emb_184 - 0.0
# 1020:	 short_desc_emb_185 - 0.0
# 1021:	 short_desc_emb_186 - 0.0
# 1022:	 short_desc_emb_187 - 0.0
# 1023:	 short_desc_emb_188 - 0.0
# 1024:	 short_desc_emb_189 - 0.0
# 1025:	 short_desc_emb_190 - 0.0
# 1026:	 short_desc_emb_191 - 0.0
# 1027:	 short_desc_emb_192 - 0.0
# 1028:	 short_desc_emb_193 - 0.0
# 1029:	 short_desc_emb_195 - 0.0
# 1030:	 short_desc_emb_196 - 0.0
# 1031:	 short_desc_emb_197 - 0.0
# 1032:	 short_desc_emb_198 - 0.0
# 1033:	 short_desc_emb_199 - 0.0
# 1034:	 short_desc_emb_200 - 0.0
# 1035:	 short_desc_emb_201 - 0.0
# 1036:	 short_desc_emb_202 - 0.0
# 1037:	 short_desc_emb_203 - 0.0
# 1038:	 short_desc_emb_204 - 0.0
# 1039:	 short_desc_emb_205 - 0.0
# 1040:	 short_desc_emb_206 - 0.0
# 1041:	 short_desc_emb_207 - 0.0
# 1042:	 short_desc_emb_208 - 0.0
# 1043:	 short_desc_emb_209 - 0.0
# 1044:	 short_desc_emb_210 - 0.0
# 1045:	 short_desc_emb_211 - 0.0
# 1046:	 short_desc_emb_212 - 0.0
# 1047:	 short_desc_emb_214 - 0.0
# 1048:	 short_desc_emb_216 - 0.0
# 1049:	 short_desc_emb_217 - 0.0
# 1050:	 short_desc_emb_218 - 0.0
# 1051:	 short_desc_emb_219 - 0.0
# 1052:	 short_desc_emb_220 - 0.0
# 1053:	 short_desc_emb_221 - 0.0
# 1054:	 short_desc_emb_222 - 0.0
# 1055:	 short_desc_emb_223 - 0.0
# 1056:	 short_desc_emb_225 - 0.0
# 1057:	 short_desc_emb_226 - 0.0
# 1058:	 short_desc_emb_227 - 0.0
# 1059:	 short_desc_emb_228 - 0.0
# 1060:	 short_desc_emb_229 - 0.0
# 1061:	 short_desc_emb_230 - 0.0
# 1062:	 short_desc_emb_231 - 0.0
# 1063:	 short_desc_emb_232 - 0.0
# 1064:	 short_desc_emb_234 - 0.0
# 1065:	 short_desc_emb_235 - 0.0
# 1066:	 short_desc_emb_236 - 0.0
# 1067:	 short_desc_emb_237 - 0.0
# 1068:	 short_desc_emb_238 - 0.0
# 1069:	 short_desc_emb_239 - 0.0
# 1070:	 short_desc_emb_240 - 0.0
# 1071:	 short_desc_emb_241 - 0.0
# 1072:	 short_desc_emb_242 - 0.0
# 1073:	 short_desc_emb_243 - 0.0
# 1074:	 short_desc_emb_244 - 0.0
# 1075:	 short_desc_emb_245 - 0.0
# 1076:	 short_desc_emb_246 - 0.0
# 1077:	 short_desc_emb_247 - 0.0
# 1078:	 short_desc_emb_248 - 0.0
# 1079:	 short_desc_emb_249 - 0.0
# 1080:	 short_desc_emb_250 - 0.0
# 1081:	 short_desc_emb_251 - 0.0
# 1082:	 short_desc_emb_252 - 0.0
# 1083:	 short_desc_emb_253 - 0.0
# 1084:	 short_desc_emb_255 - 0.0
# 1085:	 short_desc_emb_256 - 0.0
# 1086:	 short_desc_emb_257 - 0.0
# 1087:	 short_desc_emb_258 - 0.0
# 1088:	 short_desc_emb_259 - 0.0
# 1089:	 short_desc_emb_260 - 0.0
# 1090:	 short_desc_emb_261 - 0.0
# 1091:	 short_desc_emb_262 - 0.0
# 1092:	 short_desc_emb_263 - 0.0
# 1093:	 short_desc_emb_264 - 0.0
# 1094:	 short_desc_emb_265 - 0.0
# 1095:	 short_desc_emb_266 - 0.0
# 1096:	 short_desc_emb_267 - 0.0
# 1097:	 short_desc_emb_268 - 0.0
# 1098:	 short_desc_emb_269 - 0.0
# 1099:	 short_desc_emb_270 - 0.0
# 1100:	 short_desc_emb_271 - 0.0
# 1101:	 short_desc_emb_272 - 0.0
# 1102:	 short_desc_emb_275 - 0.0
# 1103:	 short_desc_emb_276 - 0.0
# 1104:	 short_desc_emb_277 - 0.0
# 1105:	 short_desc_emb_278 - 0.0
# 1106:	 short_desc_emb_279 - 0.0
# 1107:	 short_desc_emb_280 - 0.0
# 1108:	 short_desc_emb_282 - 0.0
# 1109:	 short_desc_emb_283 - 0.0
# 1110:	 short_desc_emb_284 - 0.0
# 1111:	 short_desc_emb_285 - 0.0
# 1112:	 short_desc_emb_286 - 0.0
# 1113:	 short_desc_emb_287 - 0.0
# 1114:	 short_desc_emb_288 - 0.0
# 1115:	 short_desc_emb_289 - 0.0
# 1116:	 short_desc_emb_290 - 0.0
# 1117:	 short_desc_emb_292 - 0.0
# 1118:	 short_desc_emb_293 - 0.0
# 1119:	 short_desc_emb_294 - 0.0
# 1120:	 short_desc_emb_296 - 0.0
# 1121:	 short_desc_emb_297 - 0.0
# 1122:	 short_desc_emb_298 - 0.0
# 1123:	 short_desc_emb_299 - 0.0
# 1124:	 short_desc_emb_300 - 0.0
# 1125:	 short_desc_emb_301 - 0.0
# 1126:	 short_desc_emb_302 - 0.0
# 1127:	 short_desc_emb_303 - 0.0
# 1128:	 short_desc_emb_304 - 0.0
# 1129:	 short_desc_emb_305 - 0.0
# 1130:	 short_desc_emb_306 - 0.0
# 1131:	 short_desc_emb_307 - 0.0
# 1132:	 short_desc_emb_308 - 0.0
# 1133:	 short_desc_emb_309 - 0.0
# 1134:	 short_desc_emb_310 - 0.0
# 1135:	 short_desc_emb_311 - 0.0
# 1136:	 short_desc_emb_312 - 0.0
# 1137:	 short_desc_emb_313 - 0.0
# 1138:	 short_desc_emb_314 - 0.0
# 1139:	 short_desc_emb_315 - 0.0
# 1140:	 short_desc_emb_316 - 0.0
# 1141:	 short_desc_emb_317 - 0.0
# 1142:	 short_desc_emb_318 - 0.0
# 1143:	 short_desc_emb_319 - 0.0
# 1144:	 short_desc_emb_320 - 0.0
# 1145:	 short_desc_emb_321 - 0.0
# 1146:	 short_desc_emb_322 - 0.0
# 1147:	 short_desc_emb_323 - 0.0
# 1148:	 short_desc_emb_324 - 0.0
# 1149:	 short_desc_emb_325 - 0.0
# 1150:	 short_desc_emb_326 - 0.0
# 1151:	 short_desc_emb_327 - 0.0
# 1152:	 short_desc_emb_328 - 0.0
# 1153:	 short_desc_emb_329 - 0.0
# 1154:	 short_desc_emb_330 - 0.0
# 1155:	 short_desc_emb_331 - 0.0
# 1156:	 short_desc_emb_332 - 0.0
# 1157:	 short_desc_emb_333 - 0.0
# 1158:	 short_desc_emb_335 - 0.0
# 1159:	 short_desc_emb_336 - 0.0
# 1160:	 short_desc_emb_337 - 0.0
# 1161:	 short_desc_emb_338 - 0.0
# 1162:	 short_desc_emb_339 - 0.0
# 1163:	 short_desc_emb_340 - 0.0
# 1164:	 short_desc_emb_341 - 0.0
# 1165:	 short_desc_emb_342 - 0.0
# 1166:	 short_desc_emb_343 - 0.0
# 1167:	 short_desc_emb_344 - 0.0
# 1168:	 short_desc_emb_345 - 0.0
# 1169:	 short_desc_emb_346 - 0.0
# 1170:	 short_desc_emb_347 - 0.0
# 1171:	 short_desc_emb_348 - 0.0
# 1172:	 short_desc_emb_349 - 0.0
# 1173:	 short_desc_emb_350 - 0.0
# 1174:	 short_desc_emb_351 - 0.0
# 1175:	 short_desc_emb_352 - 0.0
# 1176:	 short_desc_emb_353 - 0.0
# 1177:	 short_desc_emb_354 - 0.0
# 1178:	 short_desc_emb_355 - 0.0
# 1179:	 short_desc_emb_356 - 0.0
# 1180:	 short_desc_emb_357 - 0.0
# 1181:	 short_desc_emb_358 - 0.0
# 1182:	 short_desc_emb_359 - 0.0
# 1183:	 short_desc_emb_360 - 0.0
# 1184:	 short_desc_emb_361 - 0.0
# 1185:	 short_desc_emb_362 - 0.0
# 1186:	 short_desc_emb_363 - 0.0
# 1187:	 short_desc_emb_364 - 0.0
# 1188:	 short_desc_emb_365 - 0.0
# 1189:	 short_desc_emb_366 - 0.0
# 1190:	 short_desc_emb_367 - 0.0
# 1191:	 short_desc_emb_368 - 0.0
# 1192:	 short_desc_emb_369 - 0.0
# 1193:	 short_desc_emb_371 - 0.0
# 1194:	 short_desc_emb_372 - 0.0
# 1195:	 short_desc_emb_373 - 0.0
# 1196:	 short_desc_emb_374 - 0.0
# 1197:	 short_desc_emb_376 - 0.0
# 1198:	 short_desc_emb_377 - 0.0
# 1199:	 short_desc_emb_378 - 0.0
# 1200:	 short_desc_emb_379 - 0.0
# 1201:	 short_desc_emb_380 - 0.0
# 1202:	 short_desc_emb_381 - 0.0
# 1203:	 short_desc_emb_382 - 0.0
# 1204:	 short_desc_emb_383 - 0.0
# 1205:	 short_desc_emb_384 - 0.0
# 1206:	 short_desc_emb_385 - 0.0
# 1207:	 short_desc_emb_386 - 0.0
# 1208:	 short_desc_emb_387 - 0.0
# 1209:	 short_desc_emb_388 - 0.0
# 1210:	 short_desc_emb_389 - 0.0
# 1211:	 short_desc_emb_390 - 0.0
# 1212:	 short_desc_emb_391 - 0.0
# 1213:	 short_desc_emb_392 - 0.0
# 1214:	 short_desc_emb_393 - 0.0
# 1215:	 short_desc_emb_394 - 0.0
# 1216:	 short_desc_emb_395 - 0.0
# 1217:	 short_desc_emb_396 - 0.0
# 1218:	 short_desc_emb_397 - 0.0
# 1219:	 short_desc_emb_398 - 0.0
# 1220:	 short_desc_emb_400 - 0.0
# 1221:	 short_desc_emb_401 - 0.0
# 1222:	 short_desc_emb_402 - 0.0
# 1223:	 short_desc_emb_403 - 0.0
# 1224:	 short_desc_emb_404 - 0.0
# 1225:	 short_desc_emb_405 - 0.0
# 1226:	 short_desc_emb_406 - 0.0
# 1227:	 short_desc_emb_407 - 0.0
# 1228:	 short_desc_emb_408 - 0.0
# 1229:	 short_desc_emb_409 - 0.0
# 1230:	 short_desc_emb_410 - 0.0
# 1231:	 short_desc_emb_411 - 0.0
# 1232:	 short_desc_emb_413 - 0.0
# 1233:	 short_desc_emb_414 - 0.0
# 1234:	 short_desc_emb_415 - 0.0
# 1235:	 short_desc_emb_417 - 0.0
# 1236:	 short_desc_emb_419 - 0.0
# 1237:	 short_desc_emb_420 - 0.0
# 1238:	 short_desc_emb_421 - 0.0
# 1239:	 short_desc_emb_422 - 0.0
# 1240:	 short_desc_emb_423 - 0.0
# 1241:	 short_desc_emb_424 - 0.0
# 1242:	 short_desc_emb_425 - 0.0
# 1243:	 short_desc_emb_426 - 0.0
# 1244:	 short_desc_emb_427 - 0.0
# 1245:	 short_desc_emb_428 - 0.0
# 1246:	 short_desc_emb_429 - 0.0
# 1247:	 short_desc_emb_430 - 0.0
# 1248:	 short_desc_emb_431 - 0.0
# 1249:	 short_desc_emb_432 - 0.0
# 1250:	 short_desc_emb_433 - 0.0
# 1251:	 short_desc_emb_434 - 0.0
# 1252:	 short_desc_emb_435 - 0.0
# 1253:	 short_desc_emb_436 - 0.0
# 1254:	 short_desc_emb_437 - 0.0
# 1255:	 short_desc_emb_438 - 0.0
# 1256:	 short_desc_emb_439 - 0.0
# 1257:	 short_desc_emb_440 - 0.0
# 1258:	 short_desc_emb_441 - 0.0
# 1259:	 short_desc_emb_442 - 0.0
# 1260:	 short_desc_emb_443 - 0.0
# 1261:	 short_desc_emb_444 - 0.0
# 1262:	 short_desc_emb_445 - 0.0
# 1263:	 short_desc_emb_446 - 0.0
# 1264:	 short_desc_emb_447 - 0.0
# 1265:	 short_desc_emb_448 - 0.0
# 1266:	 short_desc_emb_449 - 0.0
# 1267:	 short_desc_emb_450 - 0.0
# 1268:	 short_desc_emb_453 - 0.0
# 1269:	 short_desc_emb_454 - 0.0
# 1270:	 short_desc_emb_455 - 0.0
# 1271:	 short_desc_emb_456 - 0.0
# 1272:	 short_desc_emb_457 - 0.0
# 1273:	 short_desc_emb_460 - 0.0
# 1274:	 short_desc_emb_461 - 0.0
# 1275:	 short_desc_emb_462 - 0.0
# 1276:	 short_desc_emb_463 - 0.0
# 1277:	 short_desc_emb_464 - 0.0
# 1278:	 short_desc_emb_465 - 0.0
# 1279:	 short_desc_emb_466 - 0.0
# 1280:	 short_desc_emb_467 - 0.0
# 1281:	 short_desc_emb_468 - 0.0
# 1282:	 short_desc_emb_469 - 0.0
# 1283:	 short_desc_emb_470 - 0.0
# 1284:	 short_desc_emb_471 - 0.0
# 1285:	 short_desc_emb_472 - 0.0
# 1286:	 short_desc_emb_473 - 0.0
# 1287:	 short_desc_emb_474 - 0.0
# 1288:	 short_desc_emb_475 - 0.0
# 1289:	 short_desc_emb_476 - 0.0
# 1290:	 short_desc_emb_477 - 0.0
# 1291:	 short_desc_emb_478 - 0.0
# 1292:	 short_desc_emb_479 - 0.0
# 1293:	 short_desc_emb_480 - 0.0
# 1294:	 short_desc_emb_481 - 0.0
# 1295:	 short_desc_emb_482 - 0.0
# 1296:	 short_desc_emb_483 - 0.0
# 1297:	 short_desc_emb_484 - 0.0
# 1298:	 short_desc_emb_485 - 0.0
# 1299:	 short_desc_emb_486 - 0.0
# 1300:	 short_desc_emb_488 - 0.0
# 1301:	 short_desc_emb_489 - 0.0
# 1302:	 short_desc_emb_490 - 0.0
# 1303:	 short_desc_emb_491 - 0.0
# 1304:	 short_desc_emb_492 - 0.0
# 1305:	 short_desc_emb_493 - 0.0
# 1306:	 short_desc_emb_494 - 0.0
# 1307:	 short_desc_emb_495 - 0.0
# 1308:	 short_desc_emb_496 - 0.0
# 1309:	 short_desc_emb_497 - 0.0
# 1310:	 short_desc_emb_498 - 0.0
# 1311:	 short_desc_emb_499 - 0.0
# 1312:	 short_desc_emb_500 - 0.0
# 1313:	 short_desc_emb_501 - 0.0
# 1314:	 short_desc_emb_502 - 0.0
# 1315:	 short_desc_emb_503 - 0.0
# 1316:	 short_desc_emb_504 - 0.0
# 1317:	 short_desc_emb_505 - 0.0
# 1318:	 short_desc_emb_506 - 0.0
# 1319:	 short_desc_emb_508 - 0.0
# 1320:	 short_desc_emb_509 - 0.0
# 1321:	 short_desc_emb_510 - 0.0
# 1322:	 short_desc_emb_511 - 0.0
# 1323:	 short_desc_emb_512 - 0.0
# 1324:	 short_desc_emb_513 - 0.0
# 1325:	 short_desc_emb_514 - 0.0
# 1326:	 short_desc_emb_515 - 0.0
# 1327:	 short_desc_emb_516 - 0.0
# 1328:	 short_desc_emb_517 - 0.0
# 1329:	 short_desc_emb_518 - 0.0
# 1330:	 short_desc_emb_519 - 0.0
# 1331:	 short_desc_emb_520 - 0.0
# 1332:	 short_desc_emb_521 - 0.0
# 1333:	 short_desc_emb_522 - 0.0
# 1334:	 short_desc_emb_523 - 0.0
# 1335:	 short_desc_emb_524 - 0.0
# 1336:	 short_desc_emb_525 - 0.0
# 1337:	 short_desc_emb_526 - 0.0
# 1338:	 short_desc_emb_527 - 0.0
# 1339:	 short_desc_emb_528 - 0.0
# 1340:	 short_desc_emb_529 - 0.0
# 1341:	 short_desc_emb_532 - 0.0
# 1342:	 short_desc_emb_533 - 0.0
# 1343:	 short_desc_emb_534 - 0.0
# 1344:	 short_desc_emb_535 - 0.0
# 1345:	 short_desc_emb_536 - 0.0
# 1346:	 short_desc_emb_537 - 0.0
# 1347:	 short_desc_emb_539 - 0.0
# 1348:	 short_desc_emb_540 - 0.0
# 1349:	 short_desc_emb_541 - 0.0
# 1350:	 short_desc_emb_542 - 0.0
# 1351:	 short_desc_emb_543 - 0.0
# 1352:	 short_desc_emb_544 - 0.0
# 1353:	 short_desc_emb_545 - 0.0
# 1354:	 short_desc_emb_546 - 0.0
# 1355:	 short_desc_emb_547 - 0.0
# 1356:	 short_desc_emb_548 - 0.0
# 1357:	 short_desc_emb_549 - 0.0
# 1358:	 short_desc_emb_550 - 0.0
# 1359:	 short_desc_emb_551 - 0.0
# 1360:	 short_desc_emb_552 - 0.0
# 1361:	 short_desc_emb_553 - 0.0
# 1362:	 short_desc_emb_554 - 0.0
# 1363:	 short_desc_emb_555 - 0.0
# 1364:	 short_desc_emb_556 - 0.0
# 1365:	 short_desc_emb_557 - 0.0
# 1366:	 short_desc_emb_558 - 0.0
# 1367:	 short_desc_emb_560 - 0.0
# 1368:	 short_desc_emb_561 - 0.0
# 1369:	 short_desc_emb_563 - 0.0
# 1370:	 short_desc_emb_564 - 0.0
# 1371:	 short_desc_emb_565 - 0.0
# 1372:	 short_desc_emb_566 - 0.0
# 1373:	 short_desc_emb_568 - 0.0
# 1374:	 short_desc_emb_569 - 0.0
# 1375:	 short_desc_emb_570 - 0.0
# 1376:	 short_desc_emb_572 - 0.0
# 1377:	 short_desc_emb_573 - 0.0
# 1378:	 short_desc_emb_574 - 0.0
# 1379:	 short_desc_emb_575 - 0.0
# 1380:	 short_desc_emb_576 - 0.0
# 1381:	 short_desc_emb_577 - 0.0
# 1382:	 short_desc_emb_578 - 0.0
# 1383:	 short_desc_emb_579 - 0.0
# 1384:	 short_desc_emb_580 - 0.0
# 1385:	 short_desc_emb_581 - 0.0
# 1386:	 short_desc_emb_582 - 0.0
# 1387:	 short_desc_emb_583 - 0.0
# 1388:	 short_desc_emb_584 - 0.0
# 1389:	 short_desc_emb_585 - 0.0
# 1390:	 short_desc_emb_586 - 0.0
# 1391:	 short_desc_emb_587 - 0.0
# 1392:	 short_desc_emb_588 - 0.0
# 1393:	 short_desc_emb_589 - 0.0
# 1394:	 short_desc_emb_590 - 0.0
# 1395:	 short_desc_emb_591 - 0.0
# 1396:	 short_desc_emb_592 - 0.0
# 1397:	 short_desc_emb_593 - 0.0
# 1398:	 short_desc_emb_594 - 0.0
# 1399:	 short_desc_emb_595 - 0.0
# 1400:	 short_desc_emb_596 - 0.0
# 1401:	 short_desc_emb_597 - 0.0
# 1402:	 short_desc_emb_598 - 0.0
# 1403:	 short_desc_emb_599 - 0.0
# 1404:	 short_desc_emb_600 - 0.0
# 1405:	 short_desc_emb_601 - 0.0
# 1406:	 short_desc_emb_602 - 0.0
# 1407:	 short_desc_emb_604 - 0.0
# 1408:	 short_desc_emb_605 - 0.0
# 1409:	 short_desc_emb_607 - 0.0
# 1410:	 short_desc_emb_608 - 0.0
# 1411:	 short_desc_emb_609 - 0.0
# 1412:	 short_desc_emb_610 - 0.0
# 1413:	 short_desc_emb_611 - 0.0
# 1414:	 short_desc_emb_612 - 0.0
# 1415:	 short_desc_emb_613 - 0.0
# 1416:	 short_desc_emb_614 - 0.0
# 1417:	 short_desc_emb_615 - 0.0
# 1418:	 short_desc_emb_616 - 0.0
# 1419:	 short_desc_emb_617 - 0.0
# 1420:	 short_desc_emb_618 - 0.0
# 1421:	 short_desc_emb_619 - 0.0
# 1422:	 short_desc_emb_620 - 0.0
# 1423:	 short_desc_emb_621 - 0.0
# 1424:	 short_desc_emb_622 - 0.0
# 1425:	 short_desc_emb_623 - 0.0
# 1426:	 short_desc_emb_624 - 0.0
# 1427:	 short_desc_emb_625 - 0.0
# 1428:	 short_desc_emb_626 - 0.0
# 1429:	 short_desc_emb_627 - 0.0
# 1430:	 short_desc_emb_628 - 0.0
# 1431:	 short_desc_emb_629 - 0.0
# 1432:	 short_desc_emb_630 - 0.0
# 1433:	 short_desc_emb_631 - 0.0
# 1434:	 short_desc_emb_632 - 0.0
# 1435:	 short_desc_emb_633 - 0.0
# 1436:	 short_desc_emb_634 - 0.0
# 1437:	 short_desc_emb_635 - 0.0
# 1438:	 short_desc_emb_636 - 0.0
# 1439:	 short_desc_emb_637 - 0.0
# 1440:	 short_desc_emb_638 - 0.0
# 1441:	 short_desc_emb_639 - 0.0
# 1442:	 short_desc_emb_640 - 0.0
# 1443:	 short_desc_emb_641 - 0.0
# 1444:	 short_desc_emb_642 - 0.0
# 1445:	 short_desc_emb_644 - 0.0
# 1446:	 short_desc_emb_645 - 0.0
# 1447:	 short_desc_emb_646 - 0.0
# 1448:	 short_desc_emb_647 - 0.0
# 1449:	 short_desc_emb_648 - 0.0
# 1450:	 short_desc_emb_649 - 0.0
# 1451:	 short_desc_emb_650 - 0.0
# 1452:	 short_desc_emb_651 - 0.0
# 1453:	 short_desc_emb_652 - 0.0
# 1454:	 short_desc_emb_653 - 0.0
# 1455:	 short_desc_emb_654 - 0.0
# 1456:	 short_desc_emb_655 - 0.0
# 1457:	 short_desc_emb_656 - 0.0
# 1458:	 short_desc_emb_657 - 0.0
# 1459:	 short_desc_emb_658 - 0.0
# 1460:	 short_desc_emb_659 - 0.0
# 1461:	 short_desc_emb_660 - 0.0
# 1462:	 short_desc_emb_661 - 0.0
# 1463:	 short_desc_emb_662 - 0.0
# 1464:	 short_desc_emb_663 - 0.0
# 1465:	 short_desc_emb_665 - 0.0
# 1466:	 short_desc_emb_666 - 0.0
# 1467:	 short_desc_emb_667 - 0.0
# 1468:	 short_desc_emb_668 - 0.0
# 1469:	 short_desc_emb_669 - 0.0
# 1470:	 short_desc_emb_670 - 0.0
# 1471:	 short_desc_emb_671 - 0.0
# 1472:	 short_desc_emb_672 - 0.0
# 1473:	 short_desc_emb_673 - 0.0
# 1474:	 short_desc_emb_674 - 0.0
# 1475:	 short_desc_emb_675 - 0.0
# 1476:	 short_desc_emb_676 - 0.0
# 1477:	 short_desc_emb_677 - 0.0
# 1478:	 short_desc_emb_678 - 0.0
# 1479:	 short_desc_emb_679 - 0.0
# 1480:	 short_desc_emb_680 - 0.0
# 1481:	 short_desc_emb_681 - 0.0
# 1482:	 short_desc_emb_682 - 0.0
# 1483:	 short_desc_emb_683 - 0.0
# 1484:	 short_desc_emb_684 - 0.0
# 1485:	 short_desc_emb_685 - 0.0
# 1486:	 short_desc_emb_686 - 0.0
# 1487:	 short_desc_emb_687 - 0.0
# 1488:	 short_desc_emb_688 - 0.0
# 1489:	 short_desc_emb_689 - 0.0
# 1490:	 short_desc_emb_690 - 0.0
# 1491:	 short_desc_emb_691 - 0.0
# 1492:	 short_desc_emb_692 - 0.0
# 1493:	 short_desc_emb_693 - 0.0
# 1494:	 short_desc_emb_694 - 0.0
# 1495:	 short_desc_emb_695 - 0.0
# 1496:	 short_desc_emb_696 - 0.0
# 1497:	 short_desc_emb_697 - 0.0
# 1498:	 short_desc_emb_698 - 0.0
# 1499:	 short_desc_emb_699 - 0.0
# 1500:	 short_desc_emb_700 - 0.0
# 1501:	 short_desc_emb_701 - 0.0
# 1502:	 short_desc_emb_702 - 0.0
# 1503:	 short_desc_emb_703 - 0.0
# 1504:	 short_desc_emb_704 - 0.0
# 1505:	 short_desc_emb_705 - 0.0
# 1506:	 short_desc_emb_706 - 0.0
# 1507:	 short_desc_emb_707 - 0.0
# 1508:	 short_desc_emb_708 - 0.0
# 1509:	 short_desc_emb_709 - 0.0
# 1510:	 short_desc_emb_710 - 0.0
# 1511:	 short_desc_emb_711 - 0.0
# 1512:	 short_desc_emb_712 - 0.0
# 1513:	 short_desc_emb_713 - 0.0
# 1514:	 short_desc_emb_714 - 0.0
# 1515:	 short_desc_emb_715 - 0.0
# 1516:	 short_desc_emb_716 - 0.0
# 1517:	 short_desc_emb_717 - 0.0
# 1518:	 short_desc_emb_718 - 0.0
# 1519:	 short_desc_emb_719 - 0.0
# 1520:	 short_desc_emb_720 - 0.0
# 1521:	 short_desc_emb_721 - 0.0
# 1522:	 short_desc_emb_722 - 0.0
# 1523:	 short_desc_emb_723 - 0.0
# 1524:	 short_desc_emb_724 - 0.0
# 1525:	 short_desc_emb_725 - 0.0
# 1526:	 short_desc_emb_726 - 0.0
# 1527:	 short_desc_emb_727 - 0.0
# 1528:	 short_desc_emb_728 - 0.0
# 1529:	 short_desc_emb_729 - 0.0
# 1530:	 short_desc_emb_730 - 0.0
# 1531:	 short_desc_emb_731 - 0.0
# 1532:	 short_desc_emb_732 - 0.0
# 1533:	 short_desc_emb_733 - 0.0
# 1534:	 short_desc_emb_734 - 0.0
# 1535:	 short_desc_emb_735 - 0.0
# 1536:	 short_desc_emb_736 - 0.0
# 1537:	 short_desc_emb_737 - 0.0
# 1538:	 short_desc_emb_738 - 0.0
# 1539:	 short_desc_emb_739 - 0.0
# 1540:	 short_desc_emb_740 - 0.0
# 1541:	 short_desc_emb_741 - 0.0
# 1542:	 short_desc_emb_742 - 0.0
# 1543:	 short_desc_emb_743 - 0.0
# 1544:	 short_desc_emb_744 - 0.0
# 1545:	 short_desc_emb_745 - 0.0
# 1546:	 short_desc_emb_746 - 0.0
# 1547:	 short_desc_emb_747 - 0.0
# 1548:	 short_desc_emb_749 - 0.0
# 1549:	 short_desc_emb_751 - 0.0
# 1550:	 short_desc_emb_752 - 0.0
# 1551:	 short_desc_emb_753 - 0.0
# 1552:	 short_desc_emb_754 - 0.0
# 1553:	 short_desc_emb_755 - 0.0
# 1554:	 short_desc_emb_756 - 0.0
# 1555:	 short_desc_emb_757 - 0.0
# 1556:	 short_desc_emb_758 - 0.0
# 1557:	 short_desc_emb_759 - 0.0
# 1558:	 short_desc_emb_760 - 0.0
# 1559:	 short_desc_emb_761 - 0.0
# 1560:	 short_desc_emb_762 - 0.0
# 1561:	 short_desc_emb_763 - 0.0
# 1562:	 short_desc_emb_764 - 0.0
# 1563:	 short_desc_emb_765 - 0.0
# 1564:	 short_desc_emb_766 - 0.0
# 1565:	 short_desc_emb_767 - 0.0
# 1566:	 long_desc_emb_0 - 0.0
# 1567:	 long_desc_emb_1 - 0.0
# 1568:	 long_desc_emb_2 - 0.0
# 1569:	 long_desc_emb_3 - 0.0
# 1570:	 long_desc_emb_4 - 0.0
# 1571:	 long_desc_emb_5 - 0.0
# 1572:	 long_desc_emb_6 - 0.0
# 1573:	 long_desc_emb_7 - 0.0
# 1574:	 long_desc_emb_8 - 0.0
# 1575:	 long_desc_emb_9 - 0.0
# 1576:	 long_desc_emb_10 - 0.0
# 1577:	 long_desc_emb_11 - 0.0
# 1578:	 long_desc_emb_12 - 0.0
# 1579:	 long_desc_emb_13 - 0.0
# 1580:	 long_desc_emb_14 - 0.0
# 1581:	 long_desc_emb_15 - 0.0
# 1582:	 long_desc_emb_16 - 0.0
# 1583:	 long_desc_emb_17 - 0.0
# 1584:	 long_desc_emb_18 - 0.0
# 1585:	 long_desc_emb_19 - 0.0
# 1586:	 long_desc_emb_20 - 0.0
# 1587:	 long_desc_emb_21 - 0.0
# 1588:	 long_desc_emb_22 - 0.0
# 1589:	 long_desc_emb_23 - 0.0
# 1590:	 long_desc_emb_24 - 0.0
# 1591:	 long_desc_emb_25 - 0.0
# 1592:	 long_desc_emb_26 - 0.0
# 1593:	 long_desc_emb_27 - 0.0
# 1594:	 long_desc_emb_28 - 0.0
# 1595:	 long_desc_emb_29 - 0.0
# 1596:	 long_desc_emb_30 - 0.0
# 1597:	 long_desc_emb_31 - 0.0
# 1598:	 long_desc_emb_32 - 0.0
# 1599:	 long_desc_emb_33 - 0.0
# 1600:	 long_desc_emb_34 - 0.0
# ...
# 1732:	 long_desc_emb_166 - 0.0
# 1733:	 long_desc_emb_167 - 0.0
# 1734:	 long_desc_emb_168 - 0.0
# 1735:	 long_desc_emb_169 - 0.0
# 1736:	 long_desc_emb_170 - 0.0
# 1737:	 long_desc_emb_171 - 0.0
# 1738:	 long_desc_emb_172 - 0.0
# 1739:	 long_desc_emb_173 - 0.0
# 1740:	 long_desc_emb_174 - 0.0
# 1741:	 long_desc_emb_175 - 0.0
# 1742:	 long_desc_emb_176 - 0.0
# 1743:	 long_desc_emb_177 - 0.0
# 1744:	 long_desc_emb_178 - 0.0
# 1745:	 long_desc_emb_179 - 0.0
# 1746:	 long_desc_emb_180 - 0.0
# 1747:	 long_desc_emb_181 - 0.0
# 1748:	 long_desc_emb_182 - 0.0
# 1749:	 long_desc_emb_183 - 0.0
# 1750:	 long_desc_emb_184 - 0.0
# 1751:	 long_desc_emb_185 - 0.0
# 1752:	 long_desc_emb_186 - 0.0
# 1753:	 long_desc_emb_187 - 0.0
# 1754:	 long_desc_emb_188 - 0.0
# 1755:	 long_desc_emb_189 - 0.0
# 1756:	 long_desc_emb_190 - 0.0
# 1757:	 long_desc_emb_191 - 0.0
# 1758:	 long_desc_emb_192 - 0.0
# 1759:	 long_desc_emb_193 - 0.0
# 1760:	 long_desc_emb_194 - 0.0
# 1761:	 long_desc_emb_195 - 0.0
# 1762:	 long_desc_emb_196 - 0.0
# 1763:	 long_desc_emb_197 - 0.0
# 1764:	 long_desc_emb_198 - 0.0
# 1765:	 long_desc_emb_199 - 0.0
# 1766:	 long_desc_emb_200 - 0.0
# 1767:	 long_desc_emb_201 - 0.0
# 1768:	 long_desc_emb_202 - 0.0
# 1769:	 long_desc_emb_203 - 0.0
# 1770:	 long_desc_emb_204 - 0.0
# 1771:	 long_desc_emb_205 - 0.0
# 1772:	 long_desc_emb_206 - 0.0
# 1773:	 long_desc_emb_207 - 0.0
# 1774:	 long_desc_emb_208 - 0.0
# 1775:	 long_desc_emb_209 - 0.0
# 1776:	 long_desc_emb_210 - 0.0
# 1777:	 long_desc_emb_211 - 0.0
# 1778:	 long_desc_emb_212 - 0.0
# 1779:	 long_desc_emb_213 - 0.0
# 1780:	 long_desc_emb_214 - 0.0
# 1781:	 long_desc_emb_215 - 0.0
# 1782:	 long_desc_emb_216 - 0.0
# 1783:	 long_desc_emb_217 - 0.0
# 1784:	 long_desc_emb_218 - 0.0
# 1785:	 long_desc_emb_219 - 0.0
# 1786:	 long_desc_emb_220 - 0.0
# 1787:	 long_desc_emb_221 - 0.0
# 1788:	 long_desc_emb_222 - 0.0
# 1789:	 long_desc_emb_223 - 0.0
# 1790:	 long_desc_emb_224 - 0.0
# 1791:	 long_desc_emb_225 - 0.0
# 1792:	 long_desc_emb_226 - 0.0
# 1793:	 long_desc_emb_227 - 0.0
# 1794:	 long_desc_emb_228 - 0.0
# 1795:	 long_desc_emb_229 - 0.0
# 1796:	 long_desc_emb_230 - 0.0
# 1797:	 long_desc_emb_231 - 0.0
# 1798:	 long_desc_emb_232 - 0.0
# 1799:	 long_desc_emb_233 - 0.0
# 1800:	 long_desc_emb_234 - 0.0
# 1801:	 long_desc_emb_235 - 0.0
# 1802:	 long_desc_emb_236 - 0.0
# 1803:	 long_desc_emb_237 - 0.0
# 1804:	 long_desc_emb_238 - 0.0
# 1805:	 long_desc_emb_239 - 0.0
# 1806:	 long_desc_emb_240 - 0.0
# 1807:	 long_desc_emb_241 - 0.0
# 1808:	 long_desc_emb_242 - 0.0
# 1809:	 long_desc_emb_243 - 0.0
# 1810:	 long_desc_emb_244 - 0.0
# 1811:	 long_desc_emb_245 - 0.0
# 1812:	 long_desc_emb_246 - 0.0
# 1813:	 long_desc_emb_247 - 0.0
# 1814:	 long_desc_emb_248 - 0.0
# 1815:	 long_desc_emb_249 - 0.0
# 1816:	 long_desc_emb_250 - 0.0
# 1817:	 long_desc_emb_251 - 0.0
# 1818:	 long_desc_emb_252 - 0.0
# 1819:	 long_desc_emb_253 - 0.0
# 1820:	 long_desc_emb_254 - 0.0
# 1821:	 long_desc_emb_255 - 0.0
# 1822:	 long_desc_emb_256 - 0.0
# 1823:	 long_desc_emb_257 - 0.0
# 1824:	 long_desc_emb_258 - 0.0
# 1825:	 long_desc_emb_259 - 0.0
# 1826:	 long_desc_emb_260 - 0.0
# 1827:	 long_desc_emb_261 - 0.0
# 1828:	 long_desc_emb_262 - 0.0
# 1829:	 long_desc_emb_263 - 0.0
# 1830:	 long_desc_emb_264 - 0.0
# 1831:	 long_desc_emb_265 - 0.0
# 1832:	 long_desc_emb_266 - 0.0
# 1833:	 long_desc_emb_267 - 0.0
# 1834:	 long_desc_emb_268 - 0.0
# 1835:	 long_desc_emb_269 - 0.0
# 1836:	 long_desc_emb_270 - 0.0
# 1837:	 long_desc_emb_271 - 0.0
# 1838:	 long_desc_emb_272 - 0.0
# 1839:	 long_desc_emb_273 - 0.0
# 1840:	 long_desc_emb_274 - 0.0
# 1841:	 long_desc_emb_275 - 0.0
# 1842:	 long_desc_emb_276 - 0.0
# 1843:	 long_desc_emb_277 - 0.0
# 1844:	 long_desc_emb_278 - 0.0
# 1845:	 long_desc_emb_279 - 0.0
# 1846:	 long_desc_emb_280 - 0.0
# 1847:	 long_desc_emb_281 - 0.0
# 1848:	 long_desc_emb_282 - 0.0
# 1849:	 long_desc_emb_283 - 0.0
# 1850:	 long_desc_emb_284 - 0.0
# 1851:	 long_desc_emb_285 - 0.0
# 1852:	 long_desc_emb_286 - 0.0
# 1853:	 long_desc_emb_287 - 0.0
# 1854:	 long_desc_emb_288 - 0.0
# 1855:	 long_desc_emb_289 - 0.0
# 1856:	 long_desc_emb_290 - 0.0
# 1857:	 long_desc_emb_291 - 0.0
# 1858:	 long_desc_emb_292 - 0.0
# 1859:	 long_desc_emb_293 - 0.0
# 1860:	 long_desc_emb_294 - 0.0
# 1861:	 long_desc_emb_295 - 0.0
# 1862:	 long_desc_emb_296 - 0.0
# 1863:	 long_desc_emb_297 - 0.0
# 1864:	 long_desc_emb_298 - 0.0
# 1865:	 long_desc_emb_299 - 0.0
# 1866:	 long_desc_emb_300 - 0.0
# 1867:	 long_desc_emb_301 - 0.0
# 1868:	 long_desc_emb_302 - 0.0
# 1869:	 long_desc_emb_303 - 0.0
# 1870:	 long_desc_emb_304 - 0.0
# 1871:	 long_desc_emb_305 - 0.0
# 1872:	 long_desc_emb_306 - 0.0
# 1873:	 long_desc_emb_307 - 0.0
# 1874:	 long_desc_emb_308 - 0.0
# 1875:	 long_desc_emb_309 - 0.0
# 1876:	 long_desc_emb_310 - 0.0
# 1877:	 long_desc_emb_311 - 0.0
# 1878:	 long_desc_emb_312 - 0.0
# 1879:	 long_desc_emb_313 - 0.0
# 1880:	 long_desc_emb_314 - 0.0
# 1881:	 long_desc_emb_315 - 0.0
# 1882:	 long_desc_emb_316 - 0.0
# 1883:	 long_desc_emb_317 - 0.0
# 1884:	 long_desc_emb_318 - 0.0
# 1885:	 long_desc_emb_319 - 0.0
# 1886:	 long_desc_emb_320 - 0.0
# 1887:	 long_desc_emb_321 - 0.0
# 1888:	 long_desc_emb_322 - 0.0
# 1889:	 long_desc_emb_323 - 0.0
# 1890:	 long_desc_emb_324 - 0.0
# 1891:	 long_desc_emb_325 - 0.0
# 1892:	 long_desc_emb_326 - 0.0
# 1893:	 long_desc_emb_327 - 0.0
# 1894:	 long_desc_emb_328 - 0.0
# 1895:	 long_desc_emb_329 - 0.0
# 1896:	 long_desc_emb_330 - 0.0
# 1897:	 long_desc_emb_331 - 0.0
# 1898:	 long_desc_emb_332 - 0.0
# 1899:	 long_desc_emb_333 - 0.0
# 1900:	 long_desc_emb_334 - 0.0
# 1901:	 long_desc_emb_335 - 0.0
# 1902:	 long_desc_emb_336 - 0.0
# 1903:	 long_desc_emb_337 - 0.0
# 1904:	 long_desc_emb_338 - 0.0
# 1905:	 long_desc_emb_339 - 0.0
# 1906:	 long_desc_emb_340 - 0.0
# 1907:	 long_desc_emb_341 - 0.0
# 1908:	 long_desc_emb_342 - 0.0
# 1909:	 long_desc_emb_343 - 0.0
# 1910:	 long_desc_emb_344 - 0.0
# 1911:	 long_desc_emb_345 - 0.0
# 1912:	 long_desc_emb_346 - 0.0
# 1913:	 long_desc_emb_347 - 0.0
# 1914:	 long_desc_emb_348 - 0.0
# 1915:	 long_desc_emb_349 - 0.0
# 1916:	 long_desc_emb_350 - 0.0
# 1917:	 long_desc_emb_351 - 0.0
# 1918:	 long_desc_emb_352 - 0.0
# 1919:	 long_desc_emb_353 - 0.0
# 1920:	 long_desc_emb_354 - 0.0
# 1921:	 long_desc_emb_355 - 0.0
# 1922:	 long_desc_emb_356 - 0.0
# 1923:	 long_desc_emb_357 - 0.0
# 1924:	 long_desc_emb_358 - 0.0
# 1925:	 long_desc_emb_359 - 0.0
# 1926:	 long_desc_emb_360 - 0.0
# 1927:	 long_desc_emb_361 - 0.0
# 1928:	 long_desc_emb_362 - 0.0
# 1929:	 long_desc_emb_363 - 0.0
# 1930:	 long_desc_emb_364 - 0.0
# 1931:	 long_desc_emb_365 - 0.0
# 1932:	 long_desc_emb_366 - 0.0
# 1933:	 long_desc_emb_367 - 0.0
# 1934:	 long_desc_emb_368 - 0.0
# 1935:	 long_desc_emb_369 - 0.0
# 1936:	 long_desc_emb_370 - 0.0
# 1937:	 long_desc_emb_371 - 0.0
# 1938:	 long_desc_emb_372 - 0.0
# 1939:	 long_desc_emb_373 - 0.0
# 1940:	 long_desc_emb_374 - 0.0
# 1941:	 long_desc_emb_375 - 0.0
# 1942:	 long_desc_emb_376 - 0.0
# 1943:	 long_desc_emb_377 - 0.0
# 1944:	 long_desc_emb_378 - 0.0
# 1945:	 long_desc_emb_379 - 0.0
# 1946:	 long_desc_emb_380 - 0.0
# 1947:	 long_desc_emb_381 - 0.0
# 1948:	 long_desc_emb_382 - 0.0
# 1949:	 long_desc_emb_383 - 0.0
# 1950:	 tags_emb_0 - 0.0
# 1951:	 tags_emb_1 - 0.0
# 1952:	 tags_emb_2 - 0.0
# 1953:	 tags_emb_3 - 0.0
# 1954:	 tags_emb_4 - 0.0
# 1955:	 tags_emb_5 - 0.0
# 1956:	 tags_emb_6 - 0.0
# 1957:	 tags_emb_7 - 0.0
# 1958:	 tags_emb_8 - 0.0
# 1959:	 tags_emb_9 - 0.0
# 1960:	 tags_emb_10 - 0.0
# 1961:	 tags_emb_11 - 0.0
# 1962:	 tags_emb_12 - 0.0
# 1963:	 tags_emb_14 - 0.0
# 1964:	 tags_emb_15 - 0.0
# 1965:	 tags_emb_16 - 0.0
# 1966:	 tags_emb_17 - 0.0
# 1967:	 tags_emb_18 - 0.0
# 1968:	 tags_emb_19 - 0.0
# 1969:	 tags_emb_20 - 0.0
# 1970:	 tags_emb_21 - 0.0
# 1971:	 tags_emb_22 - 0.0
# 1972:	 tags_emb_23 - 0.0
# 1973:	 tags_emb_24 - 0.0
# 1974:	 tags_emb_26 - 0.0
# 1975:	 tags_emb_27 - 0.0
# 1976:	 tags_emb_28 - 0.0
# 1977:	 tags_emb_29 - 0.0
# 1978:	 tags_emb_30 - 0.0
# 1979:	 tags_emb_31 - 0.0
# 1980:	 tags_emb_32 - 0.0
# 1981:	 tags_emb_33 - 0.0
# 1982:	 tags_emb_34 - 0.0
# 1983:	 tags_emb_35 - 0.0
# 1984:	 tags_emb_36 - 0.0
# 1985:	 tags_emb_37 - 0.0
# 1986:	 tags_emb_38 - 0.0
# 1987:	 tags_emb_39 - 0.0
# 1988:	 tags_emb_40 - 0.0
# 1989:	 tags_emb_41 - 0.0
# 1990:	 tags_emb_42 - 0.0
# 1991:	 tags_emb_43 - 0.0
# 1992:	 tags_emb_44 - 0.0
# 1993:	 tags_emb_45 - 0.0
# 1994:	 tags_emb_46 - 0.0
# 1995:	 tags_emb_47 - 0.0
# 1996:	 tags_emb_48 - 0.0
# 1997:	 tags_emb_49 - 0.0
# 1998:	 tags_emb_50 - 0.0
# 1999:	 tags_emb_51 - 0.0
# 2000:	 tags_emb_52 - 0.0
# 2001:	 tags_emb_53 - 0.0
# 2002:	 tags_emb_54 - 0.0
# 2003:	 tags_emb_55 - 0.0
# 2004:	 tags_emb_56 - 0.0
# 2005:	 tags_emb_57 - 0.0
# 2006:	 tags_emb_58 - 0.0
# 2007:	 tags_emb_59 - 0.0
# 2008:	 tags_emb_60 - 0.0
# 2009:	 tags_emb_61 - 0.0
# 2010:	 tags_emb_62 - 0.0
# 2011:	 tags_emb_63 - 0.0
# 2012:	 tags_emb_64 - 0.0
# 2013:	 tags_emb_65 - 0.0
# 2014:	 tags_emb_66 - 0.0
# 2015:	 tags_emb_67 - 0.0
# 2016:	 tags_emb_68 - 0.0
# 2017:	 tags_emb_69 - 0.0
# 2018:	 tags_emb_70 - 0.0
# 2019:	 tags_emb_71 - 0.0
# 2020:	 tags_emb_72 - 0.0
# 2021:	 tags_emb_73 - 0.0
# 2022:	 tags_emb_74 - 0.0
# 2023:	 tags_emb_75 - 0.0
# 2024:	 tags_emb_76 - 0.0
# 2025:	 tags_emb_77 - 0.0
# 2026:	 tags_emb_78 - 0.0
# 2027:	 tags_emb_79 - 0.0
# 2028:	 tags_emb_80 - 0.0
# 2029:	 tags_emb_81 - 0.0
# 2030:	 tags_emb_82 - 0.0
# 2031:	 tags_emb_83 - 0.0
# 2032:	 tags_emb_84 - 0.0
# 2033:	 tags_emb_85 - 0.0
# 2034:	 tags_emb_86 - 0.0
# 2035:	 tags_emb_87 - 0.0
# 2036:	 tags_emb_88 - 0.0
# 2037:	 tags_emb_89 - 0.0
# 2038:	 tags_emb_90 - 0.0
# 2039:	 tags_emb_91 - 0.0
# 2040:	 tags_emb_92 - 0.0
# 2041:	 tags_emb_93 - 0.0
# 2042:	 tags_emb_94 - 0.0
# 2043:	 tags_emb_95 - 0.0
# 2044:	 tags_emb_96 - 0.0
# 2045:	 tags_emb_97 - 0.0
# 2046:	 tags_emb_98 - 0.0
# 2047:	 tags_emb_99 - 0.0
# 2048:	 tags_emb_100 - 0.0
# 2049:	 tags_emb_101 - 0.0
# 2050:	 tags_emb_102 - 0.0
# 2051:	 tags_emb_103 - 0.0
# 2052:	 tags_emb_104 - 0.0
# 2053:	 tags_emb_105 - 0.0
# 2054:	 tags_emb_106 - 0.0
# 2055:	 tags_emb_107 - 0.0
# 2056:	 tags_emb_108 - 0.0
# 2057:	 tags_emb_109 - 0.0
# 2058:	 tags_emb_110 - 0.0
# 2059:	 tags_emb_111 - 0.0
# 2060:	 tags_emb_112 - 0.0
# 2061:	 tags_emb_113 - 0.0
# 2062:	 tags_emb_114 - 0.0
# 2063:	 tags_emb_115 - 0.0
# 2064:	 tags_emb_116 - 0.0
# 2065:	 tags_emb_117 - 0.0
# 2066:	 tags_emb_119 - 0.0
# 2067:	 tags_emb_120 - 0.0
# 2068:	 tags_emb_121 - 0.0
# 2069:	 tags_emb_122 - 0.0
# 2070:	 tags_emb_123 - 0.0
# 2071:	 tags_emb_124 - 0.0
# 2072:	 tags_emb_125 - 0.0
# 2073:	 tags_emb_127 - 0.0
# 2074:	 tags_emb_128 - 0.0
# 2075:	 tags_emb_129 - 0.0
# 2076:	 tags_emb_130 - 0.0
# 2077:	 tags_emb_131 - 0.0
# 2078:	 tags_emb_132 - 0.0
# 2079:	 tags_emb_133 - 0.0
# 2080:	 tags_emb_134 - 0.0
# 2081:	 tags_emb_135 - 0.0
# 2082:	 tags_emb_136 - 0.0
# 2083:	 tags_emb_137 - 0.0
# 2084:	 tags_emb_138 - 0.0
# 2085:	 tags_emb_139 - 0.0
# 2086:	 tags_emb_141 - 0.0
# 2087:	 tags_emb_142 - 0.0
# 2088:	 tags_emb_143 - 0.0
# 2089:	 tags_emb_144 - 0.0
# 2090:	 tags_emb_145 - 0.0
# 2091:	 tags_emb_146 - 0.0
# 2092:	 tags_emb_147 - 0.0
# 2093:	 tags_emb_148 - 0.0
# 2094:	 tags_emb_149 - 0.0
# 2095:	 tags_emb_150 - 0.0
# 2096:	 tags_emb_151 - 0.0
# 2097:	 tags_emb_152 - 0.0
# 2098:	 tags_emb_153 - 0.0
# 2099:	 tags_emb_154 - 0.0
# 2100:	 tags_emb_155 - 0.0
# 2101:	 tags_emb_156 - 0.0
# 2102:	 tags_emb_157 - 0.0
# 2103:	 tags_emb_158 - 0.0
# 2104:	 tags_emb_159 - 0.0
# 2105:	 tags_emb_160 - 0.0
# 2106:	 tags_emb_161 - 0.0
# 2107:	 tags_emb_163 - 0.0
# 2108:	 tags_emb_164 - 0.0
# 2109:	 tags_emb_165 - 0.0
# 2110:	 tags_emb_166 - 0.0
# 2111:	 tags_emb_167 - 0.0
# 2112:	 tags_emb_168 - 0.0
# 2113:	 tags_emb_169 - 0.0
# 2114:	 tags_emb_170 - 0.0
# 2115:	 tags_emb_171 - 0.0
# 2116:	 tags_emb_172 - 0.0
# 2117:	 tags_emb_173 - 0.0
# 2118:	 tags_emb_174 - 0.0
# 2119:	 tags_emb_175 - 0.0
# 2120:	 tags_emb_176 - 0.0
# 2121:	 tags_emb_177 - 0.0
# 2122:	 tags_emb_178 - 0.0
# 2123:	 tags_emb_179 - 0.0
# 2124:	 tags_emb_180 - 0.0
# 2125:	 tags_emb_182 - 0.0
# 2126:	 tags_emb_183 - 0.0
# 2127:	 tags_emb_184 - 0.0
# 2128:	 tags_emb_185 - 0.0
# 2129:	 tags_emb_186 - 0.0
# 2130:	 tags_emb_187 - 0.0
# 2131:	 tags_emb_189 - 0.0
# 2132:	 tags_emb_190 - 0.0
# 2133:	 tags_emb_191 - 0.0
# 2134:	 tags_emb_192 - 0.0
# 2135:	 tags_emb_193 - 0.0
# 2136:	 tags_emb_194 - 0.0
# 2137:	 tags_emb_195 - 0.0
# 2138:	 tags_emb_196 - 0.0
# 2139:	 tags_emb_197 - 0.0
# 2140:	 tags_emb_198 - 0.0
# 2141:	 tags_emb_199 - 0.0
# 2142:	 tags_emb_200 - 0.0
# 2143:	 tags_emb_201 - 0.0
# 2144:	 tags_emb_202 - 0.0
# 2145:	 tags_emb_203 - 0.0
# 2146:	 tags_emb_204 - 0.0
# 2147:	 tags_emb_205 - 0.0
# 2148:	 tags_emb_207 - 0.0
# 2149:	 tags_emb_208 - 0.0
# 2150:	 tags_emb_209 - 0.0
# 2151:	 tags_emb_210 - 0.0
# 2152:	 tags_emb_212 - 0.0
# 2153:	 tags_emb_213 - 0.0
# 2154:	 tags_emb_214 - 0.0
# 2155:	 tags_emb_216 - 0.0
# 2156:	 tags_emb_217 - 0.0
# 2157:	 tags_emb_218 - 0.0
# 2158:	 tags_emb_219 - 0.0
# 2159:	 tags_emb_220 - 0.0
# 2160:	 tags_emb_222 - 0.0
# 2161:	 tags_emb_223 - 0.0
# 2162:	 tags_emb_224 - 0.0
# 2163:	 tags_emb_225 - 0.0
# 2164:	 tags_emb_226 - 0.0
# 2165:	 tags_emb_228 - 0.0
# 2166:	 tags_emb_229 - 0.0
# 2167:	 tags_emb_230 - 0.0
# 2168:	 tags_emb_231 - 0.0
# 2169:	 tags_emb_232 - 0.0
# 2170:	 tags_emb_233 - 0.0
# 2171:	 tags_emb_235 - 0.0
# 2172:	 tags_emb_236 - 0.0
# 2173:	 tags_emb_237 - 0.0
# 2174:	 tags_emb_238 - 0.0
# 2175:	 tags_emb_239 - 0.0
# 2176:	 tags_emb_240 - 0.0
# 2177:	 tags_emb_241 - 0.0
# 2178:	 tags_emb_243 - 0.0
# 2179:	 tags_emb_244 - 0.0
# 2180:	 tags_emb_245 - 0.0
# 2181:	 tags_emb_246 - 0.0
# 2182:	 tags_emb_247 - 0.0
# 2183:	 tags_emb_248 - 0.0
# 2184:	 tags_emb_249 - 0.0
# 2185:	 tags_emb_250 - 0.0
# 2186:	 tags_emb_251 - 0.0
# 2187:	 tags_emb_252 - 0.0
# 2188:	 tags_emb_253 - 0.0
# 2189:	 tags_emb_254 - 0.0
# 2190:	 tags_emb_255 - 0.0
# 2191:	 tags_emb_256 - 0.0
# 2192:	 tags_emb_257 - 0.0
# 2193:	 tags_emb_258 - 0.0
# 2194:	 tags_emb_259 - 0.0
# 2195:	 tags_emb_260 - 0.0
# 2196:	 tags_emb_261 - 0.0
# 2197:	 tags_emb_262 - 0.0
# 2198:	 tags_emb_263 - 0.0
# 2199:	 tags_emb_264 - 0.0
# 2200:	 tags_emb_265 - 0.0
# 2201:	 tags_emb_266 - 0.0
# 2202:	 tags_emb_267 - 0.0
# 2203:	 tags_emb_268 - 0.0
# 2204:	 tags_emb_269 - 0.0
# 2205:	 tags_emb_270 - 0.0
# 2206:	 tags_emb_271 - 0.0
# 2207:	 tags_emb_272 - 0.0
# 2208:	 tags_emb_273 - 0.0
# 2209:	 tags_emb_274 - 0.0
# 2210:	 tags_emb_275 - 0.0
# 2211:	 tags_emb_276 - 0.0
# 2212:	 tags_emb_277 - 0.0
# 2213:	 tags_emb_278 - 0.0
# 2214:	 tags_emb_279 - 0.0
# 2215:	 tags_emb_280 - 0.0
# 2216:	 tags_emb_282 - 0.0
# 2217:	 tags_emb_283 - 0.0
# 2218:	 tags_emb_284 - 0.0
# 2219:	 tags_emb_285 - 0.0
# 2220:	 tags_emb_287 - 0.0
# 2221:	 tags_emb_288 - 0.0
# 2222:	 tags_emb_289 - 0.0
# 2223:	 tags_emb_290 - 0.0
# 2224:	 tags_emb_291 - 0.0
# 2225:	 tags_emb_292 - 0.0
# 2226:	 tags_emb_293 - 0.0
# 2227:	 tags_emb_296 - 0.0
# 2228:	 tags_emb_297 - 0.0
# 2229:	 tags_emb_298 - 0.0
# 2230:	 tags_emb_299 - 0.0
# 2231:	 tags_emb_300 - 0.0
# 2232:	 tags_emb_301 - 0.0
# 2233:	 tags_emb_302 - 0.0
# 2234:	 tags_emb_303 - 0.0
# 2235:	 tags_emb_304 - 0.0
# 2236:	 tags_emb_305 - 0.0
# 2237:	 tags_emb_306 - 0.0
# 2238:	 tags_emb_307 - 0.0
# 2239:	 tags_emb_308 - 0.0
# 2240:	 tags_emb_309 - 0.0
# 2241:	 tags_emb_310 - 0.0
# 2242:	 tags_emb_311 - 0.0
# 2243:	 tags_emb_312 - 0.0
# 2244:	 tags_emb_313 - 0.0
# 2245:	 tags_emb_314 - 0.0
# 2246:	 tags_emb_315 - 0.0
# 2247:	 tags_emb_316 - 0.0
# 2248:	 tags_emb_317 - 0.0
# 2249:	 tags_emb_318 - 0.0
# 2250:	 tags_emb_319 - 0.0
# 2251:	 tags_emb_320 - 0.0
# 2252:	 tags_emb_321 - 0.0
# 2253:	 tags_emb_322 - 0.0
# 2254:	 tags_emb_323 - 0.0
# 2255:	 tags_emb_324 - 0.0
# 2256:	 tags_emb_325 - 0.0
# 2257:	 tags_emb_326 - 0.0
# 2258:	 tags_emb_328 - 0.0
# 2259:	 tags_emb_329 - 0.0
# 2260:	 tags_emb_330 - 0.0
# 2261:	 tags_emb_332 - 0.0
# 2262:	 tags_emb_334 - 0.0
# 2263:	 tags_emb_335 - 0.0
# 2264:	 tags_emb_336 - 0.0
# 2265:	 tags_emb_338 - 0.0
# 2266:	 tags_emb_339 - 0.0
# 2267:	 tags_emb_340 - 0.0
# 2268:	 tags_emb_341 - 0.0
# 2269:	 tags_emb_342 - 0.0
# 2270:	 tags_emb_343 - 0.0
# 2271:	 tags_emb_345 - 0.0
# 2272:	 tags_emb_346 - 0.0
# 2273:	 tags_emb_347 - 0.0
# 2274:	 tags_emb_348 - 0.0
# 2275:	 tags_emb_349 - 0.0
# 2276:	 tags_emb_350 - 0.0
# 2277:	 tags_emb_351 - 0.0
# 2278:	 tags_emb_352 - 0.0
# 2279:	 tags_emb_353 - 0.0
# 2280:	 tags_emb_354 - 0.0
# 2281:	 tags_emb_355 - 0.0
# 2282:	 tags_emb_356 - 0.0
# 2283:	 tags_emb_357 - 0.0
# 2284:	 tags_emb_358 - 0.0
# 2285:	 tags_emb_359 - 0.0
# 2286:	 tags_emb_360 - 0.0
# 2287:	 tags_emb_361 - 0.0
# 2288:	 tags_emb_362 - 0.0
# 2289:	 tags_emb_363 - 0.0
# 2290:	 tags_emb_364 - 0.0
# 2291:	 tags_emb_365 - 0.0
# 2292:	 tags_emb_366 - 0.0
# 2293:	 tags_emb_367 - 0.0
# 2294:	 tags_emb_368 - 0.0
# 2295:	 tags_emb_370 - 0.0
# 2296:	 tags_emb_371 - 0.0
# 2297:	 tags_emb_372 - 0.0
# 2298:	 tags_emb_373 - 0.0
# 2299:	 tags_emb_374 - 0.0
# 2300:	 tags_emb_375 - 0.0
# 2301:	 tags_emb_376 - 0.0
# 2302:	 tags_emb_377 - 0.0
# 2303:	 tags_emb_378 - 0.0
# 2304:	 tags_emb_379 - 0.0
# 2305:	 tags_emb_380 - 0.0
# 2306:	 tags_emb_381 - 0.0
# 2307:	 tags_emb_382 - 0.0
# 2308:	 tags_emb_383 - 0.0
