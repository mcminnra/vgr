# %%
import re

import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import GridSearchCV, cross_val_score
from xgboost import XGBRegressor

# %%
df = pd.read_csv('data/data.csv')
df = df.set_index('AppID')

df
# Out:
#          Score                                           name  recent_percent  \
# AppID
# 335300     6.0       DARK SOULS™ II: Scholar of the First Sin            83.0
# 374320     6.0                                DARK SOULS™ III            94.0
# 570940     6.0                        DARK SOULS™: REMASTERED            93.0
# 435150     6.0  Divinity: Original Sin 2 - Definitive Edition            94.0
# 427520     6.0                                       Factorio            98.0
# ...        ...                                            ...             ...
# 1536610    NaN                                        OpenTTD            94.0
# 1569090    NaN                                   Vivid Knight            92.0
# 1582510    NaN                              Mercenaries Blaze            75.0
# 1599340    NaN                                       Lost Ark            97.0
# 1656220    NaN               Lost Ark Platinum Founder's Pack             0.0
#
#          recent_count  all_percent  all_count  \
# AppID
# 335300         1886.0         86.0    43864.0
# 374320         7339.0         94.0   176926.0
# 570940          852.0         85.0    28933.0
# 435150         2043.0         95.0   108079.0
# 427520         2838.0         98.0    96196.0
# ...               ...          ...        ...
# 1536610         267.0         95.0     2812.0
# 1569090         830.0         92.0      830.0
# 1582510         150.0         75.0      150.0
# 1599340        1083.0         97.0     1083.0
# 1656220           0.0          0.0        0.0
#
#                                                 short_desc  \
# AppID
# 335300   DARK SOULS™ II: Scholar of the First Sin bring...
# 374320   Dark Souls continues to push the boundaries wi...
# 570940   Then, there was fire. Re-experience the critic...
# 435150   The critically acclaimed RPG that raised the b...
# 427520   Factorio is a game about building and creating...
# ...                                                    ...
# 1536610  OpenTTD is a business simulation game in which...
# 1569090  Vivid Knight is a roguelike adventure game in ...
# 1582510  “Mercenaries Blaze”is the 5th fantasy tactical...
# 1599340  Embark on an odyssey for the Lost Ark in a vas...
# 1656220                                                NaN
#
#                                                  long_desc  \
# AppID
# 335300   Gamers are in for a big surprise in DARK SOULS...
# 374320   Get the DARK SOULS™ III Season Pass now and ch...
# 570940   Then, there was fire. Re-experience the critic...
# 435150   The Divine is dead. The Void approaches. And t...
# 427520   is a game in which you build and maintain fact...
# ...                                                    ...
# 1536610  OpenTTD is a business simulation game in which...
# 1569090  Explore a dungeon that changes with every play...
# 1582510  A story about a corrupt kingdom and a fight fo...
# 1599340  Embark on an odyssey for the Lost Ark in a vas...
# 1656220  Enjoy Lost Ark's launch in luxurious comfort w...
#
#                                                       tags
# AppID
# 335300   ['Souls-like', 'Dark Fantasy', 'RPG', 'Difficu...
# 374320   ['Souls-like', 'Dark Fantasy', 'Difficult', 'R...
# 570940   ['Souls-like', 'Education', 'Dark Fantasy', 'A...
# 435150   ['Tactical RPG', 'Exploration', 'Story Rich', ...
# 427520   ['Automation', 'Base Building', 'Resource Mana...
# ...                                                    ...
# 1536610  ['Simulation', 'Trains', 'Building', 'Sandbox'...
# 1569090  ['Roguelike Deckbuilder', 'Difficult', 'Choice...
# 1582510  ['RPG', 'Strategy', 'Turn-Based Tactics', 'Str...
# 1599340  ['Action', 'RPG', 'MMORPG', 'Action RPG', 'Adv...
# 1656220  ['Action', 'Adventure', 'Free to Play', 'Massi...
#
# [777 rows x 9 columns]

# %%
df = df[df['name'].notnull()]

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

missing_value_df
# Out:
#                    column_name  percent_missing
# Score                    Score        91.076115
# name                      name         0.000000
# recent_percent  recent_percent         0.000000
# recent_count      recent_count         0.000000
# all_percent        all_percent         0.000000
# all_count            all_count         0.000000
# short_desc          short_desc        10.629921
# long_desc            long_desc         1.837270
# tags                      tags         0.000000

# %%
### Data Pre-process

model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
model.max_seq_length = 10000

# Remove appids that were unable to pull information and fill null
df = df[df['name'].notnull()]

# Fill Null
df['short_desc'] = df['short_desc'].fillna('')
df['long_desc'] = df['short_desc'].fillna('')
df['tags'] = df['tags'].fillna('')

# Normalize ratings cols
df['recent_percent']=(df['recent_percent']-df['recent_percent'].mean())/df['recent_percent'].std()
df['recent_count']=(df['recent_count']-df['recent_count'].mean())/df['recent_count'].std()
df['all_percent']=(df['all_percent']-df['all_percent'].mean())/df['all_percent'].std()
df['all_count']=(df['all_count']-df['all_count'].mean())/df['all_count'].std()

# Process name
# Get name embeddings
df['name_emb'] = None
for idx, sentence in zip(df.index, df['name'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'name_emb'] = sentence_emb

# Explode name_emb to multiple cols
emb_len = df['name_emb'].values[0].shape[0]
emb_cols = [f'name_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['name_emb'].tolist(), index=df.index)
df = df.drop(['name_emb'], axis=1)

# Process short_desc
# Get short_desc embeddings
df['short_desc_emb'] = None
for idx, sentence in zip(df.index, df['short_desc'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'short_desc_emb'] = sentence_emb

# Explode short_desc_emb to multiple cols
emb_len = df['short_desc_emb'].values[0].shape[0]
emb_cols = [f'short_desc_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['short_desc_emb'].tolist(), index=df.index)
df = df.drop(['short_desc_emb'], axis=1)

# Process long_desc
# Get long_desc embeddings
df['long_desc_emb'] = None
for idx, sentence in zip(df.index, df['long_desc'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'long_desc_emb'] = sentence_emb

# Explode short_desc_emb to multiple cols
emb_len = df['long_desc_emb'].values[0].shape[0]
emb_cols = [f'long_desc_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['long_desc_emb'].tolist(), index=df.index)
df = df.drop(['long_desc_emb'], axis=1)

# Process tags
# Get tags embeddings
df['tags_emb'] = None
for idx, sentence in zip(df.index, df['tags'].values):
    sentence_emb = model.encode(sentence)
    df.at[idx, 'tags_emb'] = sentence_emb

# Explode tags to multiple cols
emb_len = df['tags_emb'].values[0].shape[0]
emb_cols = [f'tags_emb_{i}' for i in range(0, emb_len)]
df[emb_cols] = pd.DataFrame(df['tags_emb'].tolist(), index=df.index)
df = df.drop(['tags_emb'], axis=1)

# Drop unneeded cols
df_proc = df.drop(['name', 'short_desc', 'long_desc', 'tags'], axis=1)

df_proc
# Out:
# /home/mcminnra/miniconda3/envs/sgr/lib/python3.9/site-packages/pandas/core/frame.py:3636: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[k1] = value[k2]
#          Score  recent_percent  recent_count  all_percent  all_count  \
# AppID
# 335300     6.0        0.119388      0.126654     0.223968   0.029267
# 374320     6.0        0.643869      1.197689     0.614615   0.618583
# 570940     6.0        0.596189     -0.076436     0.175137  -0.036860
# 435150     6.0        0.643869      0.157491     0.663446   0.313668
# 427520     6.0        0.834589      0.313638     0.809939   0.261040
# ...        ...             ...           ...          ...        ...
# 1536610    NaN        0.643869     -0.191337     0.663446  -0.152547
# 1569090    NaN        0.548509     -0.080757     0.516953  -0.161325
# 1582510    NaN       -0.262053     -0.214317    -0.313171  -0.164337
# 1599340    NaN        0.786909     -0.031065     0.761108  -0.160205
# 1656220    NaN       -3.838058     -0.243779    -3.975486  -0.165001
#
#          name_emb_0  name_emb_1  name_emb_2  name_emb_3  name_emb_4  ...  \
# AppID                                                                ...
# 335300    -0.205885    0.530513    0.019095    0.098417   -0.168850  ...
# 374320    -0.425299    0.070268    0.467150   -0.283747   -0.155813  ...
# 570940    -0.411845    0.084661    0.643239   -0.140084    0.178791  ...
# 435150    -0.083358    0.879001    0.190073   -0.143532   -0.288290  ...
# 427520    -0.203325   -0.352310    0.348856    0.072503    0.431592  ...
# ...             ...         ...         ...         ...         ...  ...
# 1536610   -0.991390   -0.133603   -0.438819    0.421941   -0.044087  ...
# 1569090    0.290014    0.133307    0.122345    0.043768    0.076412  ...
# 1582510   -0.098120    0.447348    0.058343   -0.344018    0.370707  ...
# 1599340    0.179558    0.133478    0.584903    0.291661    0.171639  ...
# 1656220   -0.504908    0.580813    0.138196    0.232518    0.339013  ...
#
#          tags_emb_374  tags_emb_375  tags_emb_376  tags_emb_377  tags_emb_378  \
# AppID
# 335300       0.115262      0.345862      0.314601      0.397895      0.191249
# 374320       0.126674      0.339611      0.323297      0.429290      0.262892
# 570940       0.225787      0.307348      0.386953      0.379711      0.068206
# 435150       0.368902      0.377223      0.195811      0.414621      0.222195
# 427520       0.362606      0.404979      0.033295     -0.065764      0.200150
# ...               ...           ...           ...           ...           ...
# 1536610      0.424816      0.414719     -0.098012      0.051488     -0.005264
# 1569090      0.056362      0.609228      0.119564      0.231422      0.050099
# 1582510      0.344954      0.644763      0.145340      0.265822     -0.108715
# 1599340      0.269069      0.345348      0.190187      0.354339      0.104349
# 1656220      0.267895      0.377920      0.187860      0.376677      0.092930
#
#          tags_emb_379  tags_emb_380  tags_emb_381  tags_emb_382  tags_emb_383
# AppID
# 335300       0.155089      0.538477     -0.224875     -0.174770      0.102378
# 374320       0.199058      0.464258     -0.147462     -0.180969      0.051385
# 570940       0.046789      0.564373     -0.161320     -0.144110      0.041049
# 435150       0.056970      0.097474      0.168953      0.013213      0.036279
# 427520       0.384024     -0.044277     -0.100570      0.045499      0.350224
# ...               ...           ...           ...           ...           ...
# 1536610      0.162055     -0.048542     -0.050706      0.006860      0.362241
# 1569090      0.187765      0.506191     -0.376130      0.170645      0.256374
# 1582510      0.220161     -0.029297     -0.116917      0.115908      0.220530
# 1599340      0.270990      0.176236     -0.248504      0.104688      0.063225
# 1656220      0.217142      0.113441     -0.224005      0.028210      0.128886
#
# [762 rows x 1541 columns]

# %%
### ML Model

# data split
df_model = df_proc[df_proc['Score'].notnull()]
X = df_model.drop(['Score'], axis=1)
y = df_model['Score']

df_pred = df_proc[df_proc['Score'].isnull()]
X_pred = df_pred.drop(['Score'], axis=1)

# Fit Model
model = XGBRegressor(
    max_depth=32,
    n_estimators=250,
    objective='reg:squarederror',
    random_state=42,
    verbosity=0,
    n_jobs=-1)
model.fit(X, y)

# Get Cross Val Score
scores = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
print(f' Avg. MSE: {scores.mean():0.4f} (+/- {scores.std():0.4f})')

# pred
y_pred = model.predict(X_pred)

df_pred = pd.DataFrame({
    'AppID': X_pred.index.values,
    'Pred Score': y_pred
}).sort_values('Pred Score', ascending=False).set_index('AppID')
df_pred = df_pred.join(df[['name']], how='left')
df_pred = df_pred[['name', 'Pred Score']]

df_pred
# Out:
#  Avg. MSE: -2.3078 (+/- 1.8037)
#                                               name  Pred Score
# AppID
# 1173820                           FINAL FANTASY VI    5.428536
# 1307550                                  Craftopia    5.380709
# 1328670             Mass Effect™ Legendary Edition    5.372001
# 320                        Half-Life 2: Deathmatch    5.317527
# 373420   Divinity: Original Sin - Enhanced Edition    5.306143
# ...                                            ...         ...
# 361420                                   ASTRONEER    2.261503
# 460950                                 Katana ZERO    2.200018
# 1536610                                    OpenTTD    2.028811
# 808090                            Bury Me, My Love    2.020130
# 220200                        Kerbal Space Program    2.002461
#
# [694 rows x 2 columns]

# %%
"""
No Name
78	588650	5.660944 - Dead Cells
411	288470	5.444581 - Fable Anniversy
642	1174180	5.382903 - RDR2
185	550	5.309083     - L4D2
376	17460	5.304587 - Mass Effect

Name
576	976730	5.124917 - Halo: MCC
627	1174180	4.943077 - RDR2
626	1172620	4.901459 - Sea of Thieves
334	391540	4.901459 - Undertale
535	812140	4.883088 - AC: Odyssey
Avg. MSE: -1.9802 (+/- 1.4576)

Pathfinder: Kingmaker - Enhanced Plus Edition	5.656024
Disco Elysium - The Final Cut	5.580381
Ghostrunner	5.534202
Divinity: Original Sin - Enhanced Edition	5.524318
The Elder Scrolls IV: Oblivion® Game of the Ye...	5.486963
"""
# Out:
# '\nNo Name\n78\t588650\t5.660944 - Dead Cells\n411\t288470\t5.444581 - Fable Anniversy\n642\t1174180\t5.382903 - RDR2\n185\t550\t5.309083     - L4D2\n376\t17460\t5.304587 - Mass Effect\n\nName\n576\t976730\t5.124917 - Halo: MCC\n627\t1174180\t4.943077 - RDR2\n626\t1172620\t4.901459 - Sea of Thieves\n334\t391540\t4.901459 - Undertale\n535\t812140\t4.883088 - AC: Odyssey\nAvg. MSE: -1.9802 (+/- 1.4576)\n\nPathfinder: Kingmaker - Enhanced Plus Edition\t5.656024\nDisco Elysium - The Final Cut\t5.580381\nGhostrunner\t5.534202\nDivinity: Original Sin - Enhanced Edition\t5.524318\nThe Elder Scrolls IV: Oblivion® Game of the Ye...\t5.486963\n'

# %%
for i , (col, imp) in enumerate(sorted(zip(X_pred.columns, model.feature_importances_), key=lambda x: x[1], reverse=True)):
    print(f'{i+1}:\t {col} - {imp}')
# Out:
# 1:	 short_desc_emb_77 - 0.2072708010673523
# 2:	 tags_emb_45 - 0.1323198825120926
# 3:	 tags_emb_2 - 0.11169445514678955
# 4:	 short_desc_emb_72 - 0.06746085733175278
# 5:	 name_emb_14 - 0.06168180704116821
# 6:	 name_emb_44 - 0.04708661511540413
# 7:	 name_emb_343 - 0.04054763913154602
# 8:	 name_emb_270 - 0.03490351513028145
# 9:	 tags_emb_331 - 0.02970220148563385
# 10:	 short_desc_emb_113 - 0.029453029856085777
# 11:	 short_desc_emb_273 - 0.028360877186059952
# 12:	 name_emb_320 - 0.027783123776316643
# 13:	 short_desc_emb_74 - 0.026059841737151146
# 14:	 short_desc_emb_144 - 0.01763145811855793
# 15:	 name_emb_246 - 0.01581518165767193
# 16:	 tags_emb_251 - 0.009064163081347942
# 17:	 short_desc_emb_183 - 0.009015262126922607
# 18:	 tags_emb_295 - 0.008626204915344715
# 19:	 name_emb_32 - 0.008284243755042553
# 20:	 short_desc_emb_76 - 0.008005697280168533
# 21:	 name_emb_300 - 0.007071197498589754
# 22:	 tags_emb_14 - 0.0067472136579453945
# 23:	 short_desc_emb_123 - 0.006734563037753105
# 24:	 short_desc_emb_3 - 0.0063844225369393826
# 25:	 tags_emb_162 - 0.006314583122730255
# 26:	 name_emb_223 - 0.004307410214096308
# 27:	 name_emb_176 - 0.004210285376757383
# 28:	 short_desc_emb_182 - 0.0032267768401652575
# 29:	 name_emb_330 - 0.003123885253444314
# 30:	 short_desc_emb_324 - 0.0025083920918405056
# 31:	 name_emb_0 - 0.002435862785205245
# 32:	 short_desc_emb_241 - 0.0020142248831689358
# 33:	 short_desc_emb_35 - 0.001826644060201943
# 34:	 name_emb_3 - 0.0017609583446756005
# 35:	 short_desc_emb_4 - 0.0016621609684079885
# 36:	 name_emb_68 - 0.0015924042090773582
# 37:	 name_emb_355 - 0.0014726528897881508
# 38:	 name_emb_324 - 0.001470249961130321
# 39:	 short_desc_emb_64 - 0.0014573639491572976
# 40:	 name_emb_2 - 0.0013671893393620849
# 41:	 tags_emb_373 - 0.0012979436432942748
# 42:	 short_desc_emb_0 - 0.0011271259281784296
# 43:	 tags_emb_219 - 0.0007872100686654449
# 44:	 short_desc_emb_202 - 0.0007455160957761109
# 45:	 name_emb_373 - 0.0006960641476325691
# 46:	 short_desc_emb_306 - 0.0006400346755981445
# 47:	 tags_emb_26 - 0.0006162113859318197
# 48:	 name_emb_18 - 0.0005788639537058771
# 49:	 recent_count - 0.0005514802760444582
# 50:	 name_emb_26 - 0.0005073867505416274
# 51:	 name_emb_4 - 0.0004993151524104178
# 52:	 name_emb_318 - 0.0004506031982600689
# 53:	 name_emb_67 - 0.0004371852264739573
# 54:	 name_emb_1 - 0.0002789816935546696
# 55:	 name_emb_229 - 0.00019502408395055681
# 56:	 name_emb_358 - 0.00019190086459275335
# 57:	 short_desc_emb_22 - 0.00018133653793483973
# 58:	 name_emb_38 - 0.00014788612315896899
# 59:	 short_desc_emb_288 - 0.0001343370386166498
# 60:	 short_desc_emb_254 - 0.0001243274164153263
# 61:	 name_emb_163 - 0.00010931464203167707
# 62:	 tags_emb_246 - 0.00010876463784370571
# 63:	 tags_emb_297 - 0.00010872113489313051
# 64:	 tags_emb_197 - 9.864667663350701e-05
# 65:	 short_desc_emb_274 - 8.234829874709249e-05
# 66:	 recent_percent - 8.160973811754957e-05
# 67:	 short_desc_emb_92 - 7.882332283770666e-05
# 68:	 name_emb_6 - 6.92275571054779e-05
# 69:	 short_desc_emb_56 - 5.731090277549811e-05
# 70:	 short_desc_emb_117 - 4.919376442558132e-05
# 71:	 tags_emb_366 - 4.529144644038752e-05
# 72:	 short_desc_emb_242 - 4.320776497479528e-05
# 73:	 name_emb_252 - 3.556980300345458e-05
# 74:	 name_emb_69 - 3.161360291414894e-05
# 75:	 tags_emb_196 - 3.14930803142488e-05
# 76:	 short_desc_emb_295 - 2.9939990781713277e-05
# 77:	 tags_emb_111 - 2.744233643170446e-05
# 78:	 short_desc_emb_9 - 2.373678216827102e-05
# 79:	 short_desc_emb_82 - 2.359124664508272e-05
# 80:	 name_emb_17 - 2.074336225632578e-05
# 81:	 name_emb_19 - 1.98697489395272e-05
# 82:	 name_emb_123 - 1.7189231584779918e-05
# 83:	 name_emb_193 - 1.6296580724883825e-05
# 84:	 name_emb_100 - 1.5374074791907333e-05
# 85:	 name_emb_342 - 1.2917357707920019e-05
# 86:	 name_emb_273 - 1.077614251698833e-05
# 87:	 name_emb_280 - 1.0391730938863475e-05
# 88:	 tags_emb_266 - 9.661309377406724e-06
# 89:	 name_emb_215 - 8.050853466556873e-06
# 90:	 name_emb_70 - 7.56511190047604e-06
# 91:	 name_emb_51 - 5.283820428303443e-06
# 92:	 name_emb_66 - 5.1661700126715004e-06
# 93:	 short_desc_emb_232 - 3.865476628561737e-06
# 94:	 name_emb_98 - 3.819166977336863e-06
# 95:	 short_desc_emb_319 - 3.3083761081798002e-06
# 96:	 name_emb_83 - 3.247288077545818e-06
# 97:	 name_emb_269 - 2.8637314244406298e-06
# 98:	 name_emb_167 - 2.8040346933266846e-06
# 99:	 short_desc_emb_225 - 2.8004476462228922e-06
# 100:	 tags_emb_77 - 2.7994094580208184e-06
# 101:	 short_desc_emb_218 - 2.720154270718922e-06
# 102:	 name_emb_147 - 2.5079289116547443e-06
# 103:	 tags_emb_106 - 2.492433850420639e-06
# 104:	 name_emb_283 - 2.4200846837629797e-06
# 105:	 name_emb_63 - 2.142563744200743e-06
# 106:	 tags_emb_140 - 2.0915958884870633e-06
# 107:	 short_desc_emb_66 - 1.8380922028882196e-06
# 108:	 name_emb_335 - 1.7187084040415357e-06
# 109:	 short_desc_emb_179 - 1.3812435781801469e-06
# 110:	 all_percent - 1.1288392443020712e-06
# 111:	 tags_emb_218 - 1.0184930943069048e-06
# 112:	 name_emb_31 - 9.012977102429431e-07
# 113:	 name_emb_135 - 8.663028552291507e-07
# 114:	 name_emb_374 - 8.534104267710063e-07
# 115:	 tags_emb_13 - 8.343794206666644e-07
# 116:	 name_emb_129 - 7.907198664725001e-07
# 117:	 name_emb_152 - 7.618056656610861e-07
# 118:	 name_emb_192 - 5.92841558955115e-07
# 119:	 short_desc_emb_380 - 5.727265488530975e-07
# 120:	 tags_emb_334 - 4.353709641691239e-07
# 121:	 tags_emb_96 - 4.3043246478191577e-07
# 122:	 name_emb_332 - 4.1969417452492053e-07
# 123:	 short_desc_emb_264 - 4.1435433217884565e-07
# 124:	 name_emb_302 - 3.835551183328789e-07
# 125:	 short_desc_emb_94 - 3.7672603525606974e-07
# 126:	 name_emb_55 - 3.625729902978492e-07
# 127:	 name_emb_8 - 3.592673465391272e-07
# 128:	 short_desc_emb_139 - 3.259139589317783e-07
# 129:	 short_desc_emb_207 - 2.5727712227308075e-07
# 130:	 name_emb_30 - 2.56842497492471e-07
# 131:	 name_emb_53 - 2.561412770774041e-07
# 132:	 short_desc_emb_90 - 2.2681555833514722e-07
# 133:	 tags_emb_314 - 2.1715928255616745e-07
# 134:	 name_emb_317 - 1.9786534721788485e-07
# 135:	 short_desc_emb_101 - 1.914865919161457e-07
# 136:	 short_desc_emb_50 - 1.8917494060133322e-07
# 137:	 name_emb_29 - 1.7458307866036193e-07
# 138:	 short_desc_emb_160 - 1.6042041295349918e-07
# 139:	 name_emb_25 - 1.4813467430485616e-07
# 140:	 tags_emb_341 - 1.4204778153725783e-07
# 141:	 tags_emb_284 - 1.295020695124549e-07
# 142:	 name_emb_36 - 1.2765505630341067e-07
# 143:	 short_desc_emb_379 - 1.1866052318509901e-07
# 144:	 name_emb_124 - 1.1852215919816445e-07
# 145:	 short_desc_emb_128 - 1.1510639552625435e-07
# 146:	 short_desc_emb_189 - 9.760075414533276e-08
# 147:	 name_emb_337 - 9.742886675212503e-08
# 148:	 short_desc_emb_224 - 8.855131738982891e-08
# 149:	 name_emb_262 - 7.584803540794383e-08
# 150:	 short_desc_emb_302 - 7.519610534245658e-08
# 151:	 name_emb_77 - 7.451132688629514e-08
# 152:	 name_emb_232 - 5.8660209134586694e-08
# 153:	 tags_emb_259 - 5.690642268518786e-08
# 154:	 name_emb_251 - 5.5403194920700116e-08
# 155:	 name_emb_136 - 5.327948926492354e-08
# 156:	 short_desc_emb_262 - 4.7183966955799406e-08
# 157:	 name_emb_260 - 4.541324472029373e-08
# 158:	 tags_emb_102 - 3.74007029790846e-08
# 159:	 tags_emb_91 - 3.2943574979071855e-08
# 160:	 name_emb_364 - 2.8963610176901966e-08
# 161:	 tags_emb_355 - 2.5947821669092264e-08
# 162:	 tags_emb_338 - 2.454676995000682e-08
# 163:	 name_emb_139 - 2.3810967419990448e-08
# 164:	 short_desc_emb_16 - 2.35937100967476e-08
# 165:	 short_desc_emb_121 - 2.2641961194835858e-08
# 166:	 tags_emb_53 - 2.212470207041406e-08
# 167:	 name_emb_294 - 2.0359964381100326e-08
# 168:	 name_emb_9 - 1.96073202118896e-08
# 169:	 short_desc_emb_245 - 1.897221579838515e-08
# 170:	 short_desc_emb_49 - 1.801192794914641e-08
# 171:	 name_emb_118 - 1.715376818367531e-08
# 172:	 short_desc_emb_97 - 1.6906589905829605e-08
# 173:	 short_desc_emb_181 - 1.6443506112295836e-08
# 174:	 short_desc_emb_307 - 1.6403634006678658e-08
# 175:	 name_emb_57 - 1.559928008987299e-08
# 176:	 all_count - 0.0
# 177:	 name_emb_5 - 0.0
# 178:	 name_emb_7 - 0.0
# 179:	 name_emb_10 - 0.0
# 180:	 name_emb_11 - 0.0
# 181:	 name_emb_12 - 0.0
# 182:	 name_emb_13 - 0.0
# 183:	 name_emb_15 - 0.0
# 184:	 name_emb_16 - 0.0
# 185:	 name_emb_20 - 0.0
# 186:	 name_emb_21 - 0.0
# 187:	 name_emb_22 - 0.0
# 188:	 name_emb_23 - 0.0
# 189:	 name_emb_24 - 0.0
# 190:	 name_emb_27 - 0.0
# 191:	 name_emb_28 - 0.0
# 192:	 name_emb_33 - 0.0
# 193:	 name_emb_34 - 0.0
# 194:	 name_emb_35 - 0.0
# 195:	 name_emb_37 - 0.0
# 196:	 name_emb_39 - 0.0
# 197:	 name_emb_40 - 0.0
# 198:	 name_emb_41 - 0.0
# 199:	 name_emb_42 - 0.0
# 200:	 name_emb_43 - 0.0
# 201:	 name_emb_45 - 0.0
# 202:	 name_emb_46 - 0.0
# 203:	 name_emb_47 - 0.0
# 204:	 name_emb_48 - 0.0
# 205:	 name_emb_49 - 0.0
# 206:	 name_emb_50 - 0.0
# 207:	 name_emb_52 - 0.0
# 208:	 name_emb_54 - 0.0
# 209:	 name_emb_56 - 0.0
# 210:	 name_emb_58 - 0.0
# 211:	 name_emb_59 - 0.0
# 212:	 name_emb_60 - 0.0
# 213:	 name_emb_61 - 0.0
# 214:	 name_emb_62 - 0.0
# 215:	 name_emb_64 - 0.0
# 216:	 name_emb_65 - 0.0
# 217:	 name_emb_71 - 0.0
# 218:	 name_emb_72 - 0.0
# 219:	 name_emb_73 - 0.0
# 220:	 name_emb_74 - 0.0
# 221:	 name_emb_75 - 0.0
# 222:	 name_emb_76 - 0.0
# 223:	 name_emb_78 - 0.0
# 224:	 name_emb_79 - 0.0
# 225:	 name_emb_80 - 0.0
# 226:	 name_emb_81 - 0.0
# 227:	 name_emb_82 - 0.0
# 228:	 name_emb_84 - 0.0
# 229:	 name_emb_85 - 0.0
# 230:	 name_emb_86 - 0.0
# 231:	 name_emb_87 - 0.0
# 232:	 name_emb_88 - 0.0
# 233:	 name_emb_89 - 0.0
# 234:	 name_emb_90 - 0.0
# 235:	 name_emb_91 - 0.0
# 236:	 name_emb_92 - 0.0
# 237:	 name_emb_93 - 0.0
# 238:	 name_emb_94 - 0.0
# 239:	 name_emb_95 - 0.0
# 240:	 name_emb_96 - 0.0
# 241:	 name_emb_97 - 0.0
# 242:	 name_emb_99 - 0.0
# 243:	 name_emb_101 - 0.0
# 244:	 name_emb_102 - 0.0
# 245:	 name_emb_103 - 0.0
# 246:	 name_emb_104 - 0.0
# 247:	 name_emb_105 - 0.0
# 248:	 name_emb_106 - 0.0
# 249:	 name_emb_107 - 0.0
# 250:	 name_emb_108 - 0.0
# 251:	 name_emb_109 - 0.0
# 252:	 name_emb_110 - 0.0
# 253:	 name_emb_111 - 0.0
# 254:	 name_emb_112 - 0.0
# 255:	 name_emb_113 - 0.0
# 256:	 name_emb_114 - 0.0
# 257:	 name_emb_115 - 0.0
# 258:	 name_emb_116 - 0.0
# 259:	 name_emb_117 - 0.0
# 260:	 name_emb_119 - 0.0
# 261:	 name_emb_120 - 0.0
# 262:	 name_emb_121 - 0.0
# 263:	 name_emb_122 - 0.0
# 264:	 name_emb_125 - 0.0
# 265:	 name_emb_126 - 0.0
# 266:	 name_emb_127 - 0.0
# 267:	 name_emb_128 - 0.0
# 268:	 name_emb_130 - 0.0
# 269:	 name_emb_131 - 0.0
# 270:	 name_emb_132 - 0.0
# 271:	 name_emb_133 - 0.0
# 272:	 name_emb_134 - 0.0
# 273:	 name_emb_137 - 0.0
# 274:	 name_emb_138 - 0.0
# 275:	 name_emb_140 - 0.0
# 276:	 name_emb_141 - 0.0
# 277:	 name_emb_142 - 0.0
# 278:	 name_emb_143 - 0.0
# 279:	 name_emb_144 - 0.0
# 280:	 name_emb_145 - 0.0
# 281:	 name_emb_146 - 0.0
# 282:	 name_emb_148 - 0.0
# 283:	 name_emb_149 - 0.0
# 284:	 name_emb_150 - 0.0
# 285:	 name_emb_151 - 0.0
# 286:	 name_emb_153 - 0.0
# 287:	 name_emb_154 - 0.0
# 288:	 name_emb_155 - 0.0
# 289:	 name_emb_156 - 0.0
# 290:	 name_emb_157 - 0.0
# 291:	 name_emb_158 - 0.0
# 292:	 name_emb_159 - 0.0
# 293:	 name_emb_160 - 0.0
# 294:	 name_emb_161 - 0.0
# 295:	 name_emb_162 - 0.0
# 296:	 name_emb_164 - 0.0
# 297:	 name_emb_165 - 0.0
# 298:	 name_emb_166 - 0.0
# 299:	 name_emb_168 - 0.0
# 300:	 name_emb_169 - 0.0
# 301:	 name_emb_170 - 0.0
# 302:	 name_emb_171 - 0.0
# 303:	 name_emb_172 - 0.0
# 304:	 name_emb_173 - 0.0
# 305:	 name_emb_174 - 0.0
# 306:	 name_emb_175 - 0.0
# 307:	 name_emb_177 - 0.0
# 308:	 name_emb_178 - 0.0
# 309:	 name_emb_179 - 0.0
# 310:	 name_emb_180 - 0.0
# 311:	 name_emb_181 - 0.0
# 312:	 name_emb_182 - 0.0
# 313:	 name_emb_183 - 0.0
# 314:	 name_emb_184 - 0.0
# 315:	 name_emb_185 - 0.0
# 316:	 name_emb_186 - 0.0
# 317:	 name_emb_187 - 0.0
# 318:	 name_emb_188 - 0.0
# 319:	 name_emb_189 - 0.0
# 320:	 name_emb_190 - 0.0
# 321:	 name_emb_191 - 0.0
# 322:	 name_emb_194 - 0.0
# 323:	 name_emb_195 - 0.0
# 324:	 name_emb_196 - 0.0
# 325:	 name_emb_197 - 0.0
# 326:	 name_emb_198 - 0.0
# 327:	 name_emb_199 - 0.0
# 328:	 name_emb_200 - 0.0
# 329:	 name_emb_201 - 0.0
# 330:	 name_emb_202 - 0.0
# 331:	 name_emb_203 - 0.0
# 332:	 name_emb_204 - 0.0
# 333:	 name_emb_205 - 0.0
# 334:	 name_emb_206 - 0.0
# 335:	 name_emb_207 - 0.0
# 336:	 name_emb_208 - 0.0
# 337:	 name_emb_209 - 0.0
# 338:	 name_emb_210 - 0.0
# 339:	 name_emb_211 - 0.0
# 340:	 name_emb_212 - 0.0
# 341:	 name_emb_213 - 0.0
# 342:	 name_emb_214 - 0.0
# 343:	 name_emb_216 - 0.0
# 344:	 name_emb_217 - 0.0
# 345:	 name_emb_218 - 0.0
# 346:	 name_emb_219 - 0.0
# 347:	 name_emb_220 - 0.0
# 348:	 name_emb_221 - 0.0
# 349:	 name_emb_222 - 0.0
# 350:	 name_emb_224 - 0.0
# 351:	 name_emb_225 - 0.0
# 352:	 name_emb_226 - 0.0
# 353:	 name_emb_227 - 0.0
# 354:	 name_emb_228 - 0.0
# 355:	 name_emb_230 - 0.0
# 356:	 name_emb_231 - 0.0
# 357:	 name_emb_233 - 0.0
# 358:	 name_emb_234 - 0.0
# 359:	 name_emb_235 - 0.0
# 360:	 name_emb_236 - 0.0
# 361:	 name_emb_237 - 0.0
# 362:	 name_emb_238 - 0.0
# 363:	 name_emb_239 - 0.0
# 364:	 name_emb_240 - 0.0
# 365:	 name_emb_241 - 0.0
# 366:	 name_emb_242 - 0.0
# 367:	 name_emb_243 - 0.0
# 368:	 name_emb_244 - 0.0
# 369:	 name_emb_245 - 0.0
# 370:	 name_emb_247 - 0.0
# 371:	 name_emb_248 - 0.0
# 372:	 name_emb_249 - 0.0
# 373:	 name_emb_250 - 0.0
# 374:	 name_emb_253 - 0.0
# 375:	 name_emb_254 - 0.0
# 376:	 name_emb_255 - 0.0
# 377:	 name_emb_256 - 0.0
# 378:	 name_emb_257 - 0.0
# 379:	 name_emb_258 - 0.0
# 380:	 name_emb_259 - 0.0
# 381:	 name_emb_261 - 0.0
# 382:	 name_emb_263 - 0.0
# 383:	 name_emb_264 - 0.0
# 384:	 name_emb_265 - 0.0
# 385:	 name_emb_266 - 0.0
# 386:	 name_emb_267 - 0.0
# 387:	 name_emb_268 - 0.0
# 388:	 name_emb_271 - 0.0
# 389:	 name_emb_272 - 0.0
# 390:	 name_emb_274 - 0.0
# 391:	 name_emb_275 - 0.0
# 392:	 name_emb_276 - 0.0
# 393:	 name_emb_277 - 0.0
# 394:	 name_emb_278 - 0.0
# 395:	 name_emb_279 - 0.0
# 396:	 name_emb_281 - 0.0
# 397:	 name_emb_282 - 0.0
# 398:	 name_emb_284 - 0.0
# 399:	 name_emb_285 - 0.0
# 400:	 name_emb_286 - 0.0
# 401:	 name_emb_287 - 0.0
# 402:	 name_emb_288 - 0.0
# 403:	 name_emb_289 - 0.0
# 404:	 name_emb_290 - 0.0
# 405:	 name_emb_291 - 0.0
# 406:	 name_emb_292 - 0.0
# 407:	 name_emb_293 - 0.0
# 408:	 name_emb_295 - 0.0
# 409:	 name_emb_296 - 0.0
# 410:	 name_emb_297 - 0.0
# 411:	 name_emb_298 - 0.0
# 412:	 name_emb_299 - 0.0
# 413:	 name_emb_301 - 0.0
# 414:	 name_emb_303 - 0.0
# 415:	 name_emb_304 - 0.0
# 416:	 name_emb_305 - 0.0
# 417:	 name_emb_306 - 0.0
# 418:	 name_emb_307 - 0.0
# 419:	 name_emb_308 - 0.0
# 420:	 name_emb_309 - 0.0
# 421:	 name_emb_310 - 0.0
# 422:	 name_emb_311 - 0.0
# 423:	 name_emb_312 - 0.0
# 424:	 name_emb_313 - 0.0
# 425:	 name_emb_314 - 0.0
# 426:	 name_emb_315 - 0.0
# 427:	 name_emb_316 - 0.0
# 428:	 name_emb_319 - 0.0
# 429:	 name_emb_321 - 0.0
# 430:	 name_emb_322 - 0.0
# 431:	 name_emb_323 - 0.0
# 432:	 name_emb_325 - 0.0
# 433:	 name_emb_326 - 0.0
# 434:	 name_emb_327 - 0.0
# 435:	 name_emb_328 - 0.0
# 436:	 name_emb_329 - 0.0
# 437:	 name_emb_331 - 0.0
# 438:	 name_emb_333 - 0.0
# 439:	 name_emb_334 - 0.0
# 440:	 name_emb_336 - 0.0
# 441:	 name_emb_338 - 0.0
# 442:	 name_emb_339 - 0.0
# 443:	 name_emb_340 - 0.0
# 444:	 name_emb_341 - 0.0
# 445:	 name_emb_344 - 0.0
# 446:	 name_emb_345 - 0.0
# 447:	 name_emb_346 - 0.0
# 448:	 name_emb_347 - 0.0
# 449:	 name_emb_348 - 0.0
# 450:	 name_emb_349 - 0.0
# 451:	 name_emb_350 - 0.0
# 452:	 name_emb_351 - 0.0
# 453:	 name_emb_352 - 0.0
# 454:	 name_emb_353 - 0.0
# 455:	 name_emb_354 - 0.0
# 456:	 name_emb_356 - 0.0
# 457:	 name_emb_357 - 0.0
# 458:	 name_emb_359 - 0.0
# 459:	 name_emb_360 - 0.0
# 460:	 name_emb_361 - 0.0
# 461:	 name_emb_362 - 0.0
# 462:	 name_emb_363 - 0.0
# 463:	 name_emb_365 - 0.0
# 464:	 name_emb_366 - 0.0
# 465:	 name_emb_367 - 0.0
# 466:	 name_emb_368 - 0.0
# 467:	 name_emb_369 - 0.0
# 468:	 name_emb_370 - 0.0
# 469:	 name_emb_371 - 0.0
# 470:	 name_emb_372 - 0.0
# 471:	 name_emb_375 - 0.0
# 472:	 name_emb_376 - 0.0
# 473:	 name_emb_377 - 0.0
# 474:	 name_emb_378 - 0.0
# 475:	 name_emb_379 - 0.0
# 476:	 name_emb_380 - 0.0
# 477:	 name_emb_381 - 0.0
# 478:	 name_emb_382 - 0.0
# 479:	 name_emb_383 - 0.0
# 480:	 short_desc_emb_1 - 0.0
# 481:	 short_desc_emb_2 - 0.0
# 482:	 short_desc_emb_5 - 0.0
# 483:	 short_desc_emb_6 - 0.0
# 484:	 short_desc_emb_7 - 0.0
# 485:	 short_desc_emb_8 - 0.0
# 486:	 short_desc_emb_10 - 0.0
# 487:	 short_desc_emb_11 - 0.0
# 488:	 short_desc_emb_12 - 0.0
# 489:	 short_desc_emb_13 - 0.0
# 490:	 short_desc_emb_14 - 0.0
# 491:	 short_desc_emb_15 - 0.0
# 492:	 short_desc_emb_17 - 0.0
# 493:	 short_desc_emb_18 - 0.0
# 494:	 short_desc_emb_19 - 0.0
# 495:	 short_desc_emb_20 - 0.0
# 496:	 short_desc_emb_21 - 0.0
# 497:	 short_desc_emb_23 - 0.0
# 498:	 short_desc_emb_24 - 0.0
# 499:	 short_desc_emb_25 - 0.0
# 500:	 short_desc_emb_26 - 0.0
# 501:	 short_desc_emb_27 - 0.0
# 502:	 short_desc_emb_28 - 0.0
# 503:	 short_desc_emb_29 - 0.0
# 504:	 short_desc_emb_30 - 0.0
# 505:	 short_desc_emb_31 - 0.0
# 506:	 short_desc_emb_32 - 0.0
# 507:	 short_desc_emb_33 - 0.0
# 508:	 short_desc_emb_34 - 0.0
# 509:	 short_desc_emb_36 - 0.0
# 510:	 short_desc_emb_37 - 0.0
# 511:	 short_desc_emb_38 - 0.0
# 512:	 short_desc_emb_39 - 0.0
# 513:	 short_desc_emb_40 - 0.0
# 514:	 short_desc_emb_41 - 0.0
# 515:	 short_desc_emb_42 - 0.0
# 516:	 short_desc_emb_43 - 0.0
# 517:	 short_desc_emb_44 - 0.0
# 518:	 short_desc_emb_45 - 0.0
# 519:	 short_desc_emb_46 - 0.0
# 520:	 short_desc_emb_47 - 0.0
# 521:	 short_desc_emb_48 - 0.0
# 522:	 short_desc_emb_51 - 0.0
# 523:	 short_desc_emb_52 - 0.0
# 524:	 short_desc_emb_53 - 0.0
# 525:	 short_desc_emb_54 - 0.0
# 526:	 short_desc_emb_55 - 0.0
# 527:	 short_desc_emb_57 - 0.0
# 528:	 short_desc_emb_58 - 0.0
# 529:	 short_desc_emb_59 - 0.0
# 530:	 short_desc_emb_60 - 0.0
# 531:	 short_desc_emb_61 - 0.0
# 532:	 short_desc_emb_62 - 0.0
# 533:	 short_desc_emb_63 - 0.0
# 534:	 short_desc_emb_65 - 0.0
# 535:	 short_desc_emb_67 - 0.0
# 536:	 short_desc_emb_68 - 0.0
# 537:	 short_desc_emb_69 - 0.0
# 538:	 short_desc_emb_70 - 0.0
# 539:	 short_desc_emb_71 - 0.0
# 540:	 short_desc_emb_73 - 0.0
# 541:	 short_desc_emb_75 - 0.0
# 542:	 short_desc_emb_78 - 0.0
# 543:	 short_desc_emb_79 - 0.0
# 544:	 short_desc_emb_80 - 0.0
# 545:	 short_desc_emb_81 - 0.0
# 546:	 short_desc_emb_83 - 0.0
# 547:	 short_desc_emb_84 - 0.0
# 548:	 short_desc_emb_85 - 0.0
# 549:	 short_desc_emb_86 - 0.0
# 550:	 short_desc_emb_87 - 0.0
# 551:	 short_desc_emb_88 - 0.0
# 552:	 short_desc_emb_89 - 0.0
# 553:	 short_desc_emb_91 - 0.0
# 554:	 short_desc_emb_93 - 0.0
# 555:	 short_desc_emb_95 - 0.0
# 556:	 short_desc_emb_96 - 0.0
# 557:	 short_desc_emb_98 - 0.0
# 558:	 short_desc_emb_99 - 0.0
# 559:	 short_desc_emb_100 - 0.0
# 560:	 short_desc_emb_102 - 0.0
# 561:	 short_desc_emb_103 - 0.0
# 562:	 short_desc_emb_104 - 0.0
# 563:	 short_desc_emb_105 - 0.0
# 564:	 short_desc_emb_106 - 0.0
# 565:	 short_desc_emb_107 - 0.0
# 566:	 short_desc_emb_108 - 0.0
# 567:	 short_desc_emb_109 - 0.0
# 568:	 short_desc_emb_110 - 0.0
# 569:	 short_desc_emb_111 - 0.0
# 570:	 short_desc_emb_112 - 0.0
# 571:	 short_desc_emb_114 - 0.0
# 572:	 short_desc_emb_115 - 0.0
# 573:	 short_desc_emb_116 - 0.0
# 574:	 short_desc_emb_118 - 0.0
# 575:	 short_desc_emb_119 - 0.0
# 576:	 short_desc_emb_120 - 0.0
# 577:	 short_desc_emb_122 - 0.0
# 578:	 short_desc_emb_124 - 0.0
# 579:	 short_desc_emb_125 - 0.0
# 580:	 short_desc_emb_126 - 0.0
# 581:	 short_desc_emb_127 - 0.0
# 582:	 short_desc_emb_129 - 0.0
# 583:	 short_desc_emb_130 - 0.0
# 584:	 short_desc_emb_131 - 0.0
# 585:	 short_desc_emb_132 - 0.0
# 586:	 short_desc_emb_133 - 0.0
# 587:	 short_desc_emb_134 - 0.0
# 588:	 short_desc_emb_135 - 0.0
# 589:	 short_desc_emb_136 - 0.0
# 590:	 short_desc_emb_137 - 0.0
# 591:	 short_desc_emb_138 - 0.0
# 592:	 short_desc_emb_140 - 0.0
# 593:	 short_desc_emb_141 - 0.0
# 594:	 short_desc_emb_142 - 0.0
# 595:	 short_desc_emb_143 - 0.0
# 596:	 short_desc_emb_145 - 0.0
# 597:	 short_desc_emb_146 - 0.0
# 598:	 short_desc_emb_147 - 0.0
# 599:	 short_desc_emb_148 - 0.0
# 600:	 short_desc_emb_149 - 0.0
# 601:	 short_desc_emb_150 - 0.0
# 602:	 short_desc_emb_151 - 0.0
# 603:	 short_desc_emb_152 - 0.0
# 604:	 short_desc_emb_153 - 0.0
# 605:	 short_desc_emb_154 - 0.0
# 606:	 short_desc_emb_155 - 0.0
# 607:	 short_desc_emb_156 - 0.0
# 608:	 short_desc_emb_157 - 0.0
# 609:	 short_desc_emb_158 - 0.0
# 610:	 short_desc_emb_159 - 0.0
# 611:	 short_desc_emb_161 - 0.0
# 612:	 short_desc_emb_162 - 0.0
# 613:	 short_desc_emb_163 - 0.0
# 614:	 short_desc_emb_164 - 0.0
# 615:	 short_desc_emb_165 - 0.0
# 616:	 short_desc_emb_166 - 0.0
# 617:	 short_desc_emb_167 - 0.0
# 618:	 short_desc_emb_168 - 0.0
# 619:	 short_desc_emb_169 - 0.0
# 620:	 short_desc_emb_170 - 0.0
# 621:	 short_desc_emb_171 - 0.0
# 622:	 short_desc_emb_172 - 0.0
# 623:	 short_desc_emb_173 - 0.0
# 624:	 short_desc_emb_174 - 0.0
# 625:	 short_desc_emb_175 - 0.0
# 626:	 short_desc_emb_176 - 0.0
# 627:	 short_desc_emb_177 - 0.0
# 628:	 short_desc_emb_178 - 0.0
# 629:	 short_desc_emb_180 - 0.0
# 630:	 short_desc_emb_184 - 0.0
# 631:	 short_desc_emb_185 - 0.0
# 632:	 short_desc_emb_186 - 0.0
# 633:	 short_desc_emb_187 - 0.0
# 634:	 short_desc_emb_188 - 0.0
# 635:	 short_desc_emb_190 - 0.0
# 636:	 short_desc_emb_191 - 0.0
# 637:	 short_desc_emb_192 - 0.0
# 638:	 short_desc_emb_193 - 0.0
# 639:	 short_desc_emb_194 - 0.0
# 640:	 short_desc_emb_195 - 0.0
# 641:	 short_desc_emb_196 - 0.0
# 642:	 short_desc_emb_197 - 0.0
# 643:	 short_desc_emb_198 - 0.0
# 644:	 short_desc_emb_199 - 0.0
# 645:	 short_desc_emb_200 - 0.0
# 646:	 short_desc_emb_201 - 0.0
# 647:	 short_desc_emb_203 - 0.0
# 648:	 short_desc_emb_204 - 0.0
# 649:	 short_desc_emb_205 - 0.0
# 650:	 short_desc_emb_206 - 0.0
# 651:	 short_desc_emb_208 - 0.0
# 652:	 short_desc_emb_209 - 0.0
# 653:	 short_desc_emb_210 - 0.0
# 654:	 short_desc_emb_211 - 0.0
# 655:	 short_desc_emb_212 - 0.0
# 656:	 short_desc_emb_213 - 0.0
# 657:	 short_desc_emb_214 - 0.0
# 658:	 short_desc_emb_215 - 0.0
# 659:	 short_desc_emb_216 - 0.0
# 660:	 short_desc_emb_217 - 0.0
# 661:	 short_desc_emb_219 - 0.0
# 662:	 short_desc_emb_220 - 0.0
# 663:	 short_desc_emb_221 - 0.0
# 664:	 short_desc_emb_222 - 0.0
# 665:	 short_desc_emb_223 - 0.0
# 666:	 short_desc_emb_226 - 0.0
# 667:	 short_desc_emb_227 - 0.0
# 668:	 short_desc_emb_228 - 0.0
# 669:	 short_desc_emb_229 - 0.0
# 670:	 short_desc_emb_230 - 0.0
# 671:	 short_desc_emb_231 - 0.0
# 672:	 short_desc_emb_233 - 0.0
# 673:	 short_desc_emb_234 - 0.0
# 674:	 short_desc_emb_235 - 0.0
# 675:	 short_desc_emb_236 - 0.0
# 676:	 short_desc_emb_237 - 0.0
# 677:	 short_desc_emb_238 - 0.0
# 678:	 short_desc_emb_239 - 0.0
# 679:	 short_desc_emb_240 - 0.0
# 680:	 short_desc_emb_243 - 0.0
# 681:	 short_desc_emb_244 - 0.0
# 682:	 short_desc_emb_246 - 0.0
# 683:	 short_desc_emb_247 - 0.0
# 684:	 short_desc_emb_248 - 0.0
# 685:	 short_desc_emb_249 - 0.0
# 686:	 short_desc_emb_250 - 0.0
# 687:	 short_desc_emb_251 - 0.0
# 688:	 short_desc_emb_252 - 0.0
# 689:	 short_desc_emb_253 - 0.0
# 690:	 short_desc_emb_255 - 0.0
# 691:	 short_desc_emb_256 - 0.0
# 692:	 short_desc_emb_257 - 0.0
# 693:	 short_desc_emb_258 - 0.0
# 694:	 short_desc_emb_259 - 0.0
# 695:	 short_desc_emb_260 - 0.0
# 696:	 short_desc_emb_261 - 0.0
# 697:	 short_desc_emb_263 - 0.0
# 698:	 short_desc_emb_265 - 0.0
# 699:	 short_desc_emb_266 - 0.0
# 700:	 short_desc_emb_267 - 0.0
# 701:	 short_desc_emb_268 - 0.0
# 702:	 short_desc_emb_269 - 0.0
# 703:	 short_desc_emb_270 - 0.0
# 704:	 short_desc_emb_271 - 0.0
# 705:	 short_desc_emb_272 - 0.0
# 706:	 short_desc_emb_275 - 0.0
# 707:	 short_desc_emb_276 - 0.0
# 708:	 short_desc_emb_277 - 0.0
# 709:	 short_desc_emb_278 - 0.0
# 710:	 short_desc_emb_279 - 0.0
# 711:	 short_desc_emb_280 - 0.0
# 712:	 short_desc_emb_281 - 0.0
# 713:	 short_desc_emb_282 - 0.0
# 714:	 short_desc_emb_283 - 0.0
# 715:	 short_desc_emb_284 - 0.0
# 716:	 short_desc_emb_285 - 0.0
# 717:	 short_desc_emb_286 - 0.0
# 718:	 short_desc_emb_287 - 0.0
# 719:	 short_desc_emb_289 - 0.0
# 720:	 short_desc_emb_290 - 0.0
# 721:	 short_desc_emb_291 - 0.0
# 722:	 short_desc_emb_292 - 0.0
# 723:	 short_desc_emb_293 - 0.0
# 724:	 short_desc_emb_294 - 0.0
# 725:	 short_desc_emb_296 - 0.0
# 726:	 short_desc_emb_297 - 0.0
# 727:	 short_desc_emb_298 - 0.0
# 728:	 short_desc_emb_299 - 0.0
# 729:	 short_desc_emb_300 - 0.0
# 730:	 short_desc_emb_301 - 0.0
# 731:	 short_desc_emb_303 - 0.0
# 732:	 short_desc_emb_304 - 0.0
# 733:	 short_desc_emb_305 - 0.0
# 734:	 short_desc_emb_308 - 0.0
# 735:	 short_desc_emb_309 - 0.0
# 736:	 short_desc_emb_310 - 0.0
# 737:	 short_desc_emb_311 - 0.0
# 738:	 short_desc_emb_312 - 0.0
# 739:	 short_desc_emb_313 - 0.0
# 740:	 short_desc_emb_314 - 0.0
# 741:	 short_desc_emb_315 - 0.0
# 742:	 short_desc_emb_316 - 0.0
# 743:	 short_desc_emb_317 - 0.0
# 744:	 short_desc_emb_318 - 0.0
# 745:	 short_desc_emb_320 - 0.0
# 746:	 short_desc_emb_321 - 0.0
# 747:	 short_desc_emb_322 - 0.0
# 748:	 short_desc_emb_323 - 0.0
# 749:	 short_desc_emb_325 - 0.0
# 750:	 short_desc_emb_326 - 0.0
# 751:	 short_desc_emb_327 - 0.0
# 752:	 short_desc_emb_328 - 0.0
# 753:	 short_desc_emb_329 - 0.0
# 754:	 short_desc_emb_330 - 0.0
# 755:	 short_desc_emb_331 - 0.0
# 756:	 short_desc_emb_332 - 0.0
# 757:	 short_desc_emb_333 - 0.0
# 758:	 short_desc_emb_334 - 0.0
# 759:	 short_desc_emb_335 - 0.0
# 760:	 short_desc_emb_336 - 0.0
# 761:	 short_desc_emb_337 - 0.0
# 762:	 short_desc_emb_338 - 0.0
# 763:	 short_desc_emb_339 - 0.0
# 764:	 short_desc_emb_340 - 0.0
# 765:	 short_desc_emb_341 - 0.0
# 766:	 short_desc_emb_342 - 0.0
# 767:	 short_desc_emb_343 - 0.0
# 768:	 short_desc_emb_344 - 0.0
# 769:	 short_desc_emb_345 - 0.0
# 770:	 short_desc_emb_346 - 0.0
# 771:	 short_desc_emb_347 - 0.0
# 772:	 short_desc_emb_348 - 0.0
# 773:	 short_desc_emb_349 - 0.0
# 774:	 short_desc_emb_350 - 0.0
# 775:	 short_desc_emb_351 - 0.0
# 776:	 short_desc_emb_352 - 0.0
# 777:	 short_desc_emb_353 - 0.0
# 778:	 short_desc_emb_354 - 0.0
# 779:	 short_desc_emb_355 - 0.0
# 780:	 short_desc_emb_356 - 0.0
# 781:	 short_desc_emb_357 - 0.0
# 782:	 short_desc_emb_358 - 0.0
# 783:	 short_desc_emb_359 - 0.0
# 784:	 short_desc_emb_360 - 0.0
# 785:	 short_desc_emb_361 - 0.0
# 786:	 short_desc_emb_362 - 0.0
# 787:	 short_desc_emb_363 - 0.0
# 788:	 short_desc_emb_364 - 0.0
# 789:	 short_desc_emb_365 - 0.0
# 790:	 short_desc_emb_366 - 0.0
# 791:	 short_desc_emb_367 - 0.0
# 792:	 short_desc_emb_368 - 0.0
# 793:	 short_desc_emb_369 - 0.0
# 794:	 short_desc_emb_370 - 0.0
# 795:	 short_desc_emb_371 - 0.0
# 796:	 short_desc_emb_372 - 0.0
# 797:	 short_desc_emb_373 - 0.0
# 798:	 short_desc_emb_374 - 0.0
# 799:	 short_desc_emb_375 - 0.0
# 800:	 short_desc_emb_376 - 0.0
# 801:	 short_desc_emb_377 - 0.0
# 802:	 short_desc_emb_378 - 0.0
# 803:	 short_desc_emb_381 - 0.0
# 804:	 short_desc_emb_382 - 0.0
# 805:	 short_desc_emb_383 - 0.0
# 806:	 long_desc_emb_0 - 0.0
# 807:	 long_desc_emb_1 - 0.0
# 808:	 long_desc_emb_2 - 0.0
# 809:	 long_desc_emb_3 - 0.0
# 810:	 long_desc_emb_4 - 0.0
# 811:	 long_desc_emb_5 - 0.0
# 812:	 long_desc_emb_6 - 0.0
# 813:	 long_desc_emb_7 - 0.0
# 814:	 long_desc_emb_8 - 0.0
# 815:	 long_desc_emb_9 - 0.0
# 816:	 long_desc_emb_10 - 0.0
# 817:	 long_desc_emb_11 - 0.0
# 818:	 long_desc_emb_12 - 0.0
# 819:	 long_desc_emb_13 - 0.0
# 820:	 long_desc_emb_14 - 0.0
# 821:	 long_desc_emb_15 - 0.0
# 822:	 long_desc_emb_16 - 0.0
# 823:	 long_desc_emb_17 - 0.0
# 824:	 long_desc_emb_18 - 0.0
# 825:	 long_desc_emb_19 - 0.0
# 826:	 long_desc_emb_20 - 0.0
# 827:	 long_desc_emb_21 - 0.0
# 828:	 long_desc_emb_22 - 0.0
# 829:	 long_desc_emb_23 - 0.0
# 830:	 long_desc_emb_24 - 0.0
# 831:	 long_desc_emb_25 - 0.0
# 832:	 long_desc_emb_26 - 0.0
# 833:	 long_desc_emb_27 - 0.0
# 834:	 long_desc_emb_28 - 0.0
# 835:	 long_desc_emb_29 - 0.0
# 836:	 long_desc_emb_30 - 0.0
# 837:	 long_desc_emb_31 - 0.0
# 838:	 long_desc_emb_32 - 0.0
# 839:	 long_desc_emb_33 - 0.0
# 840:	 long_desc_emb_34 - 0.0
# 841:	 long_desc_emb_35 - 0.0
# 842:	 long_desc_emb_36 - 0.0
# 843:	 long_desc_emb_37 - 0.0
# 844:	 long_desc_emb_38 - 0.0
# 845:	 long_desc_emb_39 - 0.0
# 846:	 long_desc_emb_40 - 0.0
# 847:	 long_desc_emb_41 - 0.0
# 848:	 long_desc_emb_42 - 0.0
# 849:	 long_desc_emb_43 - 0.0
# 850:	 long_desc_emb_44 - 0.0
# 851:	 long_desc_emb_45 - 0.0
# 852:	 long_desc_emb_46 - 0.0
# 853:	 long_desc_emb_47 - 0.0
# 854:	 long_desc_emb_48 - 0.0
# 855:	 long_desc_emb_49 - 0.0
# 856:	 long_desc_emb_50 - 0.0
# 857:	 long_desc_emb_51 - 0.0
# 858:	 long_desc_emb_52 - 0.0
# 859:	 long_desc_emb_53 - 0.0
# 860:	 long_desc_emb_54 - 0.0
# 861:	 long_desc_emb_55 - 0.0
# 862:	 long_desc_emb_56 - 0.0
# 863:	 long_desc_emb_57 - 0.0
# 864:	 long_desc_emb_58 - 0.0
# 865:	 long_desc_emb_59 - 0.0
# 866:	 long_desc_emb_60 - 0.0
# 867:	 long_desc_emb_61 - 0.0
# 868:	 long_desc_emb_62 - 0.0
# 869:	 long_desc_emb_63 - 0.0
# 870:	 long_desc_emb_64 - 0.0
# 871:	 long_desc_emb_65 - 0.0
# 872:	 long_desc_emb_66 - 0.0
# 873:	 long_desc_emb_67 - 0.0
# 874:	 long_desc_emb_68 - 0.0
# 875:	 long_desc_emb_69 - 0.0
# 876:	 long_desc_emb_70 - 0.0
# 877:	 long_desc_emb_71 - 0.0
# 878:	 long_desc_emb_72 - 0.0
# 879:	 long_desc_emb_73 - 0.0
# 880:	 long_desc_emb_74 - 0.0
# 881:	 long_desc_emb_75 - 0.0
# 882:	 long_desc_emb_76 - 0.0
# 883:	 long_desc_emb_77 - 0.0
# 884:	 long_desc_emb_78 - 0.0
# 885:	 long_desc_emb_79 - 0.0
# 886:	 long_desc_emb_80 - 0.0
# 887:	 long_desc_emb_81 - 0.0
# 888:	 long_desc_emb_82 - 0.0
# 889:	 long_desc_emb_83 - 0.0
# 890:	 long_desc_emb_84 - 0.0
# 891:	 long_desc_emb_85 - 0.0
# 892:	 long_desc_emb_86 - 0.0
# 893:	 long_desc_emb_87 - 0.0
# 894:	 long_desc_emb_88 - 0.0
# 895:	 long_desc_emb_89 - 0.0
# 896:	 long_desc_emb_90 - 0.0
# 897:	 long_desc_emb_91 - 0.0
# 898:	 long_desc_emb_92 - 0.0
# 899:	 long_desc_emb_93 - 0.0
# 900:	 long_desc_emb_94 - 0.0
# 901:	 long_desc_emb_95 - 0.0
# 902:	 long_desc_emb_96 - 0.0
# 903:	 long_desc_emb_97 - 0.0
# 904:	 long_desc_emb_98 - 0.0
# 905:	 long_desc_emb_99 - 0.0
# 906:	 long_desc_emb_100 - 0.0
# 907:	 long_desc_emb_101 - 0.0
# 908:	 long_desc_emb_102 - 0.0
# 909:	 long_desc_emb_103 - 0.0
# 910:	 long_desc_emb_104 - 0.0
# 911:	 long_desc_emb_105 - 0.0
# 912:	 long_desc_emb_106 - 0.0
# 913:	 long_desc_emb_107 - 0.0
# 914:	 long_desc_emb_108 - 0.0
# 915:	 long_desc_emb_109 - 0.0
# 916:	 long_desc_emb_110 - 0.0
# 917:	 long_desc_emb_111 - 0.0
# 918:	 long_desc_emb_112 - 0.0
# 919:	 long_desc_emb_113 - 0.0
# 920:	 long_desc_emb_114 - 0.0
# 921:	 long_desc_emb_115 - 0.0
# 922:	 long_desc_emb_116 - 0.0
# 923:	 long_desc_emb_117 - 0.0
# 924:	 long_desc_emb_118 - 0.0
# 925:	 long_desc_emb_119 - 0.0
# 926:	 long_desc_emb_120 - 0.0
# 927:	 long_desc_emb_121 - 0.0
# 928:	 long_desc_emb_122 - 0.0
# 929:	 long_desc_emb_123 - 0.0
# 930:	 long_desc_emb_124 - 0.0
# 931:	 long_desc_emb_125 - 0.0
# 932:	 long_desc_emb_126 - 0.0
# 933:	 long_desc_emb_127 - 0.0
# 934:	 long_desc_emb_128 - 0.0
# 935:	 long_desc_emb_129 - 0.0
# 936:	 long_desc_emb_130 - 0.0
# 937:	 long_desc_emb_131 - 0.0
# 938:	 long_desc_emb_132 - 0.0
# 939:	 long_desc_emb_133 - 0.0
# 940:	 long_desc_emb_134 - 0.0
# 941:	 long_desc_emb_135 - 0.0
# 942:	 long_desc_emb_136 - 0.0
# 943:	 long_desc_emb_137 - 0.0
# 944:	 long_desc_emb_138 - 0.0
# 945:	 long_desc_emb_139 - 0.0
# 946:	 long_desc_emb_140 - 0.0
# 947:	 long_desc_emb_141 - 0.0
# 948:	 long_desc_emb_142 - 0.0
# 949:	 long_desc_emb_143 - 0.0
# 950:	 long_desc_emb_144 - 0.0
# 951:	 long_desc_emb_145 - 0.0
# 952:	 long_desc_emb_146 - 0.0
# 953:	 long_desc_emb_147 - 0.0
# 954:	 long_desc_emb_148 - 0.0
# 955:	 long_desc_emb_149 - 0.0
# 956:	 long_desc_emb_150 - 0.0
# 957:	 long_desc_emb_151 - 0.0
# 958:	 long_desc_emb_152 - 0.0
# 959:	 long_desc_emb_153 - 0.0
# 960:	 long_desc_emb_154 - 0.0
# 961:	 long_desc_emb_155 - 0.0
# 962:	 long_desc_emb_156 - 0.0
# 963:	 long_desc_emb_157 - 0.0
# 964:	 long_desc_emb_158 - 0.0
# 965:	 long_desc_emb_159 - 0.0
# 966:	 long_desc_emb_160 - 0.0
# 967:	 long_desc_emb_161 - 0.0
# 968:	 long_desc_emb_162 - 0.0
# 969:	 long_desc_emb_163 - 0.0
# 970:	 long_desc_emb_164 - 0.0
# 971:	 long_desc_emb_165 - 0.0
# 972:	 long_desc_emb_166 - 0.0
# 973:	 long_desc_emb_167 - 0.0
# 974:	 long_desc_emb_168 - 0.0
# 975:	 long_desc_emb_169 - 0.0
# 976:	 long_desc_emb_170 - 0.0
# 977:	 long_desc_emb_171 - 0.0
# 978:	 long_desc_emb_172 - 0.0
# 979:	 long_desc_emb_173 - 0.0
# 980:	 long_desc_emb_174 - 0.0
# 981:	 long_desc_emb_175 - 0.0
# 982:	 long_desc_emb_176 - 0.0
# 983:	 long_desc_emb_177 - 0.0
# 984:	 long_desc_emb_178 - 0.0
# 985:	 long_desc_emb_179 - 0.0
# 986:	 long_desc_emb_180 - 0.0
# 987:	 long_desc_emb_181 - 0.0
# 988:	 long_desc_emb_182 - 0.0
# 989:	 long_desc_emb_183 - 0.0
# 990:	 long_desc_emb_184 - 0.0
# 991:	 long_desc_emb_185 - 0.0
# 992:	 long_desc_emb_186 - 0.0
# 993:	 long_desc_emb_187 - 0.0
# 994:	 long_desc_emb_188 - 0.0
# 995:	 long_desc_emb_189 - 0.0
# 996:	 long_desc_emb_190 - 0.0
# 997:	 long_desc_emb_191 - 0.0
# 998:	 long_desc_emb_192 - 0.0
# 999:	 long_desc_emb_193 - 0.0
# 1000:	 long_desc_emb_194 - 0.0
# 1001:	 long_desc_emb_195 - 0.0
# 1002:	 long_desc_emb_196 - 0.0
# 1003:	 long_desc_emb_197 - 0.0
# 1004:	 long_desc_emb_198 - 0.0
# 1005:	 long_desc_emb_199 - 0.0
# 1006:	 long_desc_emb_200 - 0.0
# 1007:	 long_desc_emb_201 - 0.0
# 1008:	 long_desc_emb_202 - 0.0
# 1009:	 long_desc_emb_203 - 0.0
# 1010:	 long_desc_emb_204 - 0.0
# 1011:	 long_desc_emb_205 - 0.0
# 1012:	 long_desc_emb_206 - 0.0
# 1013:	 long_desc_emb_207 - 0.0
# 1014:	 long_desc_emb_208 - 0.0
# 1015:	 long_desc_emb_209 - 0.0
# 1016:	 long_desc_emb_210 - 0.0
# 1017:	 long_desc_emb_211 - 0.0
# 1018:	 long_desc_emb_212 - 0.0
# 1019:	 long_desc_emb_213 - 0.0
# 1020:	 long_desc_emb_214 - 0.0
# 1021:	 long_desc_emb_215 - 0.0
# 1022:	 long_desc_emb_216 - 0.0
# 1023:	 long_desc_emb_217 - 0.0
# 1024:	 long_desc_emb_218 - 0.0
# 1025:	 long_desc_emb_219 - 0.0
# 1026:	 long_desc_emb_220 - 0.0
# 1027:	 long_desc_emb_221 - 0.0
# 1028:	 long_desc_emb_222 - 0.0
# 1029:	 long_desc_emb_223 - 0.0
# 1030:	 long_desc_emb_224 - 0.0
# 1031:	 long_desc_emb_225 - 0.0
# 1032:	 long_desc_emb_226 - 0.0
# 1033:	 long_desc_emb_227 - 0.0
# 1034:	 long_desc_emb_228 - 0.0
# 1035:	 long_desc_emb_229 - 0.0
# 1036:	 long_desc_emb_230 - 0.0
# 1037:	 long_desc_emb_231 - 0.0
# 1038:	 long_desc_emb_232 - 0.0
# 1039:	 long_desc_emb_233 - 0.0
# 1040:	 long_desc_emb_234 - 0.0
# 1041:	 long_desc_emb_235 - 0.0
# 1042:	 long_desc_emb_236 - 0.0
# 1043:	 long_desc_emb_237 - 0.0
# 1044:	 long_desc_emb_238 - 0.0
# 1045:	 long_desc_emb_239 - 0.0
# 1046:	 long_desc_emb_240 - 0.0
# 1047:	 long_desc_emb_241 - 0.0
# 1048:	 long_desc_emb_242 - 0.0
# 1049:	 long_desc_emb_243 - 0.0
# 1050:	 long_desc_emb_244 - 0.0
# 1051:	 long_desc_emb_245 - 0.0
# 1052:	 long_desc_emb_246 - 0.0
# 1053:	 long_desc_emb_247 - 0.0
# 1054:	 long_desc_emb_248 - 0.0
# 1055:	 long_desc_emb_249 - 0.0
# 1056:	 long_desc_emb_250 - 0.0
# 1057:	 long_desc_emb_251 - 0.0
# 1058:	 long_desc_emb_252 - 0.0
# 1059:	 long_desc_emb_253 - 0.0
# 1060:	 long_desc_emb_254 - 0.0
# 1061:	 long_desc_emb_255 - 0.0
# 1062:	 long_desc_emb_256 - 0.0
# 1063:	 long_desc_emb_257 - 0.0
# 1064:	 long_desc_emb_258 - 0.0
# 1065:	 long_desc_emb_259 - 0.0
# 1066:	 long_desc_emb_260 - 0.0
# 1067:	 long_desc_emb_261 - 0.0
# 1068:	 long_desc_emb_262 - 0.0
# 1069:	 long_desc_emb_263 - 0.0
# 1070:	 long_desc_emb_264 - 0.0
# 1071:	 long_desc_emb_265 - 0.0
# 1072:	 long_desc_emb_266 - 0.0
# 1073:	 long_desc_emb_267 - 0.0
# 1074:	 long_desc_emb_268 - 0.0
# 1075:	 long_desc_emb_269 - 0.0
# 1076:	 long_desc_emb_270 - 0.0
# 1077:	 long_desc_emb_271 - 0.0
# 1078:	 long_desc_emb_272 - 0.0
# 1079:	 long_desc_emb_273 - 0.0
# 1080:	 long_desc_emb_274 - 0.0
# 1081:	 long_desc_emb_275 - 0.0
# 1082:	 long_desc_emb_276 - 0.0
# 1083:	 long_desc_emb_277 - 0.0
# 1084:	 long_desc_emb_278 - 0.0
# 1085:	 long_desc_emb_279 - 0.0
# 1086:	 long_desc_emb_280 - 0.0
# 1087:	 long_desc_emb_281 - 0.0
# 1088:	 long_desc_emb_282 - 0.0
# 1089:	 long_desc_emb_283 - 0.0
# 1090:	 long_desc_emb_284 - 0.0
# 1091:	 long_desc_emb_285 - 0.0
# 1092:	 long_desc_emb_286 - 0.0
# 1093:	 long_desc_emb_287 - 0.0
# 1094:	 long_desc_emb_288 - 0.0
# 1095:	 long_desc_emb_289 - 0.0
# 1096:	 long_desc_emb_290 - 0.0
# 1097:	 long_desc_emb_291 - 0.0
# 1098:	 long_desc_emb_292 - 0.0
# 1099:	 long_desc_emb_293 - 0.0
# 1100:	 long_desc_emb_294 - 0.0
# 1101:	 long_desc_emb_295 - 0.0
# 1102:	 long_desc_emb_296 - 0.0
# 1103:	 long_desc_emb_297 - 0.0
# 1104:	 long_desc_emb_298 - 0.0
# 1105:	 long_desc_emb_299 - 0.0
# 1106:	 long_desc_emb_300 - 0.0
# 1107:	 long_desc_emb_301 - 0.0
# 1108:	 long_desc_emb_302 - 0.0
# 1109:	 long_desc_emb_303 - 0.0
# 1110:	 long_desc_emb_304 - 0.0
# 1111:	 long_desc_emb_305 - 0.0
# 1112:	 long_desc_emb_306 - 0.0
# 1113:	 long_desc_emb_307 - 0.0
# 1114:	 long_desc_emb_308 - 0.0
# 1115:	 long_desc_emb_309 - 0.0
# 1116:	 long_desc_emb_310 - 0.0
# 1117:	 long_desc_emb_311 - 0.0
# 1118:	 long_desc_emb_312 - 0.0
# 1119:	 long_desc_emb_313 - 0.0
# 1120:	 long_desc_emb_314 - 0.0
# 1121:	 long_desc_emb_315 - 0.0
# 1122:	 long_desc_emb_316 - 0.0
# 1123:	 long_desc_emb_317 - 0.0
# 1124:	 long_desc_emb_318 - 0.0
# 1125:	 long_desc_emb_319 - 0.0
# 1126:	 long_desc_emb_320 - 0.0
# 1127:	 long_desc_emb_321 - 0.0
# 1128:	 long_desc_emb_322 - 0.0
# 1129:	 long_desc_emb_323 - 0.0
# 1130:	 long_desc_emb_324 - 0.0
# 1131:	 long_desc_emb_325 - 0.0
# 1132:	 long_desc_emb_326 - 0.0
# 1133:	 long_desc_emb_327 - 0.0
# 1134:	 long_desc_emb_328 - 0.0
# 1135:	 long_desc_emb_329 - 0.0
# 1136:	 long_desc_emb_330 - 0.0
# 1137:	 long_desc_emb_331 - 0.0
# 1138:	 long_desc_emb_332 - 0.0
# 1139:	 long_desc_emb_333 - 0.0
# 1140:	 long_desc_emb_334 - 0.0
# 1141:	 long_desc_emb_335 - 0.0
# 1142:	 long_desc_emb_336 - 0.0
# 1143:	 long_desc_emb_337 - 0.0
# 1144:	 long_desc_emb_338 - 0.0
# 1145:	 long_desc_emb_339 - 0.0
# 1146:	 long_desc_emb_340 - 0.0
# 1147:	 long_desc_emb_341 - 0.0
# 1148:	 long_desc_emb_342 - 0.0
# 1149:	 long_desc_emb_343 - 0.0
# 1150:	 long_desc_emb_344 - 0.0
# 1151:	 long_desc_emb_345 - 0.0
# 1152:	 long_desc_emb_346 - 0.0
# 1153:	 long_desc_emb_347 - 0.0
# 1154:	 long_desc_emb_348 - 0.0
# 1155:	 long_desc_emb_349 - 0.0
# 1156:	 long_desc_emb_350 - 0.0
# 1157:	 long_desc_emb_351 - 0.0
# 1158:	 long_desc_emb_352 - 0.0
# 1159:	 long_desc_emb_353 - 0.0
# 1160:	 long_desc_emb_354 - 0.0
# 1161:	 long_desc_emb_355 - 0.0
# 1162:	 long_desc_emb_356 - 0.0
# 1163:	 long_desc_emb_357 - 0.0
# 1164:	 long_desc_emb_358 - 0.0
# 1165:	 long_desc_emb_359 - 0.0
# 1166:	 long_desc_emb_360 - 0.0
# 1167:	 long_desc_emb_361 - 0.0
# 1168:	 long_desc_emb_362 - 0.0
# 1169:	 long_desc_emb_363 - 0.0
# 1170:	 long_desc_emb_364 - 0.0
# 1171:	 long_desc_emb_365 - 0.0
# 1172:	 long_desc_emb_366 - 0.0
# 1173:	 long_desc_emb_367 - 0.0
# 1174:	 long_desc_emb_368 - 0.0
# 1175:	 long_desc_emb_369 - 0.0
# 1176:	 long_desc_emb_370 - 0.0
# 1177:	 long_desc_emb_371 - 0.0
# 1178:	 long_desc_emb_372 - 0.0
# 1179:	 long_desc_emb_373 - 0.0
# 1180:	 long_desc_emb_374 - 0.0
# 1181:	 long_desc_emb_375 - 0.0
# 1182:	 long_desc_emb_376 - 0.0
# 1183:	 long_desc_emb_377 - 0.0
# 1184:	 long_desc_emb_378 - 0.0
# 1185:	 long_desc_emb_379 - 0.0
# 1186:	 long_desc_emb_380 - 0.0
# 1187:	 long_desc_emb_381 - 0.0
# 1188:	 long_desc_emb_382 - 0.0
# 1189:	 long_desc_emb_383 - 0.0
# 1190:	 tags_emb_0 - 0.0
# 1191:	 tags_emb_1 - 0.0
# 1192:	 tags_emb_3 - 0.0
# 1193:	 tags_emb_4 - 0.0
# 1194:	 tags_emb_5 - 0.0
# 1195:	 tags_emb_6 - 0.0
# 1196:	 tags_emb_7 - 0.0
# 1197:	 tags_emb_8 - 0.0
# 1198:	 tags_emb_9 - 0.0
# 1199:	 tags_emb_10 - 0.0
# 1200:	 tags_emb_11 - 0.0
# 1201:	 tags_emb_12 - 0.0
# 1202:	 tags_emb_15 - 0.0
# 1203:	 tags_emb_16 - 0.0
# 1204:	 tags_emb_17 - 0.0
# 1205:	 tags_emb_18 - 0.0
# 1206:	 tags_emb_19 - 0.0
# 1207:	 tags_emb_20 - 0.0
# 1208:	 tags_emb_21 - 0.0
# 1209:	 tags_emb_22 - 0.0
# 1210:	 tags_emb_23 - 0.0
# 1211:	 tags_emb_24 - 0.0
# 1212:	 tags_emb_25 - 0.0
# 1213:	 tags_emb_27 - 0.0
# 1214:	 tags_emb_28 - 0.0
# 1215:	 tags_emb_29 - 0.0
# 1216:	 tags_emb_30 - 0.0
# 1217:	 tags_emb_31 - 0.0
# 1218:	 tags_emb_32 - 0.0
# 1219:	 tags_emb_33 - 0.0
# 1220:	 tags_emb_34 - 0.0
# 1221:	 tags_emb_35 - 0.0
# 1222:	 tags_emb_36 - 0.0
# 1223:	 tags_emb_37 - 0.0
# 1224:	 tags_emb_38 - 0.0
# 1225:	 tags_emb_39 - 0.0
# 1226:	 tags_emb_40 - 0.0
# 1227:	 tags_emb_41 - 0.0
# 1228:	 tags_emb_42 - 0.0
# 1229:	 tags_emb_43 - 0.0
# 1230:	 tags_emb_44 - 0.0
# 1231:	 tags_emb_46 - 0.0
# 1232:	 tags_emb_47 - 0.0
# 1233:	 tags_emb_48 - 0.0
# 1234:	 tags_emb_49 - 0.0
# 1235:	 tags_emb_50 - 0.0
# 1236:	 tags_emb_51 - 0.0
# 1237:	 tags_emb_52 - 0.0
# 1238:	 tags_emb_54 - 0.0
# 1239:	 tags_emb_55 - 0.0
# 1240:	 tags_emb_56 - 0.0
# 1241:	 tags_emb_57 - 0.0
# 1242:	 tags_emb_58 - 0.0
# 1243:	 tags_emb_59 - 0.0
# 1244:	 tags_emb_60 - 0.0
# 1245:	 tags_emb_61 - 0.0
# 1246:	 tags_emb_62 - 0.0
# 1247:	 tags_emb_63 - 0.0
# 1248:	 tags_emb_64 - 0.0
# 1249:	 tags_emb_65 - 0.0
# 1250:	 tags_emb_66 - 0.0
# 1251:	 tags_emb_67 - 0.0
# 1252:	 tags_emb_68 - 0.0
# 1253:	 tags_emb_69 - 0.0
# 1254:	 tags_emb_70 - 0.0
# 1255:	 tags_emb_71 - 0.0
# 1256:	 tags_emb_72 - 0.0
# 1257:	 tags_emb_73 - 0.0
# 1258:	 tags_emb_74 - 0.0
# 1259:	 tags_emb_75 - 0.0
# 1260:	 tags_emb_76 - 0.0
# 1261:	 tags_emb_78 - 0.0
# 1262:	 tags_emb_79 - 0.0
# 1263:	 tags_emb_80 - 0.0
# 1264:	 tags_emb_81 - 0.0
# 1265:	 tags_emb_82 - 0.0
# 1266:	 tags_emb_83 - 0.0
# 1267:	 tags_emb_84 - 0.0
# 1268:	 tags_emb_85 - 0.0
# 1269:	 tags_emb_86 - 0.0
# 1270:	 tags_emb_87 - 0.0
# 1271:	 tags_emb_88 - 0.0
# 1272:	 tags_emb_89 - 0.0
# 1273:	 tags_emb_90 - 0.0
# 1274:	 tags_emb_92 - 0.0
# 1275:	 tags_emb_93 - 0.0
# 1276:	 tags_emb_94 - 0.0
# 1277:	 tags_emb_95 - 0.0
# 1278:	 tags_emb_97 - 0.0
# 1279:	 tags_emb_98 - 0.0
# 1280:	 tags_emb_99 - 0.0
# 1281:	 tags_emb_100 - 0.0
# 1282:	 tags_emb_101 - 0.0
# 1283:	 tags_emb_103 - 0.0
# 1284:	 tags_emb_104 - 0.0
# 1285:	 tags_emb_105 - 0.0
# 1286:	 tags_emb_107 - 0.0
# 1287:	 tags_emb_108 - 0.0
# 1288:	 tags_emb_109 - 0.0
# 1289:	 tags_emb_110 - 0.0
# 1290:	 tags_emb_112 - 0.0
# 1291:	 tags_emb_113 - 0.0
# 1292:	 tags_emb_114 - 0.0
# 1293:	 tags_emb_115 - 0.0
# 1294:	 tags_emb_116 - 0.0
# 1295:	 tags_emb_117 - 0.0
# 1296:	 tags_emb_118 - 0.0
# 1297:	 tags_emb_119 - 0.0
# 1298:	 tags_emb_120 - 0.0
# 1299:	 tags_emb_121 - 0.0
# 1300:	 tags_emb_122 - 0.0
# 1301:	 tags_emb_123 - 0.0
# 1302:	 tags_emb_124 - 0.0
# 1303:	 tags_emb_125 - 0.0
# 1304:	 tags_emb_126 - 0.0
# 1305:	 tags_emb_127 - 0.0
# 1306:	 tags_emb_128 - 0.0
# 1307:	 tags_emb_129 - 0.0
# 1308:	 tags_emb_130 - 0.0
# 1309:	 tags_emb_131 - 0.0
# 1310:	 tags_emb_132 - 0.0
# 1311:	 tags_emb_133 - 0.0
# 1312:	 tags_emb_134 - 0.0
# 1313:	 tags_emb_135 - 0.0
# 1314:	 tags_emb_136 - 0.0
# 1315:	 tags_emb_137 - 0.0
# 1316:	 tags_emb_138 - 0.0
# 1317:	 tags_emb_139 - 0.0
# 1318:	 tags_emb_141 - 0.0
# 1319:	 tags_emb_142 - 0.0
# 1320:	 tags_emb_143 - 0.0
# 1321:	 tags_emb_144 - 0.0
# 1322:	 tags_emb_145 - 0.0
# 1323:	 tags_emb_146 - 0.0
# 1324:	 tags_emb_147 - 0.0
# 1325:	 tags_emb_148 - 0.0
# 1326:	 tags_emb_149 - 0.0
# 1327:	 tags_emb_150 - 0.0
# 1328:	 tags_emb_151 - 0.0
# 1329:	 tags_emb_152 - 0.0
# 1330:	 tags_emb_153 - 0.0
# 1331:	 tags_emb_154 - 0.0
# 1332:	 tags_emb_155 - 0.0
# 1333:	 tags_emb_156 - 0.0
# 1334:	 tags_emb_157 - 0.0
# 1335:	 tags_emb_158 - 0.0
# 1336:	 tags_emb_159 - 0.0
# 1337:	 tags_emb_160 - 0.0
# 1338:	 tags_emb_161 - 0.0
# 1339:	 tags_emb_163 - 0.0
# 1340:	 tags_emb_164 - 0.0
# 1341:	 tags_emb_165 - 0.0
# 1342:	 tags_emb_166 - 0.0
# 1343:	 tags_emb_167 - 0.0
# 1344:	 tags_emb_168 - 0.0
# 1345:	 tags_emb_169 - 0.0
# 1346:	 tags_emb_170 - 0.0
# 1347:	 tags_emb_171 - 0.0
# 1348:	 tags_emb_172 - 0.0
# 1349:	 tags_emb_173 - 0.0
# 1350:	 tags_emb_174 - 0.0
# 1351:	 tags_emb_175 - 0.0
# 1352:	 tags_emb_176 - 0.0
# 1353:	 tags_emb_177 - 0.0
# 1354:	 tags_emb_178 - 0.0
# 1355:	 tags_emb_179 - 0.0
# 1356:	 tags_emb_180 - 0.0
# 1357:	 tags_emb_181 - 0.0
# 1358:	 tags_emb_182 - 0.0
# 1359:	 tags_emb_183 - 0.0
# 1360:	 tags_emb_184 - 0.0
# 1361:	 tags_emb_185 - 0.0
# 1362:	 tags_emb_186 - 0.0
# 1363:	 tags_emb_187 - 0.0
# 1364:	 tags_emb_188 - 0.0
# 1365:	 tags_emb_189 - 0.0
# 1366:	 tags_emb_190 - 0.0
# 1367:	 tags_emb_191 - 0.0
# 1368:	 tags_emb_192 - 0.0
# 1369:	 tags_emb_193 - 0.0
# 1370:	 tags_emb_194 - 0.0
# 1371:	 tags_emb_195 - 0.0
# 1372:	 tags_emb_198 - 0.0
# 1373:	 tags_emb_199 - 0.0
# 1374:	 tags_emb_200 - 0.0
# 1375:	 tags_emb_201 - 0.0
# 1376:	 tags_emb_202 - 0.0
# 1377:	 tags_emb_203 - 0.0
# 1378:	 tags_emb_204 - 0.0
# 1379:	 tags_emb_205 - 0.0
# 1380:	 tags_emb_206 - 0.0
# 1381:	 tags_emb_207 - 0.0
# 1382:	 tags_emb_208 - 0.0
# 1383:	 tags_emb_209 - 0.0
# 1384:	 tags_emb_210 - 0.0
# 1385:	 tags_emb_211 - 0.0
# 1386:	 tags_emb_212 - 0.0
# 1387:	 tags_emb_213 - 0.0
# 1388:	 tags_emb_214 - 0.0
# 1389:	 tags_emb_215 - 0.0
# 1390:	 tags_emb_216 - 0.0
# 1391:	 tags_emb_217 - 0.0
# 1392:	 tags_emb_220 - 0.0
# 1393:	 tags_emb_221 - 0.0
# 1394:	 tags_emb_222 - 0.0
# 1395:	 tags_emb_223 - 0.0
# 1396:	 tags_emb_224 - 0.0
# 1397:	 tags_emb_225 - 0.0
# 1398:	 tags_emb_226 - 0.0
# 1399:	 tags_emb_227 - 0.0
# 1400:	 tags_emb_228 - 0.0
# 1401:	 tags_emb_229 - 0.0
# 1402:	 tags_emb_230 - 0.0
# 1403:	 tags_emb_231 - 0.0
# 1404:	 tags_emb_232 - 0.0
# 1405:	 tags_emb_233 - 0.0
# 1406:	 tags_emb_234 - 0.0
# 1407:	 tags_emb_235 - 0.0
# 1408:	 tags_emb_236 - 0.0
# 1409:	 tags_emb_237 - 0.0
# 1410:	 tags_emb_238 - 0.0
# 1411:	 tags_emb_239 - 0.0
# 1412:	 tags_emb_240 - 0.0
# 1413:	 tags_emb_241 - 0.0
# 1414:	 tags_emb_242 - 0.0
# 1415:	 tags_emb_243 - 0.0
# 1416:	 tags_emb_244 - 0.0
# 1417:	 tags_emb_245 - 0.0
# 1418:	 tags_emb_247 - 0.0
# 1419:	 tags_emb_248 - 0.0
# 1420:	 tags_emb_249 - 0.0
# 1421:	 tags_emb_250 - 0.0
# 1422:	 tags_emb_252 - 0.0
# 1423:	 tags_emb_253 - 0.0
# 1424:	 tags_emb_254 - 0.0
# 1425:	 tags_emb_255 - 0.0
# 1426:	 tags_emb_256 - 0.0
# 1427:	 tags_emb_257 - 0.0
# 1428:	 tags_emb_258 - 0.0
# 1429:	 tags_emb_260 - 0.0
# 1430:	 tags_emb_261 - 0.0
# 1431:	 tags_emb_262 - 0.0
# 1432:	 tags_emb_263 - 0.0
# 1433:	 tags_emb_264 - 0.0
# 1434:	 tags_emb_265 - 0.0
# 1435:	 tags_emb_267 - 0.0
# 1436:	 tags_emb_268 - 0.0
# 1437:	 tags_emb_269 - 0.0
# 1438:	 tags_emb_270 - 0.0
# 1439:	 tags_emb_271 - 0.0
# 1440:	 tags_emb_272 - 0.0
# 1441:	 tags_emb_273 - 0.0
# 1442:	 tags_emb_274 - 0.0
# 1443:	 tags_emb_275 - 0.0
# 1444:	 tags_emb_276 - 0.0
# 1445:	 tags_emb_277 - 0.0
# 1446:	 tags_emb_278 - 0.0
# 1447:	 tags_emb_279 - 0.0
# 1448:	 tags_emb_280 - 0.0
# 1449:	 tags_emb_281 - 0.0
# 1450:	 tags_emb_282 - 0.0
# 1451:	 tags_emb_283 - 0.0
# 1452:	 tags_emb_285 - 0.0
# 1453:	 tags_emb_286 - 0.0
# 1454:	 tags_emb_287 - 0.0
# 1455:	 tags_emb_288 - 0.0
# 1456:	 tags_emb_289 - 0.0
# 1457:	 tags_emb_290 - 0.0
# 1458:	 tags_emb_291 - 0.0
# 1459:	 tags_emb_292 - 0.0
# 1460:	 tags_emb_293 - 0.0
# 1461:	 tags_emb_294 - 0.0
# 1462:	 tags_emb_296 - 0.0
# 1463:	 tags_emb_298 - 0.0
# 1464:	 tags_emb_299 - 0.0
# 1465:	 tags_emb_300 - 0.0
# 1466:	 tags_emb_301 - 0.0
# 1467:	 tags_emb_302 - 0.0
# 1468:	 tags_emb_303 - 0.0
# 1469:	 tags_emb_304 - 0.0
# 1470:	 tags_emb_305 - 0.0
# 1471:	 tags_emb_306 - 0.0
# 1472:	 tags_emb_307 - 0.0
# 1473:	 tags_emb_308 - 0.0
# 1474:	 tags_emb_309 - 0.0
# 1475:	 tags_emb_310 - 0.0
# 1476:	 tags_emb_311 - 0.0
# 1477:	 tags_emb_312 - 0.0
# 1478:	 tags_emb_313 - 0.0
# 1479:	 tags_emb_315 - 0.0
# 1480:	 tags_emb_316 - 0.0
# 1481:	 tags_emb_317 - 0.0
# 1482:	 tags_emb_318 - 0.0
# 1483:	 tags_emb_319 - 0.0
# 1484:	 tags_emb_320 - 0.0
# 1485:	 tags_emb_321 - 0.0
# 1486:	 tags_emb_322 - 0.0
# 1487:	 tags_emb_323 - 0.0
# 1488:	 tags_emb_324 - 0.0
# 1489:	 tags_emb_325 - 0.0
# 1490:	 tags_emb_326 - 0.0
# 1491:	 tags_emb_327 - 0.0
# 1492:	 tags_emb_328 - 0.0
# 1493:	 tags_emb_329 - 0.0
# 1494:	 tags_emb_330 - 0.0
# 1495:	 tags_emb_332 - 0.0
# 1496:	 tags_emb_333 - 0.0
# 1497:	 tags_emb_335 - 0.0
# 1498:	 tags_emb_336 - 0.0
# 1499:	 tags_emb_337 - 0.0
# 1500:	 tags_emb_339 - 0.0
# 1501:	 tags_emb_340 - 0.0
# 1502:	 tags_emb_342 - 0.0
# 1503:	 tags_emb_343 - 0.0
# 1504:	 tags_emb_344 - 0.0
# 1505:	 tags_emb_345 - 0.0
# 1506:	 tags_emb_346 - 0.0
# 1507:	 tags_emb_347 - 0.0
# 1508:	 tags_emb_348 - 0.0
# 1509:	 tags_emb_349 - 0.0
# 1510:	 tags_emb_350 - 0.0
# 1511:	 tags_emb_351 - 0.0
# 1512:	 tags_emb_352 - 0.0
# 1513:	 tags_emb_353 - 0.0
# 1514:	 tags_emb_354 - 0.0
# 1515:	 tags_emb_356 - 0.0
# 1516:	 tags_emb_357 - 0.0
# 1517:	 tags_emb_358 - 0.0
# 1518:	 tags_emb_359 - 0.0
# 1519:	 tags_emb_360 - 0.0
# 1520:	 tags_emb_361 - 0.0
# 1521:	 tags_emb_362 - 0.0
# 1522:	 tags_emb_363 - 0.0
# 1523:	 tags_emb_364 - 0.0
# 1524:	 tags_emb_365 - 0.0
# 1525:	 tags_emb_367 - 0.0
# 1526:	 tags_emb_368 - 0.0
# 1527:	 tags_emb_369 - 0.0
# 1528:	 tags_emb_370 - 0.0
# 1529:	 tags_emb_371 - 0.0
# 1530:	 tags_emb_372 - 0.0
# 1531:	 tags_emb_374 - 0.0
# 1532:	 tags_emb_375 - 0.0
# 1533:	 tags_emb_376 - 0.0
# 1534:	 tags_emb_377 - 0.0
# 1535:	 tags_emb_378 - 0.0
# 1536:	 tags_emb_379 - 0.0
# 1537:	 tags_emb_380 - 0.0
# 1538:	 tags_emb_381 - 0.0
# 1539:	 tags_emb_382 - 0.0
# 1540:	 tags_emb_383 - 0.0
